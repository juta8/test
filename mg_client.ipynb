# %%
# //      "proxies": {"http":"http://bbfvti:aG0bT05OOV@185.250.151.148:24531"}
import alpha_client
import alpha_creator
import alpha_parser
import alpha_requestor
import alpha_mode

# %%
mode = alpha_mode.AlphaMode('mg')

# %%
for i in range(50):
    mode.simulate_base_pack(100)
    mode.parse_pack(50)
# Out:
# Function simulating alphas started
# Simulating alpha (current_ratio/sales_ps > delay(current_ratio/sales_ps, 126)) ? 1 : -1
# Simulating alpha (debt/operating_income > delay(debt/operating_income, 126)) ? 1 : -1
# Simulating alpha (debt/pretax_income > delay(debt/pretax_income, 126)) ? 1 : -1
# Simulating alpha (debt/rd_expense > delay(debt/rd_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt/rd_expense > delay(debt/rd_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt/rd_expense > delay(debt/rd_expense, 126)) ? 1 : -1
# Simulating alpha (debt/receivable > delay(debt/receivable, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt/receivable > delay(debt/receivable, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt/receivable > delay(debt/receivable, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt/receivable > delay(debt/receivable, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt/receivable > delay(debt/receivable, 126)) ? 1 : -1
# Simulating alpha (debt/retained_earnings > delay(debt/retained_earnings, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt/retained_earnings > delay(debt/retained_earnings, 126)) ? 1 : -1
# Simulating alpha (debt/return_assets > delay(debt/return_assets, 126)) ? 1 : -1
# Simulating alpha (debt/return_equity > delay(debt/return_equity, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt/return_equity > delay(debt/return_equity, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt/return_equity > delay(debt/return_equity, 126)) ? 1 : -1
# Simulating alpha (debt/revenue > delay(debt/revenue, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt/revenue > delay(debt/revenue, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt/revenue > delay(debt/revenue, 126)) ? 1 : -1
# Simulating alpha (debt/sales > delay(debt/sales, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt/sales > delay(debt/sales, 126)) ? 1 : -1
# Simulating alpha (debt/sales_growth > delay(debt/sales_growth, 126)) ? 1 : -1
# Simulating alpha (debt/sales_ps > delay(debt/sales_ps, 126)) ? 1 : -1
# Simulating alpha (debt/SGA_expense > delay(debt/SGA_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt/SGA_expense > delay(debt/SGA_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt/SGA_expense > delay(debt/SGA_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt/SGA_expense > delay(debt/SGA_expense, 126)) ? 1 : -1
# Simulating alpha (debt/working_capital > delay(debt/working_capital, 126)) ? 1 : -1
# Simulating alpha (debt_lt/debt_st > delay(debt_lt/debt_st, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/debt_st > delay(debt_lt/debt_st, 126)) ? 1 : -1
# Simulating alpha (debt_lt/depre_amort > delay(debt_lt/depre_amort, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/depre_amort > delay(debt_lt/depre_amort, 126)) ? 1 : -1
# Simulating alpha (debt_lt/EBIT > delay(debt_lt/EBIT, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/EBIT > delay(debt_lt/EBIT, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/EBIT > delay(debt_lt/EBIT, 126)) ? 1 : -1
# Simulating alpha (debt_lt/EBITDA > delay(debt_lt/EBITDA, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/EBITDA > delay(debt_lt/EBITDA, 126)) ? 1 : -1
# Simulating alpha (debt_lt/employee > delay(debt_lt/employee, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/employee > delay(debt_lt/employee, 126)) ? 1 : -1
# Simulating alpha (debt_lt/enterprise_value > delay(debt_lt/enterprise_value, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/enterprise_value > delay(debt_lt/enterprise_value, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/enterprise_value > delay(debt_lt/enterprise_value, 126)) ? 1 : -1
# Simulating alpha (debt_lt/eps > delay(debt_lt/eps, 126)) ? 1 : -1
# Simulating alpha (debt_lt/equity > delay(debt_lt/equity, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/equity > delay(debt_lt/equity, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/equity > delay(debt_lt/equity, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/equity > delay(debt_lt/equity, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/equity > delay(debt_lt/equity, 126)) ? 1 : -1
# Simulating alpha (debt_lt/goodwill > delay(debt_lt/goodwill, 126)) ? 1 : -1
# Simulating alpha (debt_lt/income > delay(debt_lt/income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/income > delay(debt_lt/income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/income > delay(debt_lt/income, 126)) ? 1 : -1
# Simulating alpha (debt_lt/income_beforeextra > delay(debt_lt/income_beforeextra, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/income_beforeextra > delay(debt_lt/income_beforeextra, 126)) ? 1 : -1
# Simulating alpha (debt_lt/income_tax > delay(debt_lt/income_tax, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/income_tax > delay(debt_lt/income_tax, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/income_tax > delay(debt_lt/income_tax, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/income_tax > delay(debt_lt/income_tax, 126)) ? 1 : -1
# Simulating alpha (debt_lt/interest_expense > delay(debt_lt/interest_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/interest_expense > delay(debt_lt/interest_expense, 126)) ? 1 : -1
# Simulating alpha (debt_lt/inventory > delay(debt_lt/inventory, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/inventory > delay(debt_lt/inventory, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/inventory > delay(debt_lt/inventory, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/inventory > delay(debt_lt/inventory, 126)) ? 1 : -1
# Simulating alpha (debt_lt/inventory_turnover > delay(debt_lt/inventory_turnover, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/inventory_turnover > delay(debt_lt/inventory_turnover, 126)) ? 1 : -1
# Simulating alpha (debt_lt/invested_capital > delay(debt_lt/invested_capital, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/invested_capital > delay(debt_lt/invested_capital, 126)) ? 1 : -1
# Exception occured while simulating alphas Expecting value: line 1 column 1 (char 0)
# Simulating alpha (debt_lt/invested_capital > delay(debt_lt/invested_capital, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/invested_capital > delay(debt_lt/invested_capital, 126)) ? 1 : -1
# Simulating alpha (debt_lt/liabilities > delay(debt_lt/liabilities, 126)) ? 1 : -1
# Exception occured while simulating alphas Expecting value: line 1 column 1 (char 0)
# Simulating alpha (debt_lt/liabilities > delay(debt_lt/liabilities, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/liabilities > delay(debt_lt/liabilities, 126)) ? 1 : -1
# Simulating alpha (debt_lt/liabilities_curr > delay(debt_lt/liabilities_curr, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/liabilities_curr > delay(debt_lt/liabilities_curr, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/liabilities_curr > delay(debt_lt/liabilities_curr, 126)) ? 1 : -1
# Simulating alpha (debt_lt/operating_expense > delay(debt_lt/operating_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/operating_expense > delay(debt_lt/operating_expense, 126)) ? 1 : -1
# Exception occured while simulating alphas Expecting value: line 1 column 1 (char 0)
# Simulating alpha (debt_lt/operating_expense > delay(debt_lt/operating_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/operating_expense > delay(debt_lt/operating_expense, 126)) ? 1 : -1
# Simulating alpha (debt_lt/operating_income > delay(debt_lt/operating_income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/operating_income > delay(debt_lt/operating_income, 126)) ? 1 : -1
# Simulating alpha (debt_lt/pretax_income > delay(debt_lt/pretax_income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/pretax_income > delay(debt_lt/pretax_income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/pretax_income > delay(debt_lt/pretax_income, 126)) ? 1 : -1
# Exception occured while simulating alphas Expecting value: line 1 column 1 (char 0)
# Simulating alpha (debt_lt/pretax_income > delay(debt_lt/pretax_income, 126)) ? 1 : -1
# Exception occured while simulating alphas Expecting value: line 1 column 1 (char 0)
# Simulating alpha (debt_lt/pretax_income > delay(debt_lt/pretax_income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/pretax_income > delay(debt_lt/pretax_income, 126)) ? 1 : -1
# Simulating alpha (debt_lt/rd_expense > delay(debt_lt/rd_expense, 126)) ? 1 : -1
# Simulating alpha (debt_lt/receivable > delay(debt_lt/receivable, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/receivable > delay(debt_lt/receivable, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/receivable > delay(debt_lt/receivable, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/receivable > delay(debt_lt/receivable, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/receivable > delay(debt_lt/receivable, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/receivable > delay(debt_lt/receivable, 126)) ? 1 : -1
# Simulating alpha (debt_lt/retained_earnings > delay(debt_lt/retained_earnings, 126)) ? 1 : -1
# Simulating alpha (debt_lt/return_assets > delay(debt_lt/return_assets, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/return_assets > delay(debt_lt/return_assets, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/return_assets > delay(debt_lt/return_assets, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/return_assets > delay(debt_lt/return_assets, 126)) ? 1 : -1
# Simulating alpha (debt_lt/return_equity > delay(debt_lt/return_equity, 126)) ? 1 : -1
# Simulating alpha (debt_lt/revenue > delay(debt_lt/revenue, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/revenue > delay(debt_lt/revenue, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/revenue > delay(debt_lt/revenue, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/revenue > delay(debt_lt/revenue, 126)) ? 1 : -1
# Simulating alpha (debt_lt/sales > delay(debt_lt/sales, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/sales > delay(debt_lt/sales, 126)) ? 1 : -1
# Simulating alpha (debt_lt/sales_growth > delay(debt_lt/sales_growth, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/sales_growth > delay(debt_lt/sales_growth, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/sales_growth > delay(debt_lt/sales_growth, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/sales_growth > delay(debt_lt/sales_growth, 126)) ? 1 : -1
# Simulating alpha (debt_lt/sales_ps > delay(debt_lt/sales_ps, 126)) ? 1 : -1
# Simulating alpha (debt_lt/SGA_expense > delay(debt_lt/SGA_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/SGA_expense > delay(debt_lt/SGA_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/SGA_expense > delay(debt_lt/SGA_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/SGA_expense > delay(debt_lt/SGA_expense, 126)) ? 1 : -1
# Simulating alpha (debt_lt/working_capital > delay(debt_lt/working_capital, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/working_capital > delay(debt_lt/working_capital, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/working_capital > delay(debt_lt/working_capital, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_lt/working_capital > delay(debt_lt/working_capital, 126)) ? 1 : -1
# Simulating alpha (debt_st/depre_amort > delay(debt_st/depre_amort, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/depre_amort > delay(debt_st/depre_amort, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/depre_amort > delay(debt_st/depre_amort, 126)) ? 1 : -1
# Simulating alpha (debt_st/EBIT > delay(debt_st/EBIT, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/EBIT > delay(debt_st/EBIT, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/EBIT > delay(debt_st/EBIT, 126)) ? 1 : -1
# Simulating alpha (debt_st/EBITDA > delay(debt_st/EBITDA, 126)) ? 1 : -1
# Exception occured while simulating alphas Expecting value: line 1 column 1 (char 0)
# Simulating alpha (debt_st/EBITDA > delay(debt_st/EBITDA, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/EBITDA > delay(debt_st/EBITDA, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/EBITDA > delay(debt_st/EBITDA, 126)) ? 1 : -1
# Simulating alpha (debt_st/employee > delay(debt_st/employee, 126)) ? 1 : -1
# Simulating alpha (debt_st/enterprise_value > delay(debt_st/enterprise_value, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/enterprise_value > delay(debt_st/enterprise_value, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/enterprise_value > delay(debt_st/enterprise_value, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/enterprise_value > delay(debt_st/enterprise_value, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/enterprise_value > delay(debt_st/enterprise_value, 126)) ? 1 : -1
# Simulating alpha (debt_st/eps > delay(debt_st/eps, 126)) ? 1 : -1
# Simulating alpha (debt_st/equity > delay(debt_st/equity, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/equity > delay(debt_st/equity, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/equity > delay(debt_st/equity, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/equity > delay(debt_st/equity, 126)) ? 1 : -1
# Simulating alpha (debt_st/goodwill > delay(debt_st/goodwill, 126)) ? 1 : -1
# Simulating alpha (debt_st/income > delay(debt_st/income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/income > delay(debt_st/income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/income > delay(debt_st/income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/income > delay(debt_st/income, 126)) ? 1 : -1
# Simulating alpha (debt_st/income_beforeextra > delay(debt_st/income_beforeextra, 126)) ? 1 : -1
# Simulating alpha (debt_st/income_tax > delay(debt_st/income_tax, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/income_tax > delay(debt_st/income_tax, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/income_tax > delay(debt_st/income_tax, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/income_tax > delay(debt_st/income_tax, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/income_tax > delay(debt_st/income_tax, 126)) ? 1 : -1
# Simulating alpha (debt_st/interest_expense > delay(debt_st/interest_expense, 126)) ? 1 : -1
# Simulating alpha (debt_st/inventory > delay(debt_st/inventory, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/inventory > delay(debt_st/inventory, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/inventory > delay(debt_st/inventory, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/inventory > delay(debt_st/inventory, 126)) ? 1 : -1
# Simulating alpha (debt_st/inventory_turnover > delay(debt_st/inventory_turnover, 126)) ? 1 : -1
# Simulating alpha (debt_st/invested_capital > delay(debt_st/invested_capital, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/invested_capital > delay(debt_st/invested_capital, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/invested_capital > delay(debt_st/invested_capital, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/invested_capital > delay(debt_st/invested_capital, 126)) ? 1 : -1
# Simulating alpha (debt_st/liabilities > delay(debt_st/liabilities, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/liabilities > delay(debt_st/liabilities, 126)) ? 1 : -1
# Exception occured while simulating alphas Expecting value: line 1 column 1 (char 0)
# Simulating alpha (debt_st/liabilities > delay(debt_st/liabilities, 126)) ? 1 : -1
# Simulating alpha (debt_st/liabilities_curr > delay(debt_st/liabilities_curr, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/liabilities_curr > delay(debt_st/liabilities_curr, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/liabilities_curr > delay(debt_st/liabilities_curr, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/liabilities_curr > delay(debt_st/liabilities_curr, 126)) ? 1 : -1
# Simulating alpha (debt_st/operating_expense > delay(debt_st/operating_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/operating_expense > delay(debt_st/operating_expense, 126)) ? 1 : -1
# Simulating alpha (debt_st/operating_income > delay(debt_st/operating_income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/operating_income > delay(debt_st/operating_income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/operating_income > delay(debt_st/operating_income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/operating_income > delay(debt_st/operating_income, 126)) ? 1 : -1
# Simulating alpha (debt_st/pretax_income > delay(debt_st/pretax_income, 126)) ? 1 : -1
# Simulating alpha (debt_st/rd_expense > delay(debt_st/rd_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/rd_expense > delay(debt_st/rd_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/rd_expense > delay(debt_st/rd_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/rd_expense > delay(debt_st/rd_expense, 126)) ? 1 : -1
# Simulating alpha (debt_st/receivable > delay(debt_st/receivable, 126)) ? 1 : -1
# Simulating alpha (debt_st/retained_earnings > delay(debt_st/retained_earnings, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/retained_earnings > delay(debt_st/retained_earnings, 126)) ? 1 : -1
# Exception occured while simulating alphas Expecting value: line 1 column 1 (char 0)
# Simulating alpha (debt_st/retained_earnings > delay(debt_st/retained_earnings, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/retained_earnings > delay(debt_st/retained_earnings, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/retained_earnings > delay(debt_st/retained_earnings, 126)) ? 1 : -1
# Simulating alpha (debt_st/return_assets > delay(debt_st/return_assets, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/return_assets > delay(debt_st/return_assets, 126)) ? 1 : -1
# Simulating alpha (debt_st/return_equity > delay(debt_st/return_equity, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/return_equity > delay(debt_st/return_equity, 126)) ? 1 : -1
# Simulating alpha (debt_st/revenue > delay(debt_st/revenue, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/revenue > delay(debt_st/revenue, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/revenue > delay(debt_st/revenue, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/revenue > delay(debt_st/revenue, 126)) ? 1 : -1
# Simulating alpha (debt_st/sales > delay(debt_st/sales, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/sales > delay(debt_st/sales, 126)) ? 1 : -1
# Simulating alpha (debt_st/sales_growth > delay(debt_st/sales_growth, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/sales_growth > delay(debt_st/sales_growth, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/sales_growth > delay(debt_st/sales_growth, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/sales_growth > delay(debt_st/sales_growth, 126)) ? 1 : -1
# Simulating alpha (debt_st/sales_ps > delay(debt_st/sales_ps, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/sales_ps > delay(debt_st/sales_ps, 126)) ? 1 : -1
# Simulating alpha (debt_st/SGA_expense > delay(debt_st/SGA_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/SGA_expense > delay(debt_st/SGA_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/SGA_expense > delay(debt_st/SGA_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/SGA_expense > delay(debt_st/SGA_expense, 126)) ? 1 : -1
# Simulating alpha (debt_st/working_capital > delay(debt_st/working_capital, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (debt_st/working_capital > delay(debt_st/working_capital, 126)) ? 1 : -1
# Simulating alpha (depre_amort/EBIT > delay(depre_amort/EBIT, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/EBIT > delay(depre_amort/EBIT, 126)) ? 1 : -1
# Exception occured while simulating alphas Expecting value: line 1 column 1 (char 0)
# Simulating alpha (depre_amort/EBIT > delay(depre_amort/EBIT, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/EBIT > delay(depre_amort/EBIT, 126)) ? 1 : -1
# Simulating alpha (depre_amort/EBITDA > delay(depre_amort/EBITDA, 126)) ? 1 : -1
# Simulating alpha (depre_amort/employee > delay(depre_amort/employee, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/employee > delay(depre_amort/employee, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/employee > delay(depre_amort/employee, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/employee > delay(depre_amort/employee, 126)) ? 1 : -1
# Simulating alpha (depre_amort/enterprise_value > delay(depre_amort/enterprise_value, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/enterprise_value > delay(depre_amort/enterprise_value, 126)) ? 1 : -1
# Simulating alpha (depre_amort/eps > delay(depre_amort/eps, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/eps > delay(depre_amort/eps, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/eps > delay(depre_amort/eps, 126)) ? 1 : -1
# Simulating alpha (depre_amort/equity > delay(depre_amort/equity, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/equity > delay(depre_amort/equity, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/equity > delay(depre_amort/equity, 126)) ? 1 : -1
# Simulating alpha (depre_amort/goodwill > delay(depre_amort/goodwill, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/goodwill > delay(depre_amort/goodwill, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/goodwill > delay(depre_amort/goodwill, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/goodwill > delay(depre_amort/goodwill, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/goodwill > delay(depre_amort/goodwill, 126)) ? 1 : -1
# Simulating alpha (depre_amort/income > delay(depre_amort/income, 126)) ? 1 : -1
# Exception occured while simulating alphas Expecting value: line 1 column 1 (char 0)
# Simulating alpha (depre_amort/income > delay(depre_amort/income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/income > delay(depre_amort/income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/income > delay(depre_amort/income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/income > delay(depre_amort/income, 126)) ? 1 : -1
# Simulating alpha (depre_amort/income_beforeextra > delay(depre_amort/income_beforeextra, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/income_beforeextra > delay(depre_amort/income_beforeextra, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/income_beforeextra > delay(depre_amort/income_beforeextra, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/income_beforeextra > delay(depre_amort/income_beforeextra, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/income_beforeextra > delay(depre_amort/income_beforeextra, 126)) ? 1 : -1
# Simulating alpha (depre_amort/income_tax > delay(depre_amort/income_tax, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/income_tax > delay(depre_amort/income_tax, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/income_tax > delay(depre_amort/income_tax, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/income_tax > delay(depre_amort/income_tax, 126)) ? 1 : -1
# Simulating alpha (depre_amort/interest_expense > delay(depre_amort/interest_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/interest_expense > delay(depre_amort/interest_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/interest_expense > delay(depre_amort/interest_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/interest_expense > delay(depre_amort/interest_expense, 126)) ? 1 : -1
# Exception occured while simulating alphas Expecting value: line 1 column 1 (char 0)
# Simulating alpha (depre_amort/interest_expense > delay(depre_amort/interest_expense, 126)) ? 1 : -1
# Simulating alpha (depre_amort/inventory > delay(depre_amort/inventory, 126)) ? 1 : -1
# Simulating alpha (depre_amort/inventory_turnover > delay(depre_amort/inventory_turnover, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/inventory_turnover > delay(depre_amort/inventory_turnover, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/inventory_turnover > delay(depre_amort/inventory_turnover, 126)) ? 1 : -1
# Simulating alpha (depre_amort/invested_capital > delay(depre_amort/invested_capital, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/invested_capital > delay(depre_amort/invested_capital, 126)) ? 1 : -1
# Simulating alpha (depre_amort/liabilities > delay(depre_amort/liabilities, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/liabilities > delay(depre_amort/liabilities, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/liabilities > delay(depre_amort/liabilities, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/liabilities > delay(depre_amort/liabilities, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/liabilities > delay(depre_amort/liabilities, 126)) ? 1 : -1
# Simulating alpha (depre_amort/liabilities_curr > delay(depre_amort/liabilities_curr, 126)) ? 1 : -1
# Simulating alpha (depre_amort/operating_expense > delay(depre_amort/operating_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/operating_expense > delay(depre_amort/operating_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/operating_expense > delay(depre_amort/operating_expense, 126)) ? 1 : -1
# Simulating alpha (depre_amort/operating_income > delay(depre_amort/operating_income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/operating_income > delay(depre_amort/operating_income, 126)) ? 1 : -1
# Simulating alpha (depre_amort/pretax_income > delay(depre_amort/pretax_income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/pretax_income > delay(depre_amort/pretax_income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/pretax_income > delay(depre_amort/pretax_income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/pretax_income > delay(depre_amort/pretax_income, 126)) ? 1 : -1
# Simulating alpha (depre_amort/rd_expense > delay(depre_amort/rd_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/rd_expense > delay(depre_amort/rd_expense, 126)) ? 1 : -1
# Simulating alpha (depre_amort/receivable > delay(depre_amort/receivable, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/receivable > delay(depre_amort/receivable, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/receivable > delay(depre_amort/receivable, 126)) ? 1 : -1
# Simulating alpha (depre_amort/retained_earnings > delay(depre_amort/retained_earnings, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/retained_earnings > delay(depre_amort/retained_earnings, 126)) ? 1 : -1
# Simulating alpha (depre_amort/return_assets > delay(depre_amort/return_assets, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/return_assets > delay(depre_amort/return_assets, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/return_assets > delay(depre_amort/return_assets, 126)) ? 1 : -1
# Function simulating alphas finished
#
#
# Function parsing alphas started
# Parsing alpha (current_ratio/sales_ps > delay(current_ratio/sales_ps, 126)) ? 1 : -1
# Parsing alpha (debt/operating_income > delay(debt/operating_income, 126)) ? 1 : -1
# Parsing alpha (debt/pretax_income > delay(debt/pretax_income, 126)) ? 1 : -1
# Parsing alpha (debt/rd_expense > delay(debt/rd_expense, 126)) ? 1 : -1
# Parsing alpha (debt/receivable > delay(debt/receivable, 126)) ? 1 : -1
# Parsing alpha (debt/retained_earnings > delay(debt/retained_earnings, 126)) ? 1 : -1
# Local exception occured Expecting value: line 1 column 1 (char 0)
# Parsing alpha (debt/retained_earnings > delay(debt/retained_earnings, 126)) ? 1 : -1
# Parsing alpha (debt/return_assets > delay(debt/return_assets, 126)) ? 1 : -1
# Local exception occured Expecting value: line 1 column 1 (char 0)
# Parsing alpha (debt/return_assets > delay(debt/return_assets, 126)) ? 1 : -1
# Not proceeded case <html>
# <head><title>502 Bad Gateway</title></head>
# <body bgcolor="white">
# <center><h1>502 Bad Gateway</h1></center>
# <hr><center>nginx/1.14.0</center>
# </body>
# </html>
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
#
# Parsing alpha (debt/return_equity > delay(debt/return_equity, 126)) ? 1 : -1
# Parsing alpha (debt/revenue > delay(debt/revenue, 126)) ? 1 : -1
# Parsing alpha (debt/sales > delay(debt/sales, 126)) ? 1 : -1
# Not proceeded case <html>
# <head><title>502 Bad Gateway</title></head>
# <body bgcolor="white">
# <center><h1>502 Bad Gateway</h1></center>
# <hr><center>nginx/1.14.0</center>
# </body>
# </html>
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
#
# Parsing alpha (debt/sales_growth > delay(debt/sales_growth, 126)) ? 1 : -1
# Not proceeded case <html>
# <head><title>502 Bad Gateway</title></head>
# <body bgcolor="white">
# <center><h1>502 Bad Gateway</h1></center>
# <hr><center>nginx/1.14.0</center>
# </body>
# </html>
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
#
# Parsing alpha (debt/sales_ps > delay(debt/sales_ps, 126)) ? 1 : -1
# Local exception occured Expecting value: line 1 column 1 (char 0)
# Parsing alpha (debt/sales_ps > delay(debt/sales_ps, 126)) ? 1 : -1
# Parsing alpha (debt/SGA_expense > delay(debt/SGA_expense, 126)) ? 1 : -1
# Parsing alpha (debt/working_capital > delay(debt/working_capital, 126)) ? 1 : -1
# Parsing alpha (debt_lt/debt_st > delay(debt_lt/debt_st, 126)) ? 1 : -1
# Parsing alpha (debt_lt/depre_amort > delay(debt_lt/depre_amort, 126)) ? 1 : -1
# Parsing alpha (debt_lt/EBIT > delay(debt_lt/EBIT, 126)) ? 1 : -1
# Error occured while simulation (debt_lt/EBIT > delay(debt_lt/EBIT, 126)) ? 1 : -1, check data or something else
# Parsing alpha (debt_lt/EBITDA > delay(debt_lt/EBITDA, 126)) ? 1 : -1
# Parsing alpha (debt_lt/employee > delay(debt_lt/employee, 126)) ? 1 : -1
# Parsing alpha (debt_lt/enterprise_value > delay(debt_lt/enterprise_value, 126)) ? 1 : -1
# Parsing alpha (debt_lt/eps > delay(debt_lt/eps, 126)) ? 1 : -1
# Parsing alpha (debt_lt/equity > delay(debt_lt/equity, 126)) ? 1 : -1
# Parsing alpha (debt_lt/goodwill > delay(debt_lt/goodwill, 126)) ? 1 : -1
# Parsing alpha (debt_lt/income > delay(debt_lt/income, 126)) ? 1 : -1
# Parsing alpha (debt_lt/income_beforeextra > delay(debt_lt/income_beforeextra, 126)) ? 1 : -1
# Parsing alpha (debt_lt/income_tax > delay(debt_lt/income_tax, 126)) ? 1 : -1
# Parsing alpha (debt_lt/interest_expense > delay(debt_lt/interest_expense, 126)) ? 1 : -1
# Parsing alpha (debt_lt/inventory > delay(debt_lt/inventory, 126)) ? 1 : -1
# Parsing alpha (debt_lt/inventory_turnover > delay(debt_lt/inventory_turnover, 126)) ? 1 : -1
# Parsing alpha (debt_lt/invested_capital > delay(debt_lt/invested_capital, 126)) ? 1 : -1
# Not proceeded case <html>
# <head><title>502 Bad Gateway</title></head>
# <body bgcolor="white">
# <center><h1>502 Bad Gateway</h1></center>
# <hr><center>nginx/1.14.0</center>
# </body>
# </html>
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
#
# Parsing alpha (debt_lt/liabilities > delay(debt_lt/liabilities, 126)) ? 1 : -1
# Parsing alpha (debt_lt/liabilities_curr > delay(debt_lt/liabilities_curr, 126)) ? 1 : -1
# Parsing alpha (debt_lt/operating_expense > delay(debt_lt/operating_expense, 126)) ? 1 : -1
# Parsing alpha (debt_lt/operating_income > delay(debt_lt/operating_income, 126)) ? 1 : -1
# Parsing alpha (debt_lt/pretax_income > delay(debt_lt/pretax_income, 126)) ? 1 : -1
# Parsing alpha (debt_lt/rd_expense > delay(debt_lt/rd_expense, 126)) ? 1 : -1
# Parsing alpha (debt_lt/receivable > delay(debt_lt/receivable, 126)) ? 1 : -1
# Parsing alpha (debt_lt/retained_earnings > delay(debt_lt/retained_earnings, 126)) ? 1 : -1
# Parsing alpha (debt_lt/return_assets > delay(debt_lt/return_assets, 126)) ? 1 : -1
# Parsing alpha (debt_lt/return_equity > delay(debt_lt/return_equity, 126)) ? 1 : -1
# Parsing alpha (debt_lt/revenue > delay(debt_lt/revenue, 126)) ? 1 : -1
# Parsing alpha (debt_lt/sales > delay(debt_lt/sales, 126)) ? 1 : -1
# Parsing alpha (debt_lt/sales_growth > delay(debt_lt/sales_growth, 126)) ? 1 : -1
# Parsing alpha (debt_lt/sales_ps > delay(debt_lt/sales_ps, 126)) ? 1 : -1
# Parsing alpha (debt_lt/SGA_expense > delay(debt_lt/SGA_expense, 126)) ? 1 : -1
# Parsing alpha (debt_lt/working_capital > delay(debt_lt/working_capital, 126)) ? 1 : -1
# Parsing alpha (debt_st/depre_amort > delay(debt_st/depre_amort, 126)) ? 1 : -1
# Parsing alpha (debt_st/EBIT > delay(debt_st/EBIT, 126)) ? 1 : -1
# Parsing alpha (debt_st/EBITDA > delay(debt_st/EBITDA, 126)) ? 1 : -1
# Parsing alpha (debt_st/employee > delay(debt_st/employee, 126)) ? 1 : -1
# Parsing alpha (debt_st/enterprise_value > delay(debt_st/enterprise_value, 126)) ? 1 : -1
# Parsing alpha (debt_st/eps > delay(debt_st/eps, 126)) ? 1 : -1
# Parsing alpha (debt_st/equity > delay(debt_st/equity, 126)) ? 1 : -1
# Parsing alpha (debt_st/goodwill > delay(debt_st/goodwill, 126)) ? 1 : -1
# Parsing alpha (debt_st/income > delay(debt_st/income, 126)) ? 1 : -1
# Parsing alpha (debt_st/income_beforeextra > delay(debt_st/income_beforeextra, 126)) ? 1 : -1
# Parsing alpha (debt_st/income_tax > delay(debt_st/income_tax, 126)) ? 1 : -1
# Parsing alpha (debt_st/interest_expense > delay(debt_st/interest_expense, 126)) ? 1 : -1
# Local exception occured Expecting value: line 1 column 1 (char 0)
# Parsing alpha (debt_st/interest_expense > delay(debt_st/interest_expense, 126)) ? 1 : -1
# Parsing alpha (debt_st/inventory > delay(debt_st/inventory, 126)) ? 1 : -1
# Parsing alpha (debt_st/inventory_turnover > delay(debt_st/inventory_turnover, 126)) ? 1 : -1
# Parsing alpha (debt_st/invested_capital > delay(debt_st/invested_capital, 126)) ? 1 : -1
# Not proceeded case <html>
# <head><title>502 Bad Gateway</title></head>
# <body bgcolor="white">
# <center><h1>502 Bad Gateway</h1></center>
# <hr><center>nginx/1.14.0</center>
# </body>
# </html>
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
#
# Parsing alpha (debt_st/liabilities > delay(debt_st/liabilities, 126)) ? 1 : -1
# Parsing alpha (debt_st/liabilities_curr > delay(debt_st/liabilities_curr, 126)) ? 1 : -1
# Parsing alpha (debt_st/operating_expense > delay(debt_st/operating_expense, 126)) ? 1 : -1
# Parsing alpha (debt_st/operating_income > delay(debt_st/operating_income, 126)) ? 1 : -1
# Parsing alpha (debt_st/pretax_income > delay(debt_st/pretax_income, 126)) ? 1 : -1
# Parsing alpha (debt_st/rd_expense > delay(debt_st/rd_expense, 126)) ? 1 : -1
# Parsing alpha (debt_st/receivable > delay(debt_st/receivable, 126)) ? 1 : -1
# Parsing alpha (debt_st/retained_earnings > delay(debt_st/retained_earnings, 126)) ? 1 : -1
# Parsing alpha (debt_st/return_assets > delay(debt_st/return_assets, 126)) ? 1 : -1
# Parsing alpha (debt_st/return_equity > delay(debt_st/return_equity, 126)) ? 1 : -1
# Parsing alpha (debt_st/revenue > delay(debt_st/revenue, 126)) ? 1 : -1
# Parsing alpha (debt_st/sales > delay(debt_st/sales, 126)) ? 1 : -1
# Parsing alpha (debt_st/sales_growth > delay(debt_st/sales_growth, 126)) ? 1 : -1
# Parsing alpha (debt_st/sales_ps > delay(debt_st/sales_ps, 126)) ? 1 : -1
# Parsing alpha (debt_st/SGA_expense > delay(debt_st/SGA_expense, 126)) ? 1 : -1
# Parsing alpha (debt_st/working_capital > delay(debt_st/working_capital, 126)) ? 1 : -1
# Parsing alpha (depre_amort/EBIT > delay(depre_amort/EBIT, 126)) ? 1 : -1
# Parsing alpha (depre_amort/EBITDA > delay(depre_amort/EBITDA, 126)) ? 1 : -1
# Not proceeded case <html>
# <head><title>502 Bad Gateway</title></head>
# <body bgcolor="white">
# <center><h1>502 Bad Gateway</h1></center>
# <hr><center>nginx/1.14.0</center>
# </body>
# </html>
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
#
# Parsing alpha (depre_amort/employee > delay(depre_amort/employee, 126)) ? 1 : -1
# Parsing alpha (depre_amort/enterprise_value > delay(depre_amort/enterprise_value, 126)) ? 1 : -1
# Parsing alpha (depre_amort/eps > delay(depre_amort/eps, 126)) ? 1 : -1
# Not proceeded case <html>
# <head><title>502 Bad Gateway</title></head>
# <body bgcolor="white">
# <center><h1>502 Bad Gateway</h1></center>
# <hr><center>nginx/1.14.0</center>
# </body>
# </html>
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
#
# Parsing alpha (depre_amort/equity > delay(depre_amort/equity, 126)) ? 1 : -1
# Parsing alpha (depre_amort/goodwill > delay(depre_amort/goodwill, 126)) ? 1 : -1
# Local exception occured Expecting value: line 1 column 1 (char 0)
# Parsing alpha (depre_amort/goodwill > delay(depre_amort/goodwill, 126)) ? 1 : -1
# Parsing alpha (depre_amort/income > delay(depre_amort/income, 126)) ? 1 : -1
# Parsing alpha (depre_amort/income_beforeextra > delay(depre_amort/income_beforeextra, 126)) ? 1 : -1
# Parsing alpha (depre_amort/income_tax > delay(depre_amort/income_tax, 126)) ? 1 : -1
# Parsing alpha (depre_amort/interest_expense > delay(depre_amort/interest_expense, 126)) ? 1 : -1
# Parsing alpha (depre_amort/inventory > delay(depre_amort/inventory, 126)) ? 1 : -1
# Parsing alpha (depre_amort/inventory_turnover > delay(depre_amort/inventory_turnover, 126)) ? 1 : -1
# Parsing alpha (depre_amort/invested_capital > delay(depre_amort/invested_capital, 126)) ? 1 : -1
# Not proceeded case <html>
# <head><title>502 Bad Gateway</title></head>
# <body bgcolor="white">
# <center><h1>502 Bad Gateway</h1></center>
# <hr><center>nginx/1.14.0</center>
# </body>
# </html>
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
#
# Parsing alpha (depre_amort/liabilities > delay(depre_amort/liabilities, 126)) ? 1 : -1
# Not proceeded case <html>
# <head><title>502 Bad Gateway</title></head>
# <body bgcolor="white">
# <center><h1>502 Bad Gateway</h1></center>
# <hr><center>nginx/1.14.0</center>
# </body>
# </html>
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
#
# Parsing alpha (depre_amort/liabilities_curr > delay(depre_amort/liabilities_curr, 126)) ? 1 : -1
# Parsing alpha (depre_amort/operating_expense > delay(depre_amort/operating_expense, 126)) ? 1 : -1
# Parsing alpha (depre_amort/operating_income > delay(depre_amort/operating_income, 126)) ? 1 : -1
# Parsing alpha (depre_amort/pretax_income > delay(depre_amort/pretax_income, 126)) ? 1 : -1
# Parsing alpha (depre_amort/rd_expense > delay(depre_amort/rd_expense, 126)) ? 1 : -1
# Local exception occured Expecting value: line 1 column 1 (char 0)
# Parsing alpha (depre_amort/rd_expense > delay(depre_amort/rd_expense, 126)) ? 1 : -1
# Parsing alpha (depre_amort/receivable > delay(depre_amort/receivable, 126)) ? 1 : -1
# Parsing alpha (depre_amort/retained_earnings > delay(depre_amort/retained_earnings, 126)) ? 1 : -1
# Local exception occured Expecting value: line 1 column 1 (char 0)
# Parsing alpha (depre_amort/retained_earnings > delay(depre_amort/retained_earnings, 126)) ? 1 : -1
# Parsing alpha (depre_amort/return_assets > delay(depre_amort/return_assets, 126)) ? 1 : -1
# Function parsing alphas finished
#
#
# Function parse submissions started
# Parsing submission of alpha with index 196748386
# {'error': 'Unknown Request Id', 'result': None, 'status': False}
# Alpha too old for submission
# Function parse submissions finished
# Function parsing alphas started
# Parsing alpha (debt/return_assets > delay(debt/return_assets, 126)) ? 1 : -1
# Parsing alpha (debt/sales > delay(debt/sales, 126)) ? 1 : -1
# Parsing alpha (debt/sales_growth > delay(debt/sales_growth, 126)) ? 1 : -1
# Parsing alpha (debt_lt/EBIT > delay(debt_lt/EBIT, 126)) ? 1 : -1
# Error occured while simulation (debt_lt/EBIT > delay(debt_lt/EBIT, 126)) ? 1 : -1, check data or something else
# Parsing alpha (debt_lt/invested_capital > delay(debt_lt/invested_capital, 126)) ? 1 : -1
# Parsing alpha (debt_st/invested_capital > delay(debt_st/invested_capital, 126)) ? 1 : -1
# Parsing alpha (depre_amort/EBITDA > delay(depre_amort/EBITDA, 126)) ? 1 : -1
# Parsing alpha (depre_amort/eps > delay(depre_amort/eps, 126)) ? 1 : -1
# Not proceeded case <html>
# <head><title>502 Bad Gateway</title></head>
# <body bgcolor="white">
# <center><h1>502 Bad Gateway</h1></center>
# <hr><center>nginx/1.14.0</center>
# </body>
# </html>
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
# <!-- a padding to disable MSIE and Chrome friendly error page -->
#
# Parsing alpha (depre_amort/invested_capital > delay(depre_amort/invested_capital, 126)) ? 1 : -1
# Parsing alpha (depre_amort/liabilities > delay(depre_amort/liabilities, 126)) ? 1 : -1
# Function parsing alphas finished
#
#
# Function simulating alphas started
# Simulating alpha (debt_lt/EBIT > delay(debt_lt/EBIT, 126)) ? 1 : -1
# Simulating alpha (depre_amort/eps > delay(depre_amort/eps, 126)) ? 1 : -1
# Simulating alpha (depre_amort/return_equity > delay(depre_amort/return_equity, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/return_equity > delay(depre_amort/return_equity, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/return_equity > delay(depre_amort/return_equity, 126)) ? 1 : -1
# Simulating alpha (depre_amort/revenue > delay(depre_amort/revenue, 126)) ? 1 : -1
# Simulating alpha (depre_amort/sales > delay(depre_amort/sales, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/sales > delay(depre_amort/sales, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/sales > delay(depre_amort/sales, 126)) ? 1 : -1
# Simulating alpha (depre_amort/sales_growth > delay(depre_amort/sales_growth, 126)) ? 1 : -1
# Simulating alpha (depre_amort/sales_ps > delay(depre_amort/sales_ps, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/sales_ps > delay(depre_amort/sales_ps, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/sales_ps > delay(depre_amort/sales_ps, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/sales_ps > delay(depre_amort/sales_ps, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/sales_ps > delay(depre_amort/sales_ps, 126)) ? 1 : -1
# Simulating alpha (depre_amort/SGA_expense > delay(depre_amort/SGA_expense, 126)) ? 1 : -1
# Simulating alpha (depre_amort/working_capital > delay(depre_amort/working_capital, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/working_capital > delay(depre_amort/working_capital, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/working_capital > delay(depre_amort/working_capital, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (depre_amort/working_capital > delay(depre_amort/working_capital, 126)) ? 1 : -1
# Simulating alpha (EBIT/EBITDA > delay(EBIT/EBITDA, 126)) ? 1 : -1
# Simulating alpha (EBIT/employee > delay(EBIT/employee, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (EBIT/employee > delay(EBIT/employee, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (EBIT/employee > delay(EBIT/employee, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (EBIT/employee > delay(EBIT/employee, 126)) ? 1 : -1
# ...
# Too many alphas simulating
# Simulating alpha (equity/liabilities_curr > delay(equity/liabilities_curr, 126)) ? 1 : -1
# Simulating alpha (equity/operating_expense > delay(equity/operating_expense, 126)) ? 1 : -1
# Exception occured while simulating alphas Expecting value: line 1 column 1 (char 0)
# Simulating alpha (equity/operating_expense > delay(equity/operating_expense, 126)) ? 1 : -1
# Simulating alpha (equity/operating_income > delay(equity/operating_income, 126)) ? 1 : -1
# Simulating alpha (equity/pretax_income > delay(equity/pretax_income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (equity/pretax_income > delay(equity/pretax_income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (equity/pretax_income > delay(equity/pretax_income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (equity/pretax_income > delay(equity/pretax_income, 126)) ? 1 : -1
# Simulating alpha (equity/rd_expense > delay(equity/rd_expense, 126)) ? 1 : -1
# Simulating alpha (equity/receivable > delay(equity/receivable, 126)) ? 1 : -1
# Exception occured while simulating alphas Expecting value: line 1 column 1 (char 0)
# Simulating alpha (equity/receivable > delay(equity/receivable, 126)) ? 1 : -1
# Simulating alpha (equity/retained_earnings > delay(equity/retained_earnings, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (equity/retained_earnings > delay(equity/retained_earnings, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (equity/retained_earnings > delay(equity/retained_earnings, 126)) ? 1 : -1
# Simulating alpha (equity/return_assets > delay(equity/return_assets, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (equity/return_assets > delay(equity/return_assets, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (equity/return_assets > delay(equity/return_assets, 126)) ? 1 : -1
# Simulating alpha (equity/return_equity > delay(equity/return_equity, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (equity/return_equity > delay(equity/return_equity, 126)) ? 1 : -1
# Simulating alpha (equity/revenue > delay(equity/revenue, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (equity/revenue > delay(equity/revenue, 126)) ? 1 : -1
# Simulating alpha (equity/sales > delay(equity/sales, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (equity/sales > delay(equity/sales, 126)) ? 1 : -1
# Simulating alpha (equity/sales_growth > delay(equity/sales_growth, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (equity/sales_growth > delay(equity/sales_growth, 126)) ? 1 : -1
# Simulating alpha (equity/sales_ps > delay(equity/sales_ps, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (equity/sales_ps > delay(equity/sales_ps, 126)) ? 1 : -1
# Simulating alpha (equity/SGA_expense > delay(equity/SGA_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (equity/SGA_expense > delay(equity/SGA_expense, 126)) ? 1 : -1
# Simulating alpha (equity/working_capital > delay(equity/working_capital, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (equity/working_capital > delay(equity/working_capital, 126)) ? 1 : -1
# Exception occured while simulating alphas Expecting value: line 1 column 1 (char 0)
# Simulating alpha (equity/working_capital > delay(equity/working_capital, 126)) ? 1 : -1
# Simulating alpha (goodwill/income > delay(goodwill/income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (goodwill/income > delay(goodwill/income, 126)) ? 1 : -1
# Simulating alpha (goodwill/income_beforeextra > delay(goodwill/income_beforeextra, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (goodwill/income_beforeextra > delay(goodwill/income_beforeextra, 126)) ? 1 : -1
# Simulating alpha (goodwill/income_tax > delay(goodwill/income_tax, 126)) ? 1 : -1
# Simulating alpha (goodwill/interest_expense > delay(goodwill/interest_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (goodwill/interest_expense > delay(goodwill/interest_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (goodwill/interest_expense > delay(goodwill/interest_expense, 126)) ? 1 : -1
# Simulating alpha (goodwill/inventory > delay(goodwill/inventory, 126)) ? 1 : -1
# Simulating alpha (goodwill/inventory_turnover > delay(goodwill/inventory_turnover, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (goodwill/inventory_turnover > delay(goodwill/inventory_turnover, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (goodwill/inventory_turnover > delay(goodwill/inventory_turnover, 126)) ? 1 : -1
# Simulating alpha (goodwill/invested_capital > delay(goodwill/invested_capital, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (goodwill/invested_capital > delay(goodwill/invested_capital, 126)) ? 1 : -1
# Simulating alpha (goodwill/liabilities > delay(goodwill/liabilities, 126)) ? 1 : -1
# Exception occured while simulating alphas Expecting value: line 1 column 1 (char 0)
# Simulating alpha (goodwill/liabilities > delay(goodwill/liabilities, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (goodwill/liabilities > delay(goodwill/liabilities, 126)) ? 1 : -1
# Simulating alpha (goodwill/liabilities_curr > delay(goodwill/liabilities_curr, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (goodwill/liabilities_curr > delay(goodwill/liabilities_curr, 126)) ? 1 : -1
# Simulating alpha (goodwill/operating_expense > delay(goodwill/operating_expense, 126)) ? 1 : -1
# Simulating alpha (goodwill/operating_income > delay(goodwill/operating_income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (goodwill/operating_income > delay(goodwill/operating_income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (goodwill/operating_income > delay(goodwill/operating_income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (goodwill/operating_income > delay(goodwill/operating_income, 126)) ? 1 : -1
# Simulating alpha (goodwill/pretax_income > delay(goodwill/pretax_income, 126)) ? 1 : -1
# Simulating alpha (goodwill/rd_expense > delay(goodwill/rd_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (goodwill/rd_expense > delay(goodwill/rd_expense, 126)) ? 1 : -1
# Simulating alpha (goodwill/receivable > delay(goodwill/receivable, 126)) ? 1 : -1
# Simulating alpha (goodwill/retained_earnings > delay(goodwill/retained_earnings, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (goodwill/retained_earnings > delay(goodwill/retained_earnings, 126)) ? 1 : -1
# Simulating alpha (goodwill/return_assets > delay(goodwill/return_assets, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (goodwill/return_assets > delay(goodwill/return_assets, 126)) ? 1 : -1
# Simulating alpha (goodwill/return_equity > delay(goodwill/return_equity, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (goodwill/return_equity > delay(goodwill/return_equity, 126)) ? 1 : -1
# Simulating alpha (goodwill/revenue > delay(goodwill/revenue, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (goodwill/revenue > delay(goodwill/revenue, 126)) ? 1 : -1
# Simulating alpha (goodwill/sales > delay(goodwill/sales, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (goodwill/sales > delay(goodwill/sales, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (goodwill/sales > delay(goodwill/sales, 126)) ? 1 : -1
# Simulating alpha (goodwill/sales_growth > delay(goodwill/sales_growth, 126)) ? 1 : -1
# Exception occured while simulating alphas Expecting value: line 1 column 1 (char 0)
# Simulating alpha (goodwill/sales_growth > delay(goodwill/sales_growth, 126)) ? 1 : -1
# Simulating alpha (goodwill/sales_ps > delay(goodwill/sales_ps, 126)) ? 1 : -1
# Simulating alpha (goodwill/SGA_expense > delay(goodwill/SGA_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (goodwill/SGA_expense > delay(goodwill/SGA_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (goodwill/SGA_expense > delay(goodwill/SGA_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (goodwill/SGA_expense > delay(goodwill/SGA_expense, 126)) ? 1 : -1
# Simulating alpha (goodwill/working_capital > delay(goodwill/working_capital, 126)) ? 1 : -1
# Exception occured while simulating alphas Expecting value: line 1 column 1 (char 0)
# Simulating alpha (goodwill/working_capital > delay(goodwill/working_capital, 126)) ? 1 : -1
# Simulating alpha (income/income_beforeextra > delay(income/income_beforeextra, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income/income_beforeextra > delay(income/income_beforeextra, 126)) ? 1 : -1
# Simulating alpha (income/income_tax > delay(income/income_tax, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income/income_tax > delay(income/income_tax, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income/income_tax > delay(income/income_tax, 126)) ? 1 : -1
# Simulating alpha (income/interest_expense > delay(income/interest_expense, 126)) ? 1 : -1
# Simulating alpha (income/inventory > delay(income/inventory, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income/inventory > delay(income/inventory, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income/inventory > delay(income/inventory, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income/inventory > delay(income/inventory, 126)) ? 1 : -1
# Simulating alpha (income/inventory_turnover > delay(income/inventory_turnover, 126)) ? 1 : -1
# Simulating alpha (income/invested_capital > delay(income/invested_capital, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income/invested_capital > delay(income/invested_capital, 126)) ? 1 : -1
# Simulating alpha (income/liabilities > delay(income/liabilities, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income/liabilities > delay(income/liabilities, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income/liabilities > delay(income/liabilities, 126)) ? 1 : -1
# Simulating alpha (income/liabilities_curr > delay(income/liabilities_curr, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income/liabilities_curr > delay(income/liabilities_curr, 126)) ? 1 : -1
# Simulating alpha (income/operating_expense > delay(income/operating_expense, 126)) ? 1 : -1
# Simulating alpha (income/operating_income > delay(income/operating_income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income/operating_income > delay(income/operating_income, 126)) ? 1 : -1
# Simulating alpha (income/pretax_income > delay(income/pretax_income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income/pretax_income > delay(income/pretax_income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income/pretax_income > delay(income/pretax_income, 126)) ? 1 : -1
# Simulating alpha (income/rd_expense > delay(income/rd_expense, 126)) ? 1 : -1
# Simulating alpha (income/receivable > delay(income/receivable, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income/receivable > delay(income/receivable, 126)) ? 1 : -1
# Simulating alpha (income/retained_earnings > delay(income/retained_earnings, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income/retained_earnings > delay(income/retained_earnings, 126)) ? 1 : -1
# Simulating alpha (income/return_assets > delay(income/return_assets, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income/return_assets > delay(income/return_assets, 126)) ? 1 : -1
# Simulating alpha (income/return_equity > delay(income/return_equity, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income/return_equity > delay(income/return_equity, 126)) ? 1 : -1
# Simulating alpha (income/revenue > delay(income/revenue, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income/revenue > delay(income/revenue, 126)) ? 1 : -1
# Simulating alpha (income/sales > delay(income/sales, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income/sales > delay(income/sales, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income/sales > delay(income/sales, 126)) ? 1 : -1
# Simulating alpha (income/sales_growth > delay(income/sales_growth, 126)) ? 1 : -1
# Simulating alpha (income/sales_ps > delay(income/sales_ps, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income/sales_ps > delay(income/sales_ps, 126)) ? 1 : -1
# Simulating alpha (income/SGA_expense > delay(income/SGA_expense, 126)) ? 1 : -1
# Simulating alpha (income/working_capital > delay(income/working_capital, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income/working_capital > delay(income/working_capital, 126)) ? 1 : -1
# Simulating alpha (income_beforeextra/income_tax > delay(income_beforeextra/income_tax, 126)) ? 1 : -1
# Exception occured while simulating alphas Expecting value: line 1 column 1 (char 0)
# Simulating alpha (income_beforeextra/income_tax > delay(income_beforeextra/income_tax, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income_beforeextra/income_tax > delay(income_beforeextra/income_tax, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income_beforeextra/income_tax > delay(income_beforeextra/income_tax, 126)) ? 1 : -1
# Simulating alpha (income_beforeextra/interest_expense > delay(income_beforeextra/interest_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income_beforeextra/interest_expense > delay(income_beforeextra/interest_expense, 126)) ? 1 : -1
# Simulating alpha (income_beforeextra/inventory > delay(income_beforeextra/inventory, 126)) ? 1 : -1
# Simulating alpha (income_beforeextra/inventory_turnover > delay(income_beforeextra/inventory_turnover, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income_beforeextra/inventory_turnover > delay(income_beforeextra/inventory_turnover, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income_beforeextra/inventory_turnover > delay(income_beforeextra/inventory_turnover, 126)) ? 1 : -1
# Simulating alpha (income_beforeextra/invested_capital > delay(income_beforeextra/invested_capital, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income_beforeextra/invested_capital > delay(income_beforeextra/invested_capital, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income_beforeextra/invested_capital > delay(income_beforeextra/invested_capital, 126)) ? 1 : -1
# Exception occured while simulating alphas Expecting value: line 1 column 1 (char 0)
# Simulating alpha (income_beforeextra/invested_capital > delay(income_beforeextra/invested_capital, 126)) ? 1 : -1
# Simulating alpha (income_beforeextra/liabilities > delay(income_beforeextra/liabilities, 126)) ? 1 : -1
# Simulating alpha (income_beforeextra/liabilities_curr > delay(income_beforeextra/liabilities_curr, 126)) ? 1 : -1
# Simulating alpha (income_beforeextra/operating_expense > delay(income_beforeextra/operating_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income_beforeextra/operating_expense > delay(income_beforeextra/operating_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income_beforeextra/operating_expense > delay(income_beforeextra/operating_expense, 126)) ? 1 : -1
# Simulating alpha (income_beforeextra/operating_income > delay(income_beforeextra/operating_income, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income_beforeextra/operating_income > delay(income_beforeextra/operating_income, 126)) ? 1 : -1
# Simulating alpha (income_beforeextra/pretax_income > delay(income_beforeextra/pretax_income, 126)) ? 1 : -1
# Simulating alpha (income_beforeextra/rd_expense > delay(income_beforeextra/rd_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income_beforeextra/rd_expense > delay(income_beforeextra/rd_expense, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (income_beforeextra/rd_expense > delay(income_beforeextra/rd_expense, 126)) ? 1 : -1
# Simulating alpha (income_beforeextra/receivable > delay(income_beforeextra/receivable, 126)) ? 1 : -1
# Too many alphas simulating

# %%
for i in range(50):
    mode.simulate_base_pack(100)
# Out:
# Function simulating alphas started
# Simulating alpha rank(delta(assets/capex, 256))
# Simulating alpha rank(delta(assets/cash, 256))
# Simulating alpha rank(delta(assets/cashflow, 256))
# Simulating alpha rank(delta(assets/cashflow_dividends, 256))
# Simulating alpha rank(delta(assets/cashflow_fin, 256))
# Simulating alpha rank(delta(assets/cashflow_invst, 256))
# Simulating alpha rank(delta(assets/cashflow_op, 256))
# Simulating alpha rank(delta(assets/cogs, 256))
# Simulating alpha rank(delta(assets/current_ratio, 256))
# Simulating alpha rank(delta(assets/debt, 256))
# Simulating alpha rank(delta(assets/debt_lt, 256))
# Simulating alpha rank(delta(assets/debt_st, 256))
# Simulating alpha rank(delta(assets/depre_amort, 256))
# Simulating alpha rank(delta(assets/EBIT, 256))
# Simulating alpha rank(delta(assets/EBITDA, 256))
# Simulating alpha rank(delta(assets/employee, 256))
# Simulating alpha rank(delta(assets/enterprise_value, 256))
# Simulating alpha rank(delta(assets/eps, 256))
# Simulating alpha rank(delta(assets/equity, 256))
# Simulating alpha rank(delta(assets/goodwill, 256))
# Simulating alpha rank(delta(assets/income, 256))
# Simulating alpha rank(delta(assets/income_beforeextra, 256))
# Simulating alpha rank(delta(assets/income_tax, 256))
# Simulating alpha rank(delta(assets/interest_expense, 256))
# Simulating alpha rank(delta(assets/inventory, 256))
# Simulating alpha rank(delta(assets/inventory_turnover, 256))
# Simulating alpha rank(delta(assets/invested_capital, 256))
# Simulating alpha rank(delta(assets/liabilities, 256))
# Simulating alpha rank(delta(assets/liabilities_curr, 256))
# Simulating alpha rank(delta(assets/operating_expense, 256))
# Simulating alpha rank(delta(assets/operating_income, 256))
# Simulating alpha rank(delta(assets/pretax_income, 256))
# Simulating alpha rank(delta(assets/rd_expense, 256))
# Simulating alpha rank(delta(assets/receivable, 256))
# Simulating alpha rank(delta(assets/retained_earnings, 256))
# Simulating alpha rank(delta(assets/return_assets, 256))
# Simulating alpha rank(delta(assets/return_equity, 256))
# Simulating alpha rank(delta(assets/revenue, 256))
# Simulating alpha rank(delta(assets/sales, 256))
# Simulating alpha rank(delta(assets/sales_growth, 256))
# Simulating alpha rank(delta(assets/sales_ps, 256))
# Simulating alpha rank(delta(assets/SGA_expense, 256))
# Simulating alpha rank(delta(assets/working_capital, 256))
# Simulating alpha rank(delta(assets_curr/bookvalue_ps, 256))
# Simulating alpha rank(delta(assets_curr/capex, 256))
# Simulating alpha rank(delta(assets_curr/cash, 256))
# Simulating alpha rank(delta(assets_curr/cashflow, 256))
# Simulating alpha rank(delta(assets_curr/cashflow_dividends, 256))
# Simulating alpha rank(delta(assets_curr/cashflow_fin, 256))
# Simulating alpha rank(delta(assets_curr/cashflow_invst, 256))
# Simulating alpha rank(delta(assets_curr/cashflow_op, 256))
# Simulating alpha rank(delta(assets_curr/cogs, 256))
# Simulating alpha rank(delta(assets_curr/current_ratio, 256))
# Simulating alpha rank(delta(assets_curr/debt, 256))
# Simulating alpha rank(delta(assets_curr/debt_lt, 256))
# Simulating alpha rank(delta(assets_curr/debt_st, 256))
# Simulating alpha rank(delta(assets_curr/depre_amort, 256))
# Simulating alpha rank(delta(assets_curr/EBIT, 256))
# Simulating alpha rank(delta(assets_curr/EBITDA, 256))
# Simulating alpha rank(delta(assets_curr/employee, 256))
# Simulating alpha rank(delta(assets_curr/enterprise_value, 256))
# Simulating alpha rank(delta(assets_curr/eps, 256))
# Simulating alpha rank(delta(assets_curr/equity, 256))
# Simulating alpha rank(delta(assets_curr/goodwill, 256))
# Simulating alpha rank(delta(assets_curr/income, 256))
# Simulating alpha rank(delta(assets_curr/income_beforeextra, 256))
# Simulating alpha rank(delta(assets_curr/income_tax, 256))
# Simulating alpha rank(delta(assets_curr/interest_expense, 256))
# Simulating alpha rank(delta(assets_curr/inventory, 256))
# Simulating alpha rank(delta(assets_curr/inventory_turnover, 256))
# Simulating alpha rank(delta(assets_curr/invested_capital, 256))
# Simulating alpha rank(delta(assets_curr/liabilities, 256))
# Simulating alpha rank(delta(assets_curr/liabilities_curr, 256))
# Simulating alpha rank(delta(assets_curr/operating_expense, 256))
# Simulating alpha rank(delta(assets_curr/operating_income, 256))
# Simulating alpha rank(delta(assets_curr/pretax_income, 256))
# Simulating alpha rank(delta(assets_curr/rd_expense, 256))
# Simulating alpha rank(delta(assets_curr/receivable, 256))
# Simulating alpha rank(delta(assets_curr/retained_earnings, 256))
# Simulating alpha rank(delta(assets_curr/return_assets, 256))
# Simulating alpha rank(delta(assets_curr/return_equity, 256))
# Simulating alpha rank(delta(assets_curr/revenue, 256))
# Simulating alpha rank(delta(assets_curr/sales, 256))
# Simulating alpha rank(delta(assets_curr/sales_growth, 256))
# Simulating alpha rank(delta(assets_curr/sales_ps, 256))
# Simulating alpha rank(delta(assets_curr/SGA_expense, 256))
# Simulating alpha rank(delta(assets_curr/working_capital, 256))
# Simulating alpha rank(delta(bookvalue_ps/capex, 256))
# Simulating alpha rank(delta(bookvalue_ps/cash, 256))
# Simulating alpha rank(delta(bookvalue_ps/cashflow, 256))
# Simulating alpha rank(delta(bookvalue_ps/cashflow_dividends, 256))
# Simulating alpha rank(delta(bookvalue_ps/cashflow_fin, 256))
# Simulating alpha rank(delta(bookvalue_ps/cashflow_invst, 256))
# Simulating alpha rank(delta(bookvalue_ps/cashflow_op, 256))
# Simulating alpha rank(delta(bookvalue_ps/cogs, 256))
# Simulating alpha rank(delta(bookvalue_ps/current_ratio, 256))
# Simulating alpha rank(delta(bookvalue_ps/debt, 256))
# Simulating alpha rank(delta(bookvalue_ps/debt_lt, 256))
# Simulating alpha rank(delta(bookvalue_ps/debt_st, 256))
# Simulating alpha rank(delta(bookvalue_ps/depre_amort, 256))
# Function simulating alphas finished
#
#
# Function parsing alphas started
# Parsing alpha rank(delta(assets/capex, 256))
# Parsing alpha rank(delta(assets/cash, 256))
# Parsing alpha rank(delta(assets/cashflow, 256))
# Parsing alpha rank(delta(assets/cashflow_dividends, 256))
# Parsing alpha rank(delta(assets/cashflow_fin, 256))
# Parsing alpha rank(delta(assets/cashflow_invst, 256))
# Parsing alpha rank(delta(assets/cashflow_op, 256))
# Parsing alpha rank(delta(assets/cogs, 256))
# Parsing alpha rank(delta(assets/current_ratio, 256))
# Parsing alpha rank(delta(assets/debt, 256))
# Parsing alpha rank(delta(assets/debt_lt, 256))
# Parsing alpha rank(delta(assets/debt_st, 256))
# Parsing alpha rank(delta(assets/depre_amort, 256))
# Parsing alpha rank(delta(assets/EBIT, 256))
# Parsing alpha rank(delta(assets/EBITDA, 256))
# Parsing alpha rank(delta(assets/employee, 256))
# Parsing alpha rank(delta(assets/enterprise_value, 256))
# Parsing alpha rank(delta(assets/eps, 256))
# Parsing alpha rank(delta(assets/equity, 256))
# Parsing alpha rank(delta(assets/goodwill, 256))
# Parsing alpha rank(delta(assets/income, 256))
# Parsing alpha rank(delta(assets/income_beforeextra, 256))
# Parsing alpha rank(delta(assets/income_tax, 256))
# Parsing alpha rank(delta(assets/interest_expense, 256))
# Parsing alpha rank(delta(assets/inventory, 256))
# Parsing alpha rank(delta(assets/inventory_turnover, 256))
# Parsing alpha rank(delta(assets/invested_capital, 256))
# AlphaId cb352f8c578741f28c25ceea9d4f5518
# SubmissionId 56558498
# Parsing alpha rank(delta(assets/liabilities, 256))
# Parsing alpha rank(delta(assets/liabilities_curr, 256))
# Parsing alpha rank(delta(assets/operating_expense, 256))
# Parsing alpha rank(delta(assets/operating_income, 256))
# Parsing alpha rank(delta(assets/pretax_income, 256))
# Parsing alpha rank(delta(assets/rd_expense, 256))
# Parsing alpha rank(delta(assets/receivable, 256))
# Parsing alpha rank(delta(assets/retained_earnings, 256))
# Parsing alpha rank(delta(assets/return_assets, 256))
# Parsing alpha rank(delta(assets/return_equity, 256))
# Parsing alpha rank(delta(assets/revenue, 256))
# Parsing alpha rank(delta(assets/sales, 256))
# Parsing alpha rank(delta(assets/sales_growth, 256))
# Parsing alpha rank(delta(assets/sales_ps, 256))
# Parsing alpha rank(delta(assets/SGA_expense, 256))
# Parsing alpha rank(delta(assets/working_capital, 256))
# Parsing alpha rank(delta(assets_curr/bookvalue_ps, 256))
# AlphaId 86b5ae8b6d6f458e88bcbf823fce9a4c
# SubmissionId 56558858
# Parsing alpha rank(delta(assets_curr/capex, 256))
# Parsing alpha rank(delta(assets_curr/cash, 256))
# Parsing alpha rank(delta(assets_curr/cashflow, 256))
# Parsing alpha rank(delta(assets_curr/cashflow_dividends, 256))
# Parsing alpha rank(delta(assets_curr/cashflow_fin, 256))
# Parsing alpha rank(delta(assets_curr/cashflow_invst, 256))
# Parsing alpha rank(delta(assets_curr/cashflow_op, 256))
# Parsing alpha rank(delta(assets_curr/cogs, 256))
# Parsing alpha rank(delta(assets_curr/current_ratio, 256))
# Parsing alpha rank(delta(assets_curr/debt, 256))
# Parsing alpha rank(delta(assets_curr/debt_lt, 256))
# Parsing alpha rank(delta(assets_curr/debt_st, 256))
# Parsing alpha rank(delta(assets_curr/depre_amort, 256))
# Parsing alpha rank(delta(assets_curr/EBIT, 256))
# Parsing alpha rank(delta(assets_curr/EBITDA, 256))
# Parsing alpha rank(delta(assets_curr/employee, 256))
# Parsing alpha rank(delta(assets_curr/enterprise_value, 256))
# Parsing alpha rank(delta(assets_curr/eps, 256))
# Parsing alpha rank(delta(assets_curr/equity, 256))
# AlphaId c6bb8d3e116042188c5654af635bec26
# SubmissionId 56559364
# Parsing alpha rank(delta(assets_curr/goodwill, 256))
# Parsing alpha rank(delta(assets_curr/income, 256))
# Parsing alpha rank(delta(assets_curr/income_beforeextra, 256))
# Parsing alpha rank(delta(assets_curr/income_tax, 256))
# Parsing alpha rank(delta(assets_curr/interest_expense, 256))
# Parsing alpha rank(delta(assets_curr/inventory, 256))
# Parsing alpha rank(delta(assets_curr/inventory_turnover, 256))
# Parsing alpha rank(delta(assets_curr/invested_capital, 256))
# AlphaId 24b982de6cb8420db690f43ae8baf634
# SubmissionId 56559538
# Parsing alpha rank(delta(assets_curr/liabilities, 256))
# Parsing alpha rank(delta(assets_curr/liabilities_curr, 256))
# Parsing alpha rank(delta(assets_curr/operating_expense, 256))
# Parsing alpha rank(delta(assets_curr/operating_income, 256))
# Parsing alpha rank(delta(assets_curr/pretax_income, 256))
# Parsing alpha rank(delta(assets_curr/rd_expense, 256))
# Parsing alpha rank(delta(assets_curr/receivable, 256))
# Parsing alpha rank(delta(assets_curr/retained_earnings, 256))
# Parsing alpha rank(delta(assets_curr/return_assets, 256))
# Parsing alpha rank(delta(assets_curr/return_equity, 256))
# Parsing alpha rank(delta(assets_curr/revenue, 256))
# Parsing alpha rank(delta(assets_curr/sales, 256))
# Parsing alpha rank(delta(assets_curr/sales_growth, 256))
# Parsing alpha rank(delta(assets_curr/sales_ps, 256))
# Parsing alpha rank(delta(assets_curr/SGA_expense, 256))
# Parsing alpha rank(delta(assets_curr/working_capital, 256))
# Parsing alpha rank(delta(bookvalue_ps/capex, 256))
# Parsing alpha rank(delta(bookvalue_ps/cash, 256))
# Parsing alpha rank(delta(bookvalue_ps/cashflow, 256))
# Parsing alpha rank(delta(bookvalue_ps/cashflow_dividends, 256))
# Parsing alpha rank(delta(bookvalue_ps/cashflow_fin, 256))
# Parsing alpha rank(delta(bookvalue_ps/cashflow_invst, 256))
# Parsing alpha rank(delta(bookvalue_ps/cashflow_op, 256))
# Parsing alpha rank(delta(bookvalue_ps/cogs, 256))
# Parsing alpha rank(delta(bookvalue_ps/current_ratio, 256))
# Parsing alpha rank(delta(bookvalue_ps/debt, 256))
# Parsing alpha rank(delta(bookvalue_ps/debt_lt, 256))
# Parsing alpha rank(delta(bookvalue_ps/debt_st, 256))
# Parsing alpha rank(delta(bookvalue_ps/depre_amort, 256))
# Function parsing alphas finished
#
#
# Function parse submissions started
# Function parse submissions finished
# Function simulating alphas started
# Simulating alpha rank(delta(bookvalue_ps/EBIT, 256))
# Simulating alpha rank(delta(bookvalue_ps/EBITDA, 256))
# Simulating alpha rank(delta(bookvalue_ps/employee, 256))
# Simulating alpha rank(delta(bookvalue_ps/enterprise_value, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/enterprise_value, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/enterprise_value, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/enterprise_value, 256))
# Simulating alpha rank(delta(bookvalue_ps/eps, 256))
# Simulating alpha rank(delta(bookvalue_ps/equity, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/equity, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/equity, 256))
# Simulating alpha rank(delta(bookvalue_ps/goodwill, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/goodwill, 256))
# Simulating alpha rank(delta(bookvalue_ps/income, 256))
# Simulating alpha rank(delta(bookvalue_ps/income_beforeextra, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/income_beforeextra, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/income_beforeextra, 256))
# Simulating alpha rank(delta(bookvalue_ps/income_tax, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/income_tax, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/income_tax, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/income_tax, 256))
# Simulating alpha rank(delta(bookvalue_ps/interest_expense, 256))
# Simulating alpha rank(delta(bookvalue_ps/inventory, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/inventory, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/inventory, 256))
# Simulating alpha rank(delta(bookvalue_ps/inventory_turnover, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/inventory_turnover, 256))
# Simulating alpha rank(delta(bookvalue_ps/invested_capital, 256))
# Simulating alpha rank(delta(bookvalue_ps/liabilities, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/liabilities, 256))
# Simulating alpha rank(delta(bookvalue_ps/liabilities_curr, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/liabilities_curr, 256))
# Simulating alpha rank(delta(bookvalue_ps/operating_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/operating_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/operating_expense, 256))
# Simulating alpha rank(delta(bookvalue_ps/operating_income, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/operating_income, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/operating_income, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/operating_income, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/operating_income, 256))
# Simulating alpha rank(delta(bookvalue_ps/pretax_income, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/pretax_income, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/pretax_income, 256))
# Simulating alpha rank(delta(bookvalue_ps/rd_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/rd_expense, 256))
# Simulating alpha rank(delta(bookvalue_ps/receivable, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/receivable, 256))
# Simulating alpha rank(delta(bookvalue_ps/retained_earnings, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/retained_earnings, 256))
# Simulating alpha rank(delta(bookvalue_ps/return_assets, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/return_assets, 256))
# Simulating alpha rank(delta(bookvalue_ps/return_equity, 256))
# Simulating alpha rank(delta(bookvalue_ps/revenue, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/revenue, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/revenue, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/revenue, 256))
# Simulating alpha rank(delta(bookvalue_ps/sales, 256))
# Simulating alpha rank(delta(bookvalue_ps/sales_growth, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/sales_growth, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/sales_growth, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/sales_growth, 256))
# Simulating alpha rank(delta(bookvalue_ps/sales_ps, 256))
# Simulating alpha rank(delta(bookvalue_ps/SGA_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/SGA_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/SGA_expense, 256))
# Simulating alpha rank(delta(bookvalue_ps/working_capital, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/working_capital, 256))
# Simulating alpha rank(delta(capex/cash, 256))
# Simulating alpha rank(delta(capex/cashflow, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/cashflow, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/cashflow, 256))
# Simulating alpha rank(delta(capex/cashflow_dividends, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/cashflow_dividends, 256))
# Simulating alpha rank(delta(capex/cashflow_fin, 256))
# Simulating alpha rank(delta(capex/cashflow_invst, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/cashflow_invst, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/cashflow_invst, 256))
# Simulating alpha rank(delta(capex/cashflow_op, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/cashflow_op, 256))
# Simulating alpha rank(delta(capex/cogs, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/cogs, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/cogs, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/cogs, 256))
# Simulating alpha rank(delta(capex/current_ratio, 256))
# Simulating alpha rank(delta(capex/debt, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/debt, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/debt, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/debt, 256))
# Simulating alpha rank(delta(capex/debt_lt, 256))
# Simulating alpha rank(delta(capex/debt_st, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/debt_st, 256))
# Simulating alpha rank(delta(capex/depre_amort, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/depre_amort, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/depre_amort, 256))
# Simulating alpha rank(delta(capex/EBIT, 256))
# Simulating alpha rank(delta(capex/EBITDA, 256))
# Simulating alpha rank(delta(capex/employee, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/employee, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/employee, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/employee, 256))
# Simulating alpha rank(delta(capex/enterprise_value, 256))
# Simulating alpha rank(delta(capex/eps, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/eps, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/eps, 256))
# Simulating alpha rank(delta(capex/equity, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/equity, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/equity, 256))
# Simulating alpha rank(delta(capex/goodwill, 256))
# Simulating alpha rank(delta(capex/income, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/income, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/income, 256))
# Simulating alpha rank(delta(capex/income_beforeextra, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/income_beforeextra, 256))
# Simulating alpha rank(delta(capex/income_tax, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/income_tax, 256))
# Simulating alpha rank(delta(capex/interest_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/interest_expense, 256))
# Simulating alpha rank(delta(capex/inventory, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/inventory, 256))
# Simulating alpha rank(delta(capex/inventory_turnover, 256))
# Simulating alpha rank(delta(capex/invested_capital, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/invested_capital, 256))
# Simulating alpha rank(delta(capex/liabilities, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/liabilities, 256))
# Simulating alpha rank(delta(capex/liabilities_curr, 256))
# Simulating alpha rank(delta(capex/operating_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/operating_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/operating_expense, 256))
# Simulating alpha rank(delta(capex/operating_income, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/operating_income, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/operating_income, 256))
# Simulating alpha rank(delta(capex/pretax_income, 256))
# Simulating alpha rank(delta(capex/rd_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/rd_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/rd_expense, 256))
# Simulating alpha rank(delta(capex/receivable, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/receivable, 256))
# Simulating alpha rank(delta(capex/retained_earnings, 256))
# Simulating alpha rank(delta(capex/return_assets, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/return_assets, 256))
# Simulating alpha rank(delta(capex/return_equity, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/return_equity, 256))
# Simulating alpha rank(delta(capex/revenue, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/revenue, 256))
# Simulating alpha rank(delta(capex/sales, 256))
# Simulating alpha rank(delta(capex/sales_growth, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/sales_growth, 256))
# Simulating alpha rank(delta(capex/sales_ps, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/sales_ps, 256))
# Simulating alpha rank(delta(capex/SGA_expense, 256))
# Simulating alpha rank(delta(capex/working_capital, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/working_capital, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/working_capital, 256))
# Simulating alpha rank(delta(cash/cashflow, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/cashflow, 256))
# Simulating alpha rank(delta(cash/cashflow_dividends, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/cashflow_dividends, 256))
# Simulating alpha rank(delta(cash/cashflow_fin, 256))
# Simulating alpha rank(delta(cash/cashflow_invst, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/cashflow_invst, 256))
# Simulating alpha rank(delta(cash/cashflow_op, 256))
# Simulating alpha rank(delta(cash/cogs, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/cogs, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/cogs, 256))
# Simulating alpha rank(delta(cash/current_ratio, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/current_ratio, 256))
# Simulating alpha rank(delta(cash/debt, 256))
# Simulating alpha rank(delta(cash/debt_lt, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/debt_lt, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/debt_lt, 256))
# Simulating alpha rank(delta(cash/debt_st, 256))
# Simulating alpha rank(delta(cash/depre_amort, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/depre_amort, 256))
# Simulating alpha rank(delta(cash/EBIT, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/EBIT, 256))
# Simulating alpha rank(delta(cash/EBITDA, 256))
# Simulating alpha rank(delta(cash/employee, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/employee, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/employee, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/employee, 256))
# Simulating alpha rank(delta(cash/enterprise_value, 256))
# Simulating alpha rank(delta(cash/eps, 256))
# Simulating alpha rank(delta(cash/equity, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/equity, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/equity, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/equity, 256))
# Simulating alpha rank(delta(cash/goodwill, 256))
# Simulating alpha rank(delta(cash/income, 256))
# Simulating alpha rank(delta(cash/income_beforeextra, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/income_beforeextra, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/income_beforeextra, 256))
# Simulating alpha rank(delta(cash/income_tax, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/income_tax, 256))
# Simulating alpha rank(delta(cash/interest_expense, 256))
# Simulating alpha rank(delta(cash/inventory, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/inventory, 256))
# Simulating alpha rank(delta(cash/inventory_turnover, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/inventory_turnover, 256))
# Simulating alpha rank(delta(cash/invested_capital, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/invested_capital, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/invested_capital, 256))
# Simulating alpha rank(delta(cash/liabilities, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/liabilities, 256))
# Simulating alpha rank(delta(cash/liabilities_curr, 256))
# Simulating alpha rank(delta(cash/operating_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/operating_expense, 256))
# Function simulating alphas finished
#
#
# Function parsing alphas started
# Parsing alpha rank(delta(bookvalue_ps/EBIT, 256))
# Parsing alpha rank(delta(bookvalue_ps/EBITDA, 256))
# Parsing alpha rank(delta(bookvalue_ps/employee, 256))
# Parsing alpha rank(delta(bookvalue_ps/enterprise_value, 256))
# Parsing alpha rank(delta(bookvalue_ps/eps, 256))
# Parsing alpha rank(delta(bookvalue_ps/equity, 256))
# Parsing alpha rank(delta(bookvalue_ps/goodwill, 256))
# Parsing alpha rank(delta(bookvalue_ps/income, 256))
# Parsing alpha rank(delta(bookvalue_ps/income_beforeextra, 256))
# Parsing alpha rank(delta(bookvalue_ps/income_tax, 256))
# Parsing alpha rank(delta(bookvalue_ps/interest_expense, 256))
# Parsing alpha rank(delta(bookvalue_ps/inventory, 256))
# Parsing alpha rank(delta(bookvalue_ps/inventory_turnover, 256))
# Parsing alpha rank(delta(bookvalue_ps/invested_capital, 256))
# Parsing alpha rank(delta(bookvalue_ps/liabilities, 256))
# Parsing alpha rank(delta(bookvalue_ps/liabilities_curr, 256))
# Parsing alpha rank(delta(bookvalue_ps/operating_expense, 256))
# Parsing alpha rank(delta(bookvalue_ps/operating_income, 256))
# Parsing alpha rank(delta(bookvalue_ps/pretax_income, 256))
# Parsing alpha rank(delta(bookvalue_ps/rd_expense, 256))
# Parsing alpha rank(delta(bookvalue_ps/receivable, 256))
# Parsing alpha rank(delta(bookvalue_ps/retained_earnings, 256))
# Parsing alpha rank(delta(bookvalue_ps/return_assets, 256))
# Parsing alpha rank(delta(bookvalue_ps/return_equity, 256))
# Parsing alpha rank(delta(bookvalue_ps/revenue, 256))
# Parsing alpha rank(delta(bookvalue_ps/sales, 256))
# Parsing alpha rank(delta(bookvalue_ps/sales_growth, 256))
# Parsing alpha rank(delta(bookvalue_ps/sales_ps, 256))
# Parsing alpha rank(delta(bookvalue_ps/SGA_expense, 256))
# Parsing alpha rank(delta(bookvalue_ps/working_capital, 256))
# Parsing alpha rank(delta(capex/cash, 256))
# Parsing alpha rank(delta(capex/cashflow, 256))
# Parsing alpha rank(delta(capex/cashflow_dividends, 256))
# Parsing alpha rank(delta(capex/cashflow_fin, 256))
# Parsing alpha rank(delta(capex/cashflow_invst, 256))
# Parsing alpha rank(delta(capex/cashflow_op, 256))
# Parsing alpha rank(delta(capex/cogs, 256))
# Parsing alpha rank(delta(capex/current_ratio, 256))
# Parsing alpha rank(delta(capex/debt, 256))
# Parsing alpha rank(delta(capex/debt_lt, 256))
# Parsing alpha rank(delta(capex/debt_st, 256))
# Parsing alpha rank(delta(capex/depre_amort, 256))
# Parsing alpha rank(delta(capex/EBIT, 256))
# Parsing alpha rank(delta(capex/EBITDA, 256))
# Parsing alpha rank(delta(capex/employee, 256))
# Parsing alpha rank(delta(capex/enterprise_value, 256))
# Parsing alpha rank(delta(capex/eps, 256))
# Parsing alpha rank(delta(capex/equity, 256))
# Parsing alpha rank(delta(capex/goodwill, 256))
# Parsing alpha rank(delta(capex/income, 256))
# Parsing alpha rank(delta(capex/income_beforeextra, 256))
# Parsing alpha rank(delta(capex/income_tax, 256))
# Parsing alpha rank(delta(capex/interest_expense, 256))
# Parsing alpha rank(delta(capex/inventory, 256))
# Parsing alpha rank(delta(capex/inventory_turnover, 256))
# Parsing alpha rank(delta(capex/invested_capital, 256))
# Parsing alpha rank(delta(capex/liabilities, 256))
# Parsing alpha rank(delta(capex/liabilities_curr, 256))
# Parsing alpha rank(delta(capex/operating_expense, 256))
# Parsing alpha rank(delta(capex/operating_income, 256))
# Parsing alpha rank(delta(capex/pretax_income, 256))
# Parsing alpha rank(delta(capex/rd_expense, 256))
# Parsing alpha rank(delta(capex/receivable, 256))
# Parsing alpha rank(delta(capex/retained_earnings, 256))
# Parsing alpha rank(delta(capex/return_assets, 256))
# Parsing alpha rank(delta(capex/return_equity, 256))
# Parsing alpha rank(delta(capex/revenue, 256))
# Parsing alpha rank(delta(capex/sales, 256))
# Parsing alpha rank(delta(capex/sales_growth, 256))
# Parsing alpha rank(delta(capex/sales_ps, 256))
# Parsing alpha rank(delta(capex/SGA_expense, 256))
# Parsing alpha rank(delta(capex/working_capital, 256))
# Parsing alpha rank(delta(cash/cashflow, 256))
# Alpha rank(delta(cash/cashflow, 256)) not finished simulation
# Parsing alpha rank(delta(cash/cashflow, 256))
# Alpha rank(delta(cash/cashflow, 256)) not finished simulation
# Parsing alpha rank(delta(cash/cashflow, 256))
# Alpha rank(delta(cash/cashflow, 256)) not finished simulation
# Parsing alpha rank(delta(cash/cashflow_dividends, 256))
# Parsing alpha rank(delta(cash/cashflow_fin, 256))
# Parsing alpha rank(delta(cash/cashflow_invst, 256))
# Parsing alpha rank(delta(cash/cashflow_op, 256))
# Parsing alpha rank(delta(cash/cogs, 256))
# Parsing alpha rank(delta(cash/current_ratio, 256))
# AlphaId 3d6c6a28cf244201895b8fd6c500803e
# SubmissionId 56569848
# Parsing alpha rank(delta(cash/debt, 256))
# Parsing alpha rank(delta(cash/debt_lt, 256))
# Parsing alpha rank(delta(cash/debt_st, 256))
# Parsing alpha rank(delta(cash/depre_amort, 256))
# Parsing alpha rank(delta(cash/EBIT, 256))
# Parsing alpha rank(delta(cash/EBITDA, 256))
# Parsing alpha rank(delta(cash/employee, 256))
# Parsing alpha rank(delta(cash/enterprise_value, 256))
# Parsing alpha rank(delta(cash/eps, 256))
# Parsing alpha rank(delta(cash/equity, 256))
# AlphaId 632dca9ef7f847dabcf8d85fb4b0714c
# SubmissionId 56570024
# Parsing alpha rank(delta(cash/goodwill, 256))
# Parsing alpha rank(delta(cash/income, 256))
# Parsing alpha rank(delta(cash/income_beforeextra, 256))
# Parsing alpha rank(delta(cash/income_tax, 256))
# Parsing alpha rank(delta(cash/interest_expense, 256))
# Parsing alpha rank(delta(cash/inventory, 256))
# Parsing alpha rank(delta(cash/inventory_turnover, 256))
# Parsing alpha rank(delta(cash/invested_capital, 256))
# Parsing alpha rank(delta(cash/liabilities, 256))
# Parsing alpha rank(delta(cash/liabilities_curr, 256))
# Parsing alpha rank(delta(cash/operating_expense, 256))
# Function parsing alphas finished
#
#
# Function parse submissions started
# Function parse submissions finished
# Function simulating alphas started
# Simulating alpha rank(delta(cash/cashflow, 256))
# Simulating alpha rank(delta(cash/operating_income, 256))
# Simulating alpha rank(delta(cash/pretax_income, 256))
# Simulating alpha rank(delta(cash/rd_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/rd_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/rd_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/rd_expense, 256))
# Simulating alpha rank(delta(cash/receivable, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/receivable, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/receivable, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/receivable, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/receivable, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/receivable, 256))
# Simulating alpha rank(delta(cash/retained_earnings, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/retained_earnings, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/retained_earnings, 256))
# Simulating alpha rank(delta(cash/return_assets, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/return_assets, 256))
# Simulating alpha rank(delta(cash/return_equity, 256))
# Simulating alpha rank(delta(cash/revenue, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/revenue, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/revenue, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/revenue, 256))
# Simulating alpha rank(delta(cash/sales, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/sales, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/sales, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/sales, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/sales, 256))
# Simulating alpha rank(delta(cash/sales_growth, 256))
# Simulating alpha rank(delta(cash/sales_ps, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/sales_ps, 256))
# Simulating alpha rank(delta(cash/SGA_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/SGA_expense, 256))
# Simulating alpha rank(delta(cash/working_capital, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/working_capital, 256))
# Simulating alpha rank(delta(cashflow/cashflow_dividends, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/cashflow_dividends, 256))
# Simulating alpha rank(delta(cashflow/cashflow_fin, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/cashflow_fin, 256))
# Simulating alpha rank(delta(cashflow/cashflow_invst, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/cashflow_invst, 256))
# Simulating alpha rank(delta(cashflow/cashflow_op, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/cashflow_op, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/cashflow_op, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/cashflow_op, 256))
# Simulating alpha rank(delta(cashflow/cogs, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/cogs, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/cogs, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/cogs, 256))
# Simulating alpha rank(delta(cashflow/current_ratio, 256))
# Simulating alpha rank(delta(cashflow/debt, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/debt, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/debt, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/debt, 256))
# Simulating alpha rank(delta(cashflow/debt_lt, 256))
# Simulating alpha rank(delta(cashflow/debt_st, 256))
# Simulating alpha rank(delta(cashflow/depre_amort, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/depre_amort, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/depre_amort, 256))
# Simulating alpha rank(delta(cashflow/EBIT, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/EBIT, 256))
# Simulating alpha rank(delta(cashflow/EBITDA, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/EBITDA, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/EBITDA, 256))
# Simulating alpha rank(delta(cashflow/employee, 256))
# Simulating alpha rank(delta(cashflow/enterprise_value, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/enterprise_value, 256))
# Simulating alpha rank(delta(cashflow/eps, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/eps, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/eps, 256))
# Simulating alpha rank(delta(cashflow/equity, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/equity, 256))
# Simulating alpha rank(delta(cashflow/goodwill, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/goodwill, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/goodwill, 256))
# Simulating alpha rank(delta(cashflow/income, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/income, 256))
# Simulating alpha rank(delta(cashflow/income_beforeextra, 256))
# Simulating alpha rank(delta(cashflow/income_tax, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/income_tax, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/income_tax, 256))
# Simulating alpha rank(delta(cashflow/interest_expense, 256))
# Simulating alpha rank(delta(cashflow/inventory, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/inventory, 256))
# Simulating alpha rank(delta(cashflow/inventory_turnover, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/inventory_turnover, 256))
# Simulating alpha rank(delta(cashflow/invested_capital, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/invested_capital, 256))
# Simulating alpha rank(delta(cashflow/liabilities, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/liabilities, 256))
# Simulating alpha rank(delta(cashflow/liabilities_curr, 256))
# Simulating alpha rank(delta(cashflow/operating_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/operating_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/operating_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/operating_expense, 256))
# Simulating alpha rank(delta(cashflow/operating_income, 256))
# Simulating alpha rank(delta(cashflow/pretax_income, 256))
# Simulating alpha rank(delta(cashflow/rd_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/rd_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/rd_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/rd_expense, 256))
# Simulating alpha rank(delta(cashflow/receivable, 256))
# Simulating alpha rank(delta(cashflow/retained_earnings, 256))
# Simulating alpha rank(delta(cashflow/return_assets, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/return_assets, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/return_assets, 256))
# Simulating alpha rank(delta(cashflow/return_equity, 256))
# Simulating alpha rank(delta(cashflow/revenue, 256))
# Simulating alpha rank(delta(cashflow/sales, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/sales, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/sales, 256))
# Simulating alpha rank(delta(cashflow/sales_growth, 256))
# Simulating alpha rank(delta(cashflow/sales_ps, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/sales_ps, 256))
# Simulating alpha rank(delta(cashflow/SGA_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow/SGA_expense, 256))
# Simulating alpha rank(delta(cashflow/working_capital, 256))
# Simulating alpha rank(delta(cashflow_dividends/cashflow_fin, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/cashflow_fin, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/cashflow_fin, 256))
# Simulating alpha rank(delta(cashflow_dividends/cashflow_invst, 256))
# Simulating alpha rank(delta(cashflow_dividends/cashflow_op, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/cashflow_op, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/cashflow_op, 256))
# Simulating alpha rank(delta(cashflow_dividends/cogs, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/cogs, 256))
# Simulating alpha rank(delta(cashflow_dividends/current_ratio, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/current_ratio, 256))
# Simulating alpha rank(delta(cashflow_dividends/debt, 256))
# Simulating alpha rank(delta(cashflow_dividends/debt_lt, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/debt_lt, 256))
# Simulating alpha rank(delta(cashflow_dividends/debt_st, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/debt_st, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/debt_st, 256))
# Simulating alpha rank(delta(cashflow_dividends/depre_amort, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/depre_amort, 256))
# Simulating alpha rank(delta(cashflow_dividends/EBIT, 256))
# Simulating alpha rank(delta(cashflow_dividends/EBITDA, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/EBITDA, 256))
# Simulating alpha rank(delta(cashflow_dividends/employee, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/employee, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/employee, 256))
# Simulating alpha rank(delta(cashflow_dividends/enterprise_value, 256))
# Simulating alpha rank(delta(cashflow_dividends/eps, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/eps, 256))
# Simulating alpha rank(delta(cashflow_dividends/equity, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/equity, 256))
# Simulating alpha rank(delta(cashflow_dividends/goodwill, 256))
# Simulating alpha rank(delta(cashflow_dividends/income, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/income, 256))
# Simulating alpha rank(delta(cashflow_dividends/income_beforeextra, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/income_beforeextra, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/income_beforeextra, 256))
# Simulating alpha rank(delta(cashflow_dividends/income_tax, 256))
# Simulating alpha rank(delta(cashflow_dividends/interest_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/interest_expense, 256))
# Simulating alpha rank(delta(cashflow_dividends/inventory, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/inventory, 256))
# Simulating alpha rank(delta(cashflow_dividends/inventory_turnover, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/inventory_turnover, 256))
# Simulating alpha rank(delta(cashflow_dividends/invested_capital, 256))
# Simulating alpha rank(delta(cashflow_dividends/liabilities, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/liabilities, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/liabilities, 256))
# Simulating alpha rank(delta(cashflow_dividends/liabilities_curr, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/liabilities_curr, 256))
# Simulating alpha rank(delta(cashflow_dividends/operating_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/operating_expense, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/operating_expense, 256))
# Simulating alpha rank(delta(cashflow_dividends/operating_income, 256))
# Simulating alpha rank(delta(cashflow_dividends/pretax_income, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/pretax_income, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/pretax_income, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/pretax_income, 256))
# Simulating alpha rank(delta(cashflow_dividends/rd_expense, 256))
# Simulating alpha rank(delta(cashflow_dividends/receivable, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/receivable, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/receivable, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/receivable, 256))
# Simulating alpha rank(delta(cashflow_dividends/retained_earnings, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/retained_earnings, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/retained_earnings, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/retained_earnings, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/retained_earnings, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/retained_earnings, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/retained_earnings, 256))
# Simulating alpha rank(delta(cashflow_dividends/return_assets, 256))
# Simulating alpha rank(delta(cashflow_dividends/return_equity, 256))
# Simulating alpha rank(delta(cashflow_dividends/revenue, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/revenue, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/revenue, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/revenue, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/revenue, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/revenue, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/revenue, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/revenue, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/revenue, 256))
# Simulating alpha rank(delta(cashflow_dividends/sales, 256))
# Simulating alpha rank(delta(cashflow_dividends/sales_growth, 256))
# Simulating alpha rank(delta(cashflow_dividends/sales_ps, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/sales_ps, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/sales_ps, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/sales_ps, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/sales_ps, 256))
# Simulating alpha rank(delta(cashflow_dividends/SGA_expense, 256))
# Simulating alpha rank(delta(cashflow_dividends/working_capital, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/working_capital, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_dividends/working_capital, 256))
# Simulating alpha rank(delta(cashflow_fin/cashflow_invst, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_fin/cashflow_invst, 256))
# Simulating alpha rank(delta(cashflow_fin/cashflow_op, 256))
# Simulating alpha rank(delta(cashflow_fin/cogs, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_fin/cogs, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_fin/cogs, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_fin/cogs, 256))
# Simulating alpha rank(delta(cashflow_fin/current_ratio, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_fin/current_ratio, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_fin/current_ratio, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_fin/current_ratio, 256))
# Simulating alpha rank(delta(cashflow_fin/debt, 256))
# Simulating alpha rank(delta(cashflow_fin/debt_lt, 256))
# Too many alphas simulating
# Simulating alpha rank(delta(cashflow_fin/debt_lt, 256))
# Simulating alpha rank(delta(cashflow_fin/debt_st, 256))
# Too many alphas simulating
# ...
# Simulating alpha rank(delta(bookvalue_ps/sales_growth, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/sales_growth, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/sales_growth, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/sales_growth, 63))
# Simulating alpha rank(delta(bookvalue_ps/sales_ps, 63))
# Simulating alpha rank(delta(bookvalue_ps/SGA_expense, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/SGA_expense, 63))
# Simulating alpha rank(delta(bookvalue_ps/working_capital, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(bookvalue_ps/working_capital, 63))
# Simulating alpha rank(delta(capex/cash, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/cash, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/cash, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/cash, 63))
# Function simulating alphas finished
#
#
# Function parsing alphas started
# Parsing alpha rank(delta(est_ebit/est_netprofit_adj, 126))
# Not proceeded case with Fitness 1.46 and Sharpe 1.25
# Parsing alpha rank(delta(est_ebit/est_netprofit_adj, 126))
# Not proceeded case with Fitness 1.46 and Sharpe 1.25
# Parsing alpha rank(delta(est_ebit/est_netprofit_adj, 126))
# Not proceeded case with Fitness 1.46 and Sharpe 1.25
# Parsing alpha rank(delta(est_ebit/est_netprofit_adj, 126))
# Not proceeded case with Fitness 1.46 and Sharpe 1.25
# Parsing alpha rank(delta(est_netprofit_adj/est_ptp, 126))
# Not proceeded case with Fitness -1.47 and Sharpe -1.25
# Parsing alpha rank(delta(est_ebit/est_netprofit_adj, 126))
# Not proceeded case with Fitness 1.46 and Sharpe 1.25
# Parsing alpha rank(delta(est_netprofit_adj/est_ptp, 126))
# Not proceeded case with Fitness -1.47 and Sharpe -1.25
# Parsing alpha rank(delta(est_ebit/est_netprofit_adj, 126))
# Not proceeded case with Fitness 1.46 and Sharpe 1.25
# Parsing alpha rank(delta(est_netprofit_adj/est_ptp, 126))
# Not proceeded case with Fitness -1.47 and Sharpe -1.25
# Parsing alpha rank(delta(assets/return_assets, 63))
# Parsing alpha rank(delta(assets/return_equity, 63))
# Parsing alpha rank(delta(assets/revenue, 63))
# Parsing alpha rank(delta(assets/sales, 63))
# Parsing alpha rank(delta(assets/sales_growth, 63))
# Parsing alpha rank(delta(assets/sales_ps, 63))
# Parsing alpha rank(delta(assets/SGA_expense, 63))
# Parsing alpha rank(delta(assets/working_capital, 63))
# Parsing alpha rank(delta(assets_curr/bookvalue_ps, 63))
# Parsing alpha rank(delta(assets_curr/capex, 63))
# Parsing alpha rank(delta(assets_curr/cash, 63))
# Parsing alpha rank(delta(assets_curr/cashflow, 63))
# Parsing alpha rank(delta(assets_curr/cashflow_dividends, 63))
# Parsing alpha rank(delta(assets_curr/cashflow_fin, 63))
# Parsing alpha rank(delta(assets_curr/cashflow_invst, 63))
# Parsing alpha rank(delta(assets_curr/cashflow_op, 63))
# Parsing alpha rank(delta(assets_curr/cogs, 63))
# Parsing alpha rank(delta(assets_curr/current_ratio, 63))
# Parsing alpha rank(delta(est_ebit/est_netprofit_adj, 126))
# Not proceeded case with Fitness 1.46 and Sharpe 1.25
# Parsing alpha rank(delta(est_netprofit_adj/est_ptp, 126))
# Not proceeded case with Fitness -1.47 and Sharpe -1.25
# Parsing alpha rank(delta(assets/assets_curr, 63))
# Parsing alpha rank(delta(assets/bookvalue_ps, 63))
# Parsing alpha rank(delta(assets/return_assets, 63))
# Parsing alpha rank(delta(assets/return_equity, 63))
# Parsing alpha rank(delta(assets/revenue, 63))
# Parsing alpha rank(delta(assets/sales, 63))
# Parsing alpha rank(delta(assets/sales_growth, 63))
# Parsing alpha rank(delta(assets/sales_ps, 63))
# Parsing alpha rank(delta(assets/SGA_expense, 63))
# Parsing alpha rank(delta(assets/working_capital, 63))
# Parsing alpha rank(delta(assets_curr/bookvalue_ps, 63))
# Parsing alpha rank(delta(assets_curr/capex, 63))
# Parsing alpha rank(delta(assets_curr/cash, 63))
# Parsing alpha rank(delta(assets_curr/cashflow, 63))
# Parsing alpha rank(delta(assets_curr/cashflow_dividends, 63))
# Parsing alpha rank(delta(assets_curr/cashflow_fin, 63))
# Parsing alpha rank(delta(assets_curr/cashflow_invst, 63))
# Parsing alpha rank(delta(assets_curr/cashflow_op, 63))
# Parsing alpha rank(delta(assets_curr/cogs, 63))
# Parsing alpha rank(delta(assets_curr/current_ratio, 63))
# Parsing alpha rank(delta(assets_curr/debt, 63))
# Parsing alpha rank(delta(assets_curr/debt_lt, 63))
# Parsing alpha rank(delta(assets_curr/debt_st, 63))
# Parsing alpha rank(delta(assets_curr/depre_amort, 63))
# Parsing alpha rank(delta(assets_curr/EBIT, 63))
# Parsing alpha rank(delta(assets_curr/EBITDA, 63))
# Parsing alpha rank(delta(assets_curr/employee, 63))
# Parsing alpha rank(delta(assets_curr/enterprise_value, 63))
# Parsing alpha rank(delta(assets_curr/eps, 63))
# Parsing alpha rank(delta(assets_curr/equity, 63))
# Parsing alpha rank(delta(assets_curr/goodwill, 63))
# Parsing alpha rank(delta(assets_curr/income, 63))
# Parsing alpha rank(delta(assets_curr/income_beforeextra, 63))
# Parsing alpha rank(delta(assets_curr/income_tax, 63))
# Parsing alpha rank(delta(assets_curr/interest_expense, 63))
# Parsing alpha rank(delta(assets_curr/inventory, 63))
# Parsing alpha rank(delta(assets_curr/inventory_turnover, 63))
# Parsing alpha rank(delta(assets_curr/invested_capital, 63))
# Parsing alpha rank(delta(assets_curr/liabilities, 63))
# Parsing alpha rank(delta(assets_curr/liabilities_curr, 63))
# Parsing alpha rank(delta(assets_curr/operating_expense, 63))
# Parsing alpha rank(delta(assets_curr/operating_income, 63))
# Parsing alpha rank(delta(assets_curr/pretax_income, 63))
# Parsing alpha rank(delta(assets_curr/rd_expense, 63))
# Parsing alpha rank(delta(assets_curr/receivable, 63))
# Parsing alpha rank(delta(assets_curr/retained_earnings, 63))
# Parsing alpha rank(delta(assets_curr/return_assets, 63))
# Parsing alpha rank(delta(assets_curr/return_equity, 63))
# Parsing alpha rank(delta(assets_curr/revenue, 63))
# Parsing alpha rank(delta(assets_curr/sales, 63))
# Parsing alpha rank(delta(assets_curr/sales_growth, 63))
# Parsing alpha rank(delta(assets_curr/sales_ps, 63))
# Parsing alpha rank(delta(assets_curr/SGA_expense, 63))
# Parsing alpha rank(delta(assets_curr/working_capital, 63))
# Parsing alpha rank(delta(bookvalue_ps/capex, 63))
# Parsing alpha rank(delta(bookvalue_ps/cash, 63))
# Parsing alpha rank(delta(bookvalue_ps/cashflow, 63))
# Parsing alpha rank(delta(bookvalue_ps/cashflow_dividends, 63))
# Parsing alpha rank(delta(bookvalue_ps/cashflow_fin, 63))
# Parsing alpha rank(delta(bookvalue_ps/cashflow_invst, 63))
# Parsing alpha rank(delta(bookvalue_ps/cashflow_op, 63))
# Parsing alpha rank(delta(bookvalue_ps/cogs, 63))
# Parsing alpha rank(delta(bookvalue_ps/current_ratio, 63))
# Parsing alpha rank(delta(bookvalue_ps/debt, 63))
# Parsing alpha rank(delta(bookvalue_ps/debt_lt, 63))
# Parsing alpha rank(delta(bookvalue_ps/debt_st, 63))
# Parsing alpha rank(delta(bookvalue_ps/depre_amort, 63))
# Parsing alpha rank(delta(bookvalue_ps/EBIT, 63))
# Parsing alpha rank(delta(bookvalue_ps/EBITDA, 63))
# Parsing alpha rank(delta(bookvalue_ps/employee, 63))
# Parsing alpha rank(delta(bookvalue_ps/enterprise_value, 63))
# Function parsing alphas finished
#
#
# Function parse submissions started
# Function parse submissions finished
# Function simulating alphas started
# Simulating alpha rank(delta(est_ebit/est_netprofit_adj, 126))
# Simulating alpha rank(delta(est_netprofit_adj/est_ptp, 126))
# Simulating alpha rank(delta(bookvalue_ps/eps, 63))
# Simulating alpha rank(delta(bookvalue_ps/equity, 63))
# Simulating alpha rank(delta(bookvalue_ps/goodwill, 63))
# Simulating alpha rank(delta(bookvalue_ps/income, 63))
# Simulating alpha rank(delta(bookvalue_ps/income_beforeextra, 63))
# Simulating alpha rank(delta(bookvalue_ps/income_tax, 63))
# Simulating alpha rank(delta(bookvalue_ps/interest_expense, 63))
# Simulating alpha rank(delta(bookvalue_ps/inventory, 63))
# Simulating alpha rank(delta(bookvalue_ps/inventory_turnover, 63))
# Simulating alpha rank(delta(bookvalue_ps/invested_capital, 63))
# Simulating alpha rank(delta(bookvalue_ps/liabilities, 63))
# Simulating alpha rank(delta(bookvalue_ps/liabilities_curr, 63))
# Simulating alpha rank(delta(bookvalue_ps/operating_expense, 63))
# Simulating alpha rank(delta(bookvalue_ps/operating_income, 63))
# Simulating alpha rank(delta(bookvalue_ps/pretax_income, 63))
# Simulating alpha rank(delta(bookvalue_ps/rd_expense, 63))
# Simulating alpha rank(delta(bookvalue_ps/receivable, 63))
# Simulating alpha rank(delta(bookvalue_ps/retained_earnings, 63))
# Simulating alpha rank(delta(bookvalue_ps/return_assets, 63))
# Simulating alpha rank(delta(bookvalue_ps/return_equity, 63))
# Simulating alpha rank(delta(bookvalue_ps/revenue, 63))
# Simulating alpha rank(delta(bookvalue_ps/sales, 63))
# Simulating alpha rank(delta(bookvalue_ps/sales_growth, 63))
# Simulating alpha rank(delta(bookvalue_ps/sales_ps, 63))
# Simulating alpha rank(delta(bookvalue_ps/SGA_expense, 63))
# Simulating alpha rank(delta(bookvalue_ps/working_capital, 63))
# Simulating alpha rank(delta(capex/cash, 63))
# Simulating alpha rank(delta(capex/cashflow, 63))
# Simulating alpha rank(delta(capex/cashflow_dividends, 63))
# Simulating alpha rank(delta(capex/cashflow_fin, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/cashflow_fin, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/cashflow_fin, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/cashflow_fin, 63))
# Simulating alpha rank(delta(capex/cashflow_invst, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/cashflow_invst, 63))
# Simulating alpha rank(delta(capex/cashflow_op, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/cashflow_op, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/cashflow_op, 63))
# Simulating alpha rank(delta(capex/cogs, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/cogs, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/cogs, 63))
# Simulating alpha rank(delta(capex/current_ratio, 63))
# Simulating alpha rank(delta(capex/debt, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/debt, 63))
# Simulating alpha rank(delta(capex/debt_lt, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/debt_lt, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/debt_lt, 63))
# Simulating alpha rank(delta(capex/debt_st, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/debt_st, 63))
# Simulating alpha rank(delta(capex/depre_amort, 63))
# Simulating alpha rank(delta(capex/EBIT, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/EBIT, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/EBIT, 63))
# Simulating alpha rank(delta(capex/EBITDA, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/EBITDA, 63))
# Simulating alpha rank(delta(capex/employee, 63))
# Simulating alpha rank(delta(capex/enterprise_value, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/enterprise_value, 63))
# Simulating alpha rank(delta(capex/eps, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/eps, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/eps, 63))
# Simulating alpha rank(delta(capex/equity, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/equity, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/equity, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/equity, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/equity, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/equity, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/equity, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/equity, 63))
# Simulating alpha rank(delta(capex/goodwill, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/goodwill, 63))
# Simulating alpha rank(delta(capex/income, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/income, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/income, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/income, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/income, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/income, 63))
# Simulating alpha rank(delta(capex/income_beforeextra, 63))
# Simulating alpha rank(delta(capex/income_tax, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/income_tax, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/income_tax, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/income_tax, 63))
# Simulating alpha rank(delta(capex/interest_expense, 63))
# Simulating alpha rank(delta(capex/inventory, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/inventory, 63))
# Simulating alpha rank(delta(capex/inventory_turnover, 63))
# Simulating alpha rank(delta(capex/invested_capital, 63))
# Simulating alpha rank(delta(capex/liabilities, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/liabilities, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/liabilities, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/liabilities, 63))
# Simulating alpha rank(delta(capex/liabilities_curr, 63))
# Simulating alpha rank(delta(capex/operating_expense, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/operating_expense, 63))
# Simulating alpha rank(delta(capex/operating_income, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/operating_income, 63))
# Simulating alpha rank(delta(capex/pretax_income, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/pretax_income, 63))
# Simulating alpha rank(delta(capex/rd_expense, 63))
# Simulating alpha rank(delta(capex/receivable, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/receivable, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/receivable, 63))
# Simulating alpha rank(delta(capex/retained_earnings, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/retained_earnings, 63))
# Simulating alpha rank(delta(capex/return_assets, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/return_assets, 63))
# Simulating alpha rank(delta(capex/return_equity, 63))
# Simulating alpha rank(delta(capex/revenue, 63))
# Simulating alpha rank(delta(capex/sales, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/sales, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/sales, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/sales, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/sales, 63))
# Simulating alpha rank(delta(capex/sales_growth, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/sales_growth, 63))
# Simulating alpha rank(delta(capex/sales_ps, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/sales_ps, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(capex/sales_ps, 63))
# Simulating alpha rank(delta(capex/SGA_expense, 63))
# Simulating alpha rank(delta(capex/working_capital, 63))
# Simulating alpha rank(delta(cash/cashflow, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/cashflow, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/cashflow, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/cashflow, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/cashflow, 63))
# Simulating alpha rank(delta(cash/cashflow_dividends, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/cashflow_dividends, 63))
# Simulating alpha rank(delta(cash/cashflow_fin, 63))
# Simulating alpha rank(delta(cash/cashflow_invst, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/cashflow_invst, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/cashflow_invst, 63))
# Simulating alpha rank(delta(cash/cashflow_op, 63))
# Simulating alpha rank(delta(cash/cogs, 63))
# Too many alphas simulating
# Simulating alpha rank(delta(cash/cogs, 63))
# Simulating alpha rank(delta(cash/current_ratio, 63))
# Too many alphas simulating

# %%
import sys
import json
import string
import pandas as pd
import pymongo
from datetime import datetime, timedelta
import time
import itertools
import alpha_parser
import pymongo

config_fn = "config.json"

# %%
import sys

del sys.modules['alpha_client']

import alpha_client

# %%
with open(config_fn, 'r') as f:
    config = json.load(f)

# %%
config
# Out:
# {'mongodb_connection_string': 'mongodb://dalisa1212:kloppolk_2017@wqserver-shard-00-00-ftqza.mongodb.net:27017,wqserver-shard-00-01-ftqza.mongodb.net:27017,wqserver-shard-00-02-ftqza.mongodb.net:27017/wq?ssl=true&replicaSet=WQServer-shard-0&authSource=admin&retryWrites=true',
#  'origin': 'https://www.worldquantvrc.com/simulate',
#  'users': [{'name': 'nk',
#    'login': 'krokhmal11@mail.ru',
#    'password': 'cop_12345',
#    'xsrf': '2|0d88a38b|11fba3b3de4b36710dcc7b5e9e1b53c1|1534426416',
#    'db_base': 'alphas_base_nk',
#    'db_simulate': 'alphas_simulate_nk',
#    'db_trash': 'alphas_trash_nk',
#    'db_prod': 'alphas_prod_nk',
#    'beg_time': '',
#    'end_time': '',
#    'days off': '',
#    'proxies': {'http': 'http://bbfvti:aG0bT05OOV@185.139.215.186:24531'}},
#   {'name': 'da',
#    'login': 'dalisa1212@mail.ru',
#    'xsrf': '2|fb38ac16|5d2254a56b5d9fe3cbbeeace215a55ef|1529707760',
#    'password': 'playhard_1212',
#    'db_base': 'alphas_base_da',
#    'db_simulate': 'alphas_simulate_da',
#    'db_trash': 'alphas_trash_da',
#    'db_prod': 'alphas_prod_da',
#    'beg_time': '',
#    'end_time': '',
#    'days_off': '',
#    'proxies': {'http': 'http://ppohxc:OROarUUmzT@78.40.118.31:24531'}},
#   {'name': 'mg',
#    'login': 'nikita95borisov@mail.ru',
#    'password': 'Ð²ÐºÐ¾Ð½Ñ‚Ð°ÐºÑ‚ÐµÐ´Ð¾Ð±Ñ€Ð¾Ð¿Ð¾Ð¶Ð°Ð»Ð¾Ð²Ð°Ñ‚ÑŒ1994',
#    'xsrf': '2|0aaabecb|5053f6e633c94aaebbd44a577c19985b|1530485282',
#    'db_base': 'alphas_base_mg',
#    'db_simulate': 'alphas_simulate_mg',
#    'db_trash': 'alphas_trash_mg',
#    'db_prod': 'alphas_prod_mg',
#    'beg_time': '',
#    'end_time': '',
#    'days_off': '',
#    'proxies': {'http': 'http://bbfvti:aG0bT05OOV@185.250.151.148:24531'}}]}

# %%
user_name = 'mg'
mongo_connection_string = config['mongodb_connection_string']
origin = config['origin']
site_address = 'https://www.worldquantvrc.com'
info = [x for x in config['users'] if x['name'] == user_name]
collection_purgatory = 'alphas_purgatory'
collection_trash = 'alphas_trash'
collection_simulate = 'alphas_simulate'
collection_prod = 'alphas_prod'
login = info[0]['login']
password = info[0]['password']
xsrf = info[0]['xsrf']
proxies = info[0]['proxies']

# %%
password
# Out:
# 'Ð²ÐºÐ¾Ð½Ñ‚Ð°ÐºÑ‚ÐµÐ´Ð¾Ð±Ñ€Ð¾Ð¿Ð¾Ð¶Ð°Ð»Ð¾Ð²Ð°Ñ‚ÑŒ1994'

# %%
client = alpha_client.alpha_client(login=login, 
                                   password=password,
                                   collection_prod=collection_prod,
                                   collection_simulate=collection_simulate,
                                   collection_trash = collection_trash,
                                   collection_purgatory = collection_purgatory,
                                   mongo_connection_string = mongo_connection_string,
                                   origin=origin,
                                   xsrf=xsrf,
                                   site_address=site_address,
                                   proxies = proxies)

# %%
requestor = alpha_requestor.Request(login=login,
                                    password=password,
                                    origin=origin,
                                    xsrf=xsrf,
                                    site_address=site_address,
                                    proxies=proxies)

# %% [markdown]
# # Test

# %%
res = requestor.log_in()
cookie = res.cookies
full_cookie = requestor.build_cookie(cookie)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-759a1d303219> in <module>()
#       1 res = requestor.log_in()
#       2 cookie = res.cookies
# ----> 3 full_cookie = requestor.build_cookie(cookie)
#
# ~\Desktop\git\test\alpha_requestor.py in build_cookie(self, cookie)
#      62         result = 'django_language={}; _xsrf={}; WSSID={}; UID={}; WQCookieConsent=accepted; _gat={}; _gat_wsdevTracker={}'.format('en', self.xsrf,
#      63                                                                                                         cookie.get_dict()[
# ---> 64                                                                                                             'WSSID'],
#      65                                                                                                         cookie.get_dict()[
#      66                                                                                                             'UID'], 1,
#
# KeyError: 'WSSID'

# %%
res.content
# Out:
# b'{"error": "Login failed. Email or Password is incorrect. Your account might be locked out if you fail login again.", "result": {"captcha": false, "site_key": "6LdW2AETAAAAAEesECdVWarvokoboWt1hDwMm9M7"}, "status": false}'

# %%
mongo = pymongo.MongoClient(mongo_connection_string).wq

# %% [markdown]
# ### Simulate

# %%
alphas = pd.DataFrame(list(mongo['alphas_simulate'].find({'Status': 'InProgress', 'Executor': 'da'}).limit(10)))
ids = list(alphas['_id'])

# %%
client.simulate_alphas(cookie, ids)
# Out:
# Simulating alpha Ts_ZScore(assets/bookvalue_ps, 126)
# Simulating alpha Ts_ZScore(assets/cashflow, 126)
# Simulating alpha Ts_ZScore(assets/cashflow_fin, 126)
# Simulating alpha Ts_ZScore(assets/debt_st, 126)
# Simulating alpha Ts_ZScore(assets/EBITDA, 126)
# Simulating alpha Ts_ZScore(assets/income_tax, 126)
# Simulating alpha Ts_ZScore(assets/liabilities_curr, 126)
# Simulating alpha Ts_ZScore(assets_curr/cashflow_op, 126)
# Simulating alpha Ts_ZScore(assets_curr/employee, 126)
# Simulating alpha Ts_ZScore(assets_curr/eps, 126)

# %% [markdown]
# ### Parse

# %%
alphas = pd.DataFrame(list(mongo['alphas_purgatory'].find({'Status': 'InProgress', 'Executor': 'da'}).limit(10)))
ids = list(alphas['_id'])

# %%
client.parse_alphas(cookie, ids)
# Out:
# Parsing alpha Ts_ZScore(assets/bookvalue_ps, 126)
# {'AlphaId': ObjectId('5ba2bd594e28b32ffc20e9ab'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "Ts_ZScore(assets/bookvalue_ps, 126)", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': 'Ts_ZScore(assets/bookvalue_ps, 126)', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-19 21:19:21.177708', 'Executor': 'da', 'LogicName': 'BT-6', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 162898536}
# Parsing alpha Ts_ZScore(assets/cashflow, 126)
# {'AlphaId': ObjectId('5ba2bd594e28b32ffc20e9ae'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "Ts_ZScore(assets/cashflow, 126)", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': 'Ts_ZScore(assets/cashflow, 126)', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-19 21:19:21.178711', 'Executor': 'da', 'LogicName': 'BT-6', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 162898604}
# Parsing alpha Ts_ZScore(assets/cashflow_fin, 126)
# {'AlphaId': ObjectId('5ba2bd594e28b32ffc20e9b0'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "Ts_ZScore(assets/cashflow_fin, 126)", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': 'Ts_ZScore(assets/cashflow_fin, 126)', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-19 21:19:21.178711', 'Executor': 'da', 'LogicName': 'BT-6', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 162898630}
# Parsing alpha Ts_ZScore(assets/debt_st, 126)
# {'AlphaId': ObjectId('5ba2bd594e28b32ffc20e9b7'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "Ts_ZScore(assets/debt_st, 126)", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': 'Ts_ZScore(assets/debt_st, 126)', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-19 21:19:21.178711', 'Executor': 'da', 'LogicName': 'BT-6', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 162898677}
# Parsing alpha Ts_ZScore(assets/EBITDA, 126)
# {'AlphaId': ObjectId('5ba2bd594e28b32ffc20e9ba'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "Ts_ZScore(assets/EBITDA, 126)", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': 'Ts_ZScore(assets/EBITDA, 126)', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-19 21:19:21.179703', 'Executor': 'da', 'LogicName': 'BT-6', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 162898700}
# Parsing alpha Ts_ZScore(assets/income_tax, 126)
# {'AlphaId': ObjectId('5ba2bd594e28b32ffc20e9c2'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "Ts_ZScore(assets/income_tax, 126)", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': 'Ts_ZScore(assets/income_tax, 126)', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-19 21:19:21.179703', 'Executor': 'da', 'LogicName': 'BT-6', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 162898734}
# Parsing alpha Ts_ZScore(assets/liabilities_curr, 126)
# {'AlphaId': ObjectId('5ba2bd594e28b32ffc20e9c8'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "Ts_ZScore(assets/liabilities_curr, 126)", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': 'Ts_ZScore(assets/liabilities_curr, 126)', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-19 21:19:21.179703', 'Executor': 'da', 'LogicName': 'BT-6', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 162898759}
# Parsing alpha Ts_ZScore(assets_curr/cashflow_op, 126)
# {'AlphaId': ObjectId('5ba2bd594e28b32ffc20e9de'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "Ts_ZScore(assets_curr/cashflow_op, 126)", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': 'Ts_ZScore(assets_curr/cashflow_op, 126)', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-19 21:19:21.180708', 'Executor': 'da', 'LogicName': 'BT-6', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 162898797}
# Parsing alpha Ts_ZScore(assets_curr/employee, 126)
# {'AlphaId': ObjectId('5ba2bd594e28b32ffc20e9e7'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "Ts_ZScore(assets_curr/employee, 126)", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': 'Ts_ZScore(assets_curr/employee, 126)', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-19 21:19:21.181710', 'Executor': 'da', 'LogicName': 'BT-6', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 162898815}
# Parsing alpha Ts_ZScore(assets_curr/eps, 126)
# {'AlphaId': ObjectId('5ba2bd594e28b32ffc20e9e9'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "Ts_ZScore(assets_curr/eps, 126)", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': 'Ts_ZScore(assets_curr/eps, 126)', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-19 21:19:21.181710', 'Executor': 'da', 'LogicName': 'BT-6', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 162898888}

# %% [markdown]
# ### Submit

# %%
alphas = pd.DataFrame(list(mongo['alphas_prod'].find({'Status': 'InProgress', 'Executor': 'da'}).limit(10)))
ids = list(alphas['_id'])

# %%
client.parse_submissions(cookie, ids)
# Out:
# Parsing submission of alpha with index 162884752
# Exception occured while submission'SubmissionId'
# Parsing submission of alpha with index 162884752
# Exception occured while submission'SubmissionId'
# Parsing submission of alpha with index 162884752
# Exception occured while submission'SubmissionId'
# Parsing submission of alpha with index 162884752
# Exception occured while submission'SubmissionId'
# Parsing submission of alpha with index 162884752
# Exception occured while submission'SubmissionId'
# Too many errors, function Parse_Submission finished

# %%
requestor.log_out(cookie)
# Out:
# <Response [200]>

# %% [markdown]
# # Test

# %%
i = 0
while i < 20:
    res = requestor.log_in()
    cookie = res.cookies
    full_cookie = requestor.build_cookie(cookie)
   
    try:
        mongo = pymongo.MongoClient(mongo_connection_string).wq
        alphas = pd.DataFrame(list(mongo['alphas_simulate'].find({'Status': 'InProgress', 'Executor': 'da'}).limit(500)))
        ids = list(alphas['_id'])

    except:
        mongo = pymongo.MongoClient(mongo_connection_string).wq
        alphas = pd.DataFrame(list(mongo['alphas_simulate'].find({'Status': 'InProgress', 'Executor': 'da'}).limit(500)))
        ids = list(alphas['_id'])
    
    client.simulate_alphas(cookie, ids)
    
    try:
        mongo = pymongo.MongoClient(mongo_connection_string).wq
        alphas = pd.DataFrame(list(mongo['alphas_purgatory'].find({'Status': 'InProgress', 'Executor': 'da'}).limit(500)))
        ids = list(alphas['_id'])
    except:
        mongo = pymongo.MongoClient(mongo_connection_string).wq
        alphas = pd.DataFrame(list(mongo['alphas_purgatory'].find({'Status': 'InProgress', 'Executor': 'da'}).limit(500)))
        ids = list(alphas['_id'])
    client.parse_alphas(cookie, ids)
    
    try:
        mongo = pymongo.MongoClient(mongo_connection_string).wq
        alphas = pd.DataFrame(list(mongo['alphas_prod'].find({'Status': 'InProgress',
                                                              'Executor': 'da',
                                                              'SubmissionId': 
                                                                   {"$gte": 0}}).limit(500)))
        ids = list(alphas['_id'])
    except:
        mongo = pymongo.MongoClient(mongo_connection_string).wq
        alphas = pd.DataFrame(list(mongo['alphas_prod'].find({'Status': 'InProgress', 'Executor': 'da', "SubmissionId": {"$gte": 0}}).limit(500)))
        ids = list(alphas['_id'])
    client.parse_submissions(cookie, ids)
    
        
    requestor.log_out(cookie)
    i +=1
    print(i)
# Out:
# Simulating alpha Ts_ZScore(assets/assets_curr, 126)
# Simulating alpha Ts_ZScore(assets/bookvalue_ps, 126)
# Simulating alpha Ts_ZScore(assets/capex, 126)
# Simulating alpha Ts_ZScore(assets/cash, 126)
# Simulating alpha Ts_ZScore(assets/cashflow, 126)
# Simulating alpha Ts_ZScore(assets/cashflow_dividends, 126)
# Simulating alpha Ts_ZScore(assets/cashflow_fin, 126)
# Simulating alpha Ts_ZScore(assets/cashflow_invst, 126)
# Simulating alpha Ts_ZScore(assets/cashflow_op, 126)
# Simulating alpha Ts_ZScore(assets/cogs, 126)
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Simulating alpha Ts_ZScore(assets/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/debt, 126)
# Simulating alpha Ts_ZScore(assets/debt_lt, 126)
# Simulating alpha Ts_ZScore(assets/debt_st, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/debt_st, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/debt_st, 126)
# Simulating alpha Ts_ZScore(assets/depre_amort, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/depre_amort, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/depre_amort, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/depre_amort, 126)
# Simulating alpha Ts_ZScore(assets/EBIT, 126)
# Simulating alpha Ts_ZScore(assets/EBITDA, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/EBITDA, 126)
# Simulating alpha Ts_ZScore(assets/employee, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/employee, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/employee, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/employee, 126)
# Simulating alpha Ts_ZScore(assets/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/enterprise_value, 126)
# Simulating alpha Ts_ZScore(assets/eps, 126)
# Simulating alpha Ts_ZScore(assets/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/equity, 126)
# Simulating alpha Ts_ZScore(assets/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/goodwill, 126)
# Simulating alpha Ts_ZScore(assets/income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/income, 126)
# Simulating alpha Ts_ZScore(assets/income_beforeextra, 126)
# Simulating alpha Ts_ZScore(assets/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/income_tax, 126)
# Simulating alpha Ts_ZScore(assets/interest_expense, 126)
# Simulating alpha Ts_ZScore(assets/inventory, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/inventory, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/inventory, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/inventory, 126)
# Simulating alpha Ts_ZScore(assets/inventory_turnover, 126)
# Simulating alpha Ts_ZScore(assets/invested_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/invested_capital, 126)
# Simulating alpha Ts_ZScore(assets/liabilities, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/liabilities, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/liabilities, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/liabilities, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/liabilities, 126)
# Simulating alpha Ts_ZScore(assets/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/liabilities_curr, 126)
# Simulating alpha Ts_ZScore(assets/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/operating_expense, 126)
# Simulating alpha Ts_ZScore(assets/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/operating_income, 126)
# Simulating alpha Ts_ZScore(assets/pretax_income, 126)
# Simulating alpha Ts_ZScore(assets/rd_expense, 126)
# Simulating alpha Ts_ZScore(assets/receivable, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/receivable, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/receivable, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/receivable, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/receivable, 126)
# Simulating alpha Ts_ZScore(assets/retained_earnings, 126)
# Simulating alpha Ts_ZScore(assets/return_assets, 126)
# Simulating alpha Ts_ZScore(assets/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/return_equity, 126)
# Simulating alpha Ts_ZScore(assets/revenue, 126)
# Simulating alpha Ts_ZScore(assets/sales, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/sales, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/sales, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/sales, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/sales, 126)
# Simulating alpha Ts_ZScore(assets/sales_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/sales_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/sales_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/sales_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/sales_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/sales_ps, 126)
# Simulating alpha Ts_ZScore(assets/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/SGA_expense, 126)
# Simulating alpha Ts_ZScore(assets/working_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/working_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/working_capital, 126)
# Simulating alpha Ts_ZScore(assets_curr/bookvalue_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/bookvalue_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/bookvalue_ps, 126)
# Simulating alpha Ts_ZScore(assets_curr/capex, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/capex, 126)
# Simulating alpha Ts_ZScore(assets_curr/cash, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cash, 126)
# Simulating alpha Ts_ZScore(assets_curr/cashflow, 126)
# Simulating alpha Ts_ZScore(assets_curr/cashflow_dividends, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cashflow_dividends, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cashflow_dividends, 126)
# Simulating alpha Ts_ZScore(assets_curr/cashflow_fin, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cashflow_fin, 126)
# Simulating alpha Ts_ZScore(assets_curr/cashflow_invst, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cashflow_invst, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cashflow_invst, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cashflow_invst, 126)
# Simulating alpha Ts_ZScore(assets_curr/cashflow_op, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cashflow_op, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cashflow_op, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cashflow_op, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cashflow_op, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cashflow_op, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cashflow_op, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cashflow_op, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cashflow_op, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cashflow_op, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cashflow_op, 126)
# Simulating alpha Ts_ZScore(assets_curr/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cogs, 126)
# Simulating alpha Ts_ZScore(assets_curr/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/current_ratio, 126)
# Simulating alpha Ts_ZScore(assets_curr/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/debt, 126)
# Simulating alpha Ts_ZScore(assets_curr/debt_lt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/debt_lt, 126)
# Simulating alpha Ts_ZScore(assets_curr/debt_st, 126)
# Simulating alpha Ts_ZScore(assets_curr/EBIT, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/EBIT, 126)
# Simulating alpha Ts_ZScore(assets_curr/EBITDA, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/EBITDA, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/EBITDA, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/EBITDA, 126)
# Simulating alpha Ts_ZScore(assets_curr/employee, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/employee, 126)
# Simulating alpha Ts_ZScore(assets_curr/eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/eps, 126)
# Simulating alpha Ts_ZScore(assets_curr/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/equity, 126)
# Simulating alpha Ts_ZScore(assets_curr/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/goodwill, 126)
# Simulating alpha Ts_ZScore(assets_curr/income, 126)
# Simulating alpha Ts_ZScore(assets_curr/income_beforeextra, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/income_beforeextra, 126)
# Simulating alpha Ts_ZScore(assets_curr/income_tax, 126)
# Simulating alpha Ts_ZScore(assets_curr/interest_expense, 126)
# Simulating alpha Ts_ZScore(assets_curr/inventory_turnover, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/inventory_turnover, 126)
# Simulating alpha Ts_ZScore(assets_curr/invested_capital, 126)
# Simulating alpha Ts_ZScore(assets_curr/liabilities, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/liabilities, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/liabilities, 126)
# Simulating alpha Ts_ZScore(assets_curr/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/liabilities_curr, 126)
# Simulating alpha Ts_ZScore(assets_curr/operating_expense, 126)
# Simulating alpha Ts_ZScore(assets_curr/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/operating_income, 126)
# Simulating alpha Ts_ZScore(assets_curr/pretax_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/pretax_income, 126)
# Simulating alpha Ts_ZScore(assets_curr/rd_expense, 126)
# Simulating alpha Ts_ZScore(assets_curr/receivable, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/receivable, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/receivable, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/receivable, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/receivable, 126)
# Simulating alpha Ts_ZScore(assets_curr/retained_earnings, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/retained_earnings, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/retained_earnings, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/retained_earnings, 126)
# Simulating alpha Ts_ZScore(assets_curr/return_assets, 126)
# Simulating alpha Ts_ZScore(assets_curr/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/return_equity, 126)
# Simulating alpha Ts_ZScore(assets_curr/revenue, 126)
# Simulating alpha Ts_ZScore(assets_curr/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/sales_growth, 126)
# Simulating alpha Ts_ZScore(assets_curr/sales_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/sales_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/sales_ps, 126)
# Simulating alpha Ts_ZScore(assets_curr/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/SGA_expense, 126)
# Simulating alpha Ts_ZScore(assets_curr/working_capital, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/capex, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/cash, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/cash, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/cash, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/cash, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/cash, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/cash, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/cash, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/cashflow, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/cashflow, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/cashflow_fin, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/cashflow_op, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/cogs, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/debt, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/debt_lt, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/employee, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/employee, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/employee, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/employee, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/employee, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/employee, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/employee, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/enterprise_value, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/equity, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/income, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/income_beforeextra, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/income_beforeextra, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/income_tax, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/interest_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/interest_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/interest_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/interest_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/interest_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/interest_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/interest_expense, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/inventory, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/inventory, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/inventory, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/liabilities, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/liabilities, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/liabilities, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/liabilities, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/liabilities, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/liabilities, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/liabilities, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/liabilities_curr, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/operating_income, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/pretax_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/pretax_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/pretax_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/pretax_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/pretax_income, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/rd_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/rd_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/rd_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/rd_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/rd_expense, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/receivable, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/receivable, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/receivable, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/receivable, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/receivable, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/receivable, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/receivable, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/receivable, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/retained_earnings, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/retained_earnings, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/return_assets, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/return_assets, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/return_assets, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/return_assets, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/revenue, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/revenue, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/sales, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/sales, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/sales, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/sales_growth, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/sales_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/sales_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/sales_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/sales_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/sales_ps, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/SGA_expense, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/working_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/working_capital, 126)
# Simulating alpha Ts_ZScore(capex/cashflow, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/cashflow, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/cashflow, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/cashflow, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/cashflow, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/cashflow, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/cashflow, 126)
# Simulating alpha Ts_ZScore(capex/cashflow_dividends, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/cashflow_dividends, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/cashflow_dividends, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/cashflow_dividends, 126)
# Simulating alpha Ts_ZScore(capex/cashflow_invst, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/cashflow_invst, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/cashflow_invst, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/cashflow_invst, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/cashflow_invst, 126)
# Simulating alpha Ts_ZScore(capex/cashflow_op, 126)
# Simulating alpha Ts_ZScore(capex/current_ratio, 126)
# Simulating alpha Ts_ZScore(capex/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/debt, 126)
# Simulating alpha Ts_ZScore(capex/debt_st, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/debt_st, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/debt_st, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/debt_st, 126)
# Simulating alpha Ts_ZScore(capex/depre_amort, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/depre_amort, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/depre_amort, 126)
# Simulating alpha Ts_ZScore(capex/EBITDA, 126)
# Simulating alpha Ts_ZScore(capex/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/enterprise_value, 126)
# Simulating alpha Ts_ZScore(capex/eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/eps, 126)
# Simulating alpha Ts_ZScore(capex/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/goodwill, 126)
# Simulating alpha Ts_ZScore(capex/income_beforeextra, 126)
# Simulating alpha Ts_ZScore(capex/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/income_tax, 126)
# Simulating alpha Ts_ZScore(capex/liabilities_curr, 126)
# Simulating alpha Ts_ZScore(capex/operating_expense, 126)
# Simulating alpha Ts_ZScore(capex/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/operating_income, 126)
# Simulating alpha Ts_ZScore(capex/rd_expense, 126)
# Simulating alpha Ts_ZScore(capex/return_assets, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/return_assets, 126)
# Simulating alpha Ts_ZScore(capex/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/return_equity, 126)
# Simulating alpha Ts_ZScore(capex/sales_growth, 126)
# Simulating alpha Ts_ZScore(capex/sales_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/sales_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/sales_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/sales_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/sales_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/sales_ps, 126)
# Simulating alpha Ts_ZScore(capex/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/SGA_expense, 126)
# Simulating alpha Ts_ZScore(capex/working_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/working_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/working_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/working_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/working_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/working_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/working_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/working_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/working_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/working_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/working_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/working_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/working_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/working_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/working_capital, 126)
# Simulating alpha Ts_ZScore(cash/cashflow, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/cashflow, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/cashflow, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/cashflow, 126)
# Simulating alpha Ts_ZScore(cash/cashflow_dividends, 126)
# Simulating alpha Ts_ZScore(cash/cashflow_op, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/cashflow_op, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/cashflow_op, 126)
# Simulating alpha Ts_ZScore(cash/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/cogs, 126)
# Simulating alpha Ts_ZScore(cash/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/debt, 126)
# Simulating alpha Ts_ZScore(cash/debt_lt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/debt_lt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/debt_lt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/debt_lt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/debt_lt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/debt_lt, 126)
# Simulating alpha Ts_ZScore(cash/depre_amort, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/depre_amort, 126)
# Simulating alpha Ts_ZScore(cash/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/enterprise_value, 126)
# Simulating alpha Ts_ZScore(cash/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/equity, 126)
# Simulating alpha Ts_ZScore(cash/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/goodwill, 126)
# Simulating alpha Ts_ZScore(cash/income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/income, 126)
# Simulating alpha Ts_ZScore(cash/income_tax, 126)
# Simulating alpha Ts_ZScore(cash/liabilities, 126)
# Simulating alpha Ts_ZScore(cash/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/liabilities_curr, 126)
# Simulating alpha Ts_ZScore(cash/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/operating_expense, 126)
# Simulating alpha Ts_ZScore(cash/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/operating_income, 126)
# Simulating alpha Ts_ZScore(cash/pretax_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/pretax_income, 126)
# Simulating alpha Ts_ZScore(cash/retained_earnings, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/retained_earnings, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/retained_earnings, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/retained_earnings, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/retained_earnings, 126)
# Simulating alpha Ts_ZScore(cash/return_assets, 126)
# Simulating alpha Ts_ZScore(cash/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/sales_growth, 126)
# Simulating alpha Ts_ZScore(cash/sales_ps, 126)
# Simulating alpha Ts_ZScore(cash/SGA_expense, 126)
# Simulating alpha Ts_ZScore(cashflow/cashflow_fin, 126)
# Simulating alpha Ts_ZScore(cashflow/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/cogs, 126)
# Simulating alpha Ts_ZScore(cashflow/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/current_ratio, 126)
# Simulating alpha Ts_ZScore(cashflow/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/debt, 126)
# Simulating alpha Ts_ZScore(cashflow/debt_st, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/debt_st, 126)
# Simulating alpha Ts_ZScore(cashflow/EBITDA, 126)
# Simulating alpha Ts_ZScore(cashflow/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/enterprise_value, 126)
# Simulating alpha Ts_ZScore(cashflow/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/equity, 126)
# Too many alphas simulating
# ...
# Parsing alpha Ts_ZScore(cashflow_fin/EBITDA, 126)
# Parsing alpha Ts_ZScore(cashflow_fin/employee, 126)
# Parsing alpha Ts_ZScore(cashflow_fin/enterprise_value, 126)
# Parsing alpha Ts_ZScore(cashflow_fin/eps, 126)
# Parsing alpha Ts_ZScore(cashflow_fin/income, 126)
# Parsing alpha Ts_ZScore(cashflow_fin/income_beforeextra, 126)
# Parsing alpha Ts_ZScore(cashflow_fin/income_tax, 126)
# Parsing alpha Ts_ZScore(cashflow_fin/inventory, 126)
# Parsing alpha Ts_ZScore(cashflow_fin/invested_capital, 126)
# Parsing alpha Ts_ZScore(cashflow_fin/liabilities, 126)
# Parsing alpha Ts_ZScore(cashflow_fin/liabilities_curr, 126)
# Parsing alpha Ts_ZScore(cashflow_fin/operating_expense, 126)
# Parsing alpha Ts_ZScore(cashflow_fin/operating_income, 126)
# Parsing alpha Ts_ZScore(cashflow_fin/rd_expense, 126)
# Parsing alpha Ts_ZScore(cashflow_fin/revenue, 126)
# Parsing alpha Ts_ZScore(cashflow_fin/sales, 126)
# Parsing alpha Ts_ZScore(cashflow_fin/sales_growth, 126)
# Parsing alpha Ts_ZScore(cashflow_fin/sales_ps, 126)
# Parsing alpha Ts_ZScore(cashflow_fin/SGA_expense, 126)
# Parsing alpha Ts_ZScore(cashflow_fin/working_capital, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/cashflow_op, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/cogs, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/current_ratio, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/debt_lt, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/debt_st, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/depre_amort, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/EBIT, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/employee, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/enterprise_value, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/eps, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/goodwill, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/income, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/income_beforeextra, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/income_tax, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/interest_expense, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/inventory, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/liabilities, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/liabilities_curr, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/operating_expense, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/operating_income, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/rd_expense, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/receivable, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/retained_earnings, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/return_equity, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/sales, 126)
# Parsing alpha Ts_ZScore(cashflow_invst/sales_ps, 126)
# Parsing alpha Ts_ZScore(cashflow_op/cogs, 126)
# Parsing alpha Ts_ZScore(cashflow_op/debt, 126)
# Parsing alpha Ts_ZScore(cashflow_op/debt_lt, 126)
# Parsing alpha Ts_ZScore(cashflow_op/debt_st, 126)
# Parsing alpha Ts_ZScore(cashflow_op/depre_amort, 126)
# Parsing alpha Ts_ZScore(cashflow_op/EBIT, 126)
# Parsing alpha Ts_ZScore(cashflow_op/EBITDA, 126)
# Parsing alpha Ts_ZScore(cashflow_op/employee, 126)
# Parsing alpha Ts_ZScore(cashflow_op/enterprise_value, 126)
# AlphaId e08bf0aae4d34bfa95f7d19e1f95ac07
# SubmissionId 53189703
# Parsing alpha Ts_ZScore(cashflow_op/eps, 126)
# Parsing alpha Ts_ZScore(cashflow_op/equity, 126)
# Parsing alpha Ts_ZScore(cashflow_op/goodwill, 126)
# Parsing alpha Ts_ZScore(cashflow_op/income, 126)
# Parsing alpha Ts_ZScore(cashflow_op/income_beforeextra, 126)
# Parsing alpha Ts_ZScore(cashflow_op/income_tax, 126)
# Parsing alpha Ts_ZScore(cashflow_op/interest_expense, 126)
# Parsing alpha Ts_ZScore(cashflow_op/inventory, 126)
# Parsing alpha Ts_ZScore(cashflow_op/inventory_turnover, 126)
# Parsing alpha Ts_ZScore(cashflow_op/pretax_income, 126)
# Parsing alpha Ts_ZScore(cashflow_op/rd_expense, 126)
# Parsing alpha Ts_ZScore(cashflow_op/receivable, 126)
# Parsing alpha Ts_ZScore(cashflow_op/retained_earnings, 126)
# Parsing alpha Ts_ZScore(cashflow_op/revenue, 126)
# Parsing alpha Ts_ZScore(cashflow_op/sales, 126)
# Parsing alpha Ts_ZScore(cashflow_op/sales_ps, 126)
# Parsing alpha Ts_ZScore(cashflow_op/SGA_expense, 126)
# Local exception occured Expecting value: line 1 column 1 (char 0)
# Parsing alpha Ts_ZScore(cashflow_op/SGA_expense, 126)
# Parsing alpha Ts_ZScore(cogs/debt, 126)
# Parsing alpha Ts_ZScore(cogs/debt_st, 126)
# Parsing alpha Ts_ZScore(cogs/depre_amort, 126)
# Parsing alpha Ts_ZScore(cogs/EBITDA, 126)
# Parsing alpha Ts_ZScore(cogs/employee, 126)
# Parsing alpha Ts_ZScore(cogs/enterprise_value, 126)
# AlphaId e8d25a46ce624d5d964cc9b5f05ec24e
# SubmissionId 53190289
# Parsing alpha Ts_ZScore(cogs/equity, 126)
# Parsing alpha Ts_ZScore(cogs/goodwill, 126)
# Parsing alpha Ts_ZScore(cogs/income_tax, 126)
# Parsing alpha Ts_ZScore(cogs/inventory, 126)
# Parsing alpha Ts_ZScore(cogs/inventory_turnover, 126)
# Parsing alpha Ts_ZScore(cogs/invested_capital, 126)
# Parsing alpha Ts_ZScore(cogs/liabilities, 126)
# Parsing alpha Ts_ZScore(cogs/operating_expense, 126)
# Parsing alpha Ts_ZScore(cogs/operating_income, 126)
# Parsing alpha Ts_ZScore(cogs/rd_expense, 126)
# Parsing alpha Ts_ZScore(cogs/receivable, 126)
# Parsing alpha Ts_ZScore(cogs/retained_earnings, 126)
# Parsing alpha Ts_ZScore(cogs/return_assets, 126)
# Parsing alpha Ts_ZScore(cogs/return_equity, 126)
# Parsing alpha Ts_ZScore(cogs/revenue, 126)
# Parsing alpha Ts_ZScore(cogs/sales_growth, 126)
# Parsing alpha Ts_ZScore(cogs/SGA_expense, 126)
# Parsing alpha Ts_ZScore(current_ratio/debt, 126)
# Parsing alpha Ts_ZScore(current_ratio/debt_lt, 126)
# Parsing alpha Ts_ZScore(current_ratio/debt_st, 126)
# Parsing alpha Ts_ZScore(current_ratio/depre_amort, 126)
# Parsing alpha Ts_ZScore(current_ratio/EBIT, 126)
# Parsing alpha Ts_ZScore(current_ratio/EBITDA, 126)
# Parsing alpha Ts_ZScore(current_ratio/equity, 126)
# Parsing alpha Ts_ZScore(current_ratio/goodwill, 126)
# Parsing alpha Ts_ZScore(current_ratio/income, 126)
# Parsing alpha Ts_ZScore(current_ratio/income_beforeextra, 126)
# Parsing alpha Ts_ZScore(current_ratio/interest_expense, 126)
# Parsing alpha Ts_ZScore(current_ratio/inventory_turnover, 126)
# Parsing alpha Ts_ZScore(current_ratio/liabilities_curr, 126)
# Parsing alpha Ts_ZScore(current_ratio/pretax_income, 126)
# Parsing alpha Ts_ZScore(current_ratio/rd_expense, 126)
# Parsing alpha Ts_ZScore(current_ratio/return_equity, 126)
# Parsing alpha Ts_ZScore(current_ratio/revenue, 126)
# Parsing alpha Ts_ZScore(current_ratio/sales, 126)
# Parsing alpha Ts_ZScore(current_ratio/sales_growth, 126)
# Parsing alpha Ts_ZScore(current_ratio/SGA_expense, 126)
# Parsing alpha Ts_ZScore(current_ratio/working_capital, 126)
# Parsing alpha Ts_ZScore(debt/debt_lt, 126)
# Parsing alpha Ts_ZScore(debt/depre_amort, 126)
# Parsing alpha Ts_ZScore(debt/EBIT, 126)
# Parsing alpha Ts_ZScore(debt/EBITDA, 126)
# Parsing alpha Ts_ZScore(debt/eps, 126)
# Parsing alpha Ts_ZScore(debt/equity, 126)
# Parsing alpha Ts_ZScore(debt/goodwill, 126)
# Parsing alpha Ts_ZScore(debt/income_beforeextra, 126)
# Parsing alpha Ts_ZScore(debt/income_tax, 126)
# Parsing alpha Ts_ZScore(debt/inventory, 126)
# Parsing alpha Ts_ZScore(debt/inventory_turnover, 126)
# Parsing alpha Ts_ZScore(debt/operating_income, 126)
# Parsing alpha Ts_ZScore(debt/rd_expense, 126)
# Parsing alpha Ts_ZScore(debt/receivable, 126)
# Parsing alpha Ts_ZScore(debt/return_assets, 126)
# Parsing alpha Ts_ZScore(debt/sales, 126)
# Parsing alpha Ts_ZScore(debt/sales_growth, 126)
# Parsing alpha Ts_ZScore(debt/sales_ps, 126)
# Parsing alpha Ts_ZScore(debt/SGA_expense, 126)
# Parsing alpha Ts_ZScore(debt_lt/debt_st, 126)
# Parsing alpha Ts_ZScore(debt_lt/EBIT, 126)
# Parsing alpha Ts_ZScore(debt_lt/employee, 126)
# Parsing alpha Ts_ZScore(debt_lt/equity, 126)
# Parsing alpha Ts_ZScore(debt_lt/goodwill, 126)
# Parsing alpha Ts_ZScore(debt_lt/income_tax, 126)
# Parsing alpha Ts_ZScore(debt_lt/interest_expense, 126)
# Parsing alpha Ts_ZScore(debt_lt/inventory_turnover, 126)
# Parsing alpha Ts_ZScore(debt_lt/liabilities, 126)
# Parsing alpha Ts_ZScore(debt_lt/liabilities_curr, 126)
# Parsing alpha Ts_ZScore(debt_lt/operating_expense, 126)
# Parsing alpha Ts_ZScore(debt_lt/operating_income, 126)
# Parsing alpha Ts_ZScore(debt_lt/pretax_income, 126)
# Parsing alpha Ts_ZScore(debt_lt/rd_expense, 126)
# Parsing alpha Ts_ZScore(debt_lt/receivable, 126)
# Parsing alpha Ts_ZScore(debt_lt/return_assets, 126)
# Parsing alpha Ts_ZScore(debt_lt/return_equity, 126)
# Parsing alpha Ts_ZScore(debt_lt/sales, 126)
# Parsing alpha Ts_ZScore(debt_lt/sales_growth, 126)
# Parsing alpha Ts_ZScore(debt_lt/sales_ps, 126)
# Parsing alpha Ts_ZScore(debt_lt/SGA_expense, 126)
# Parsing alpha Ts_ZScore(debt_lt/working_capital, 126)
# Parsing alpha Ts_ZScore(debt_st/EBIT, 126)
# Parsing alpha Ts_ZScore(debt_st/equity, 126)
# Parsing alpha Ts_ZScore(debt_st/income, 126)
# Parsing alpha Ts_ZScore(debt_st/income_beforeextra, 126)
# Parsing alpha Ts_ZScore(debt_st/interest_expense, 126)
# Parsing alpha Ts_ZScore(debt_st/inventory, 126)
# Parsing alpha Ts_ZScore(debt_st/invested_capital, 126)
# Parsing alpha Ts_ZScore(debt_st/liabilities_curr, 126)
# Parsing alpha Ts_ZScore(debt_st/operating_expense, 126)
# Parsing alpha Ts_ZScore(debt_st/operating_income, 126)
# Parsing alpha Ts_ZScore(debt_st/pretax_income, 126)
# Parsing alpha Ts_ZScore(debt_st/rd_expense, 126)
# Parsing alpha Ts_ZScore(debt_st/receivable, 126)
# Parsing alpha Ts_ZScore(debt_st/retained_earnings, 126)
# Parsing alpha Ts_ZScore(debt_st/return_equity, 126)
# Parsing alpha Ts_ZScore(debt_st/revenue, 126)
# Parsing alpha Ts_ZScore(debt_st/sales_growth, 126)
# Parsing alpha Ts_ZScore(debt_st/sales_ps, 126)
# Parsing alpha Ts_ZScore(debt_st/working_capital, 126)
# Parsing alpha Ts_ZScore(depre_amort/EBIT, 126)
# Parsing alpha Ts_ZScore(depre_amort/enterprise_value, 126)
# AlphaId c42ab1714ef1469d90d94ad2599d8eaf
# SubmissionId 53192146
# Parsing alpha Ts_ZScore(depre_amort/income, 126)
# Parsing alpha Ts_ZScore(depre_amort/income_beforeextra, 126)
# Parsing alpha Ts_ZScore(depre_amort/income_tax, 126)
# Parsing alpha Ts_ZScore(depre_amort/interest_expense, 126)
# Parsing alpha Ts_ZScore(depre_amort/inventory, 126)
# Parsing alpha Ts_ZScore(depre_amort/inventory_turnover, 126)
# Parsing alpha Ts_ZScore(depre_amort/invested_capital, 126)
# Parsing alpha Ts_ZScore(depre_amort/liabilities, 126)
# Parsing alpha Ts_ZScore(depre_amort/operating_income, 126)
# Parsing alpha Ts_ZScore(depre_amort/rd_expense, 126)
# Parsing alpha Ts_ZScore(depre_amort/receivable, 126)
# Parsing alpha Ts_ZScore(depre_amort/retained_earnings, 126)
# Parsing alpha Ts_ZScore(depre_amort/return_assets, 126)
# Parsing alpha Ts_ZScore(depre_amort/return_equity, 126)
# Parsing alpha Ts_ZScore(depre_amort/revenue, 126)
# Parsing alpha Ts_ZScore(depre_amort/sales, 126)
# Parsing alpha Ts_ZScore(depre_amort/sales_growth, 126)
# Parsing alpha Ts_ZScore(depre_amort/sales_ps, 126)
# Parsing alpha Ts_ZScore(depre_amort/working_capital, 126)
# Parsing alpha Ts_ZScore(EBIT/EBITDA, 126)
# Parsing alpha Ts_ZScore(EBIT/employee, 126)
# Parsing alpha Ts_ZScore(EBIT/enterprise_value, 126)
# Parsing alpha Ts_ZScore(EBIT/eps, 126)
# Parsing alpha Ts_ZScore(EBIT/equity, 126)
# Parsing alpha Ts_ZScore(EBIT/income, 126)
# Parsing alpha Ts_ZScore(EBIT/inventory, 126)
# Parsing alpha Ts_ZScore(EBIT/inventory_turnover, 126)
# Parsing alpha Ts_ZScore(EBIT/liabilities_curr, 126)
# Parsing alpha Ts_ZScore(EBIT/operating_expense, 126)
# Parsing alpha Ts_ZScore(EBIT/sales, 126)
# Parsing alpha Ts_ZScore(EBIT/sales_ps, 126)
# Parsing alpha Ts_ZScore(EBIT/SGA_expense, 126)
# Parsing alpha Ts_ZScore(EBIT/working_capital, 126)
# Parsing alpha Ts_ZScore(EBITDA/employee, 126)
# Parsing alpha Ts_ZScore(EBITDA/equity, 126)
# Parsing alpha Ts_ZScore(EBITDA/goodwill, 126)
# Parsing alpha Ts_ZScore(EBITDA/income, 126)
# Parsing alpha Ts_ZScore(EBITDA/income_beforeextra, 126)
# Parsing alpha Ts_ZScore(EBITDA/income_tax, 126)
# Parsing alpha Ts_ZScore(EBITDA/interest_expense, 126)
# Parsing alpha Ts_ZScore(EBITDA/inventory, 126)
# Parsing alpha Ts_ZScore(EBITDA/invested_capital, 126)
# Parsing alpha Ts_ZScore(EBITDA/liabilities_curr, 126)
# Parsing alpha Ts_ZScore(EBITDA/operating_income, 126)
# Parsing alpha Ts_ZScore(EBITDA/receivable, 126)
# Parsing alpha Ts_ZScore(EBITDA/retained_earnings, 126)
# Parsing alpha Ts_ZScore(EBITDA/return_assets, 126)
# Parsing alpha Ts_ZScore(EBITDA/return_equity, 126)
# Parsing alpha Ts_ZScore(EBITDA/revenue, 126)
# Parsing alpha Ts_ZScore(EBITDA/sales, 126)
# Parsing alpha Ts_ZScore(EBITDA/sales_growth, 126)
# Parsing alpha Ts_ZScore(EBITDA/sales_ps, 126)
# Parsing alpha Ts_ZScore(EBITDA/SGA_expense, 126)
# Parsing alpha Ts_ZScore(EBITDA/working_capital, 126)
# Parsing alpha Ts_ZScore(employee/enterprise_value, 126)
# AlphaId f6ba0478269c4e9c895550f9cfd49ee2
# SubmissionId 53193304
# Parsing alpha Ts_ZScore(employee/equity, 126)
# Parsing alpha Ts_ZScore(employee/goodwill, 126)
# Parsing alpha Ts_ZScore(employee/income, 126)
# Parsing alpha Ts_ZScore(employee/income_tax, 126)
# Parsing alpha Ts_ZScore(employee/inventory, 126)
# Parsing alpha Ts_ZScore(employee/liabilities, 126)
# Parsing alpha Ts_ZScore(employee/liabilities_curr, 126)
# Parsing alpha Ts_ZScore(employee/operating_income, 126)
# Parsing alpha Ts_ZScore(employee/rd_expense, 126)
# Parsing alpha Ts_ZScore(employee/retained_earnings, 126)
# Parsing alpha Ts_ZScore(employee/return_assets, 126)
# Parsing alpha Ts_ZScore(employee/return_equity, 126)
# Parsing alpha Ts_ZScore(employee/revenue, 126)
# Parsing alpha Ts_ZScore(employee/sales, 126)
# Parsing alpha Ts_ZScore(employee/sales_growth, 126)
# Parsing alpha Ts_ZScore(employee/working_capital, 126)
# Parsing alpha Ts_ZScore(enterprise_value/goodwill, 126)
# Parsing alpha Ts_ZScore(enterprise_value/income, 126)
# Parsing alpha Ts_ZScore(enterprise_value/income_beforeextra, 126)
# Parsing alpha Ts_ZScore(enterprise_value/income_tax, 126)
# Parsing alpha Ts_ZScore(enterprise_value/interest_expense, 126)
# Parsing alpha Ts_ZScore(enterprise_value/inventory, 126)
# Parsing alpha Ts_ZScore(enterprise_value/liabilities, 126)
# Parsing alpha Ts_ZScore(enterprise_value/operating_income, 126)
# Parsing alpha Ts_ZScore(enterprise_value/pretax_income, 126)
# Parsing alpha Ts_ZScore(enterprise_value/rd_expense, 126)
# Parsing alpha Ts_ZScore(enterprise_value/receivable, 126)
# Parsing alpha Ts_ZScore(enterprise_value/return_assets, 126)
# Parsing alpha Ts_ZScore(enterprise_value/return_equity, 126)
# Parsing alpha Ts_ZScore(enterprise_value/sales_growth, 126)
# Parsing alpha Ts_ZScore(enterprise_value/SGA_expense, 126)
# Parsing alpha Ts_ZScore(eps/equity, 126)
# Parsing alpha Ts_ZScore(eps/income, 126)
# Parsing alpha Ts_ZScore(eps/income_beforeextra, 126)
# Parsing alpha Ts_ZScore(eps/income_tax, 126)
# Parsing alpha Ts_ZScore(eps/interest_expense, 126)
# Parsing alpha Ts_ZScore(eps/inventory, 126)
# Parsing alpha Ts_ZScore(eps/invested_capital, 126)
# Parsing alpha Ts_ZScore(eps/liabilities, 126)
# Parsing alpha Ts_ZScore(eps/operating_expense, 126)
# Parsing alpha Ts_ZScore(eps/operating_income, 126)
# Parsing alpha Ts_ZScore(eps/pretax_income, 126)
# Parsing alpha Ts_ZScore(eps/receivable, 126)
# Parsing alpha Ts_ZScore(eps/return_equity, 126)
# Parsing alpha Ts_ZScore(eps/revenue, 126)
# Parsing alpha Ts_ZScore(eps/sales, 126)
# Parsing alpha Ts_ZScore(eps/sales_growth, 126)
# Parsing alpha Ts_ZScore(eps/sales_ps, 126)
# Parsing alpha Ts_ZScore(eps/SGA_expense, 126)
# Parsing alpha Ts_ZScore(eps/working_capital, 126)
# Parsing alpha Ts_ZScore(equity/income_tax, 126)
# Parsing submission of alpha with index 162929829
# {'error': 'Unknown Request Id', 'result': None, 'status': False}
# Exception occured while submissionname 'res' is not defined
# Parsing submission of alpha with index 162929829
# {'error': 'Unknown Request Id', 'result': None, 'status': False}
# Exception occured while submissionname 'res' is not defined
# Parsing submission of alpha with index 162929829
# {'error': 'Unknown Request Id', 'result': None, 'status': False}
# Exception occured while submissionname 'res' is not defined
# Parsing submission of alpha with index 162929829
# {'error': 'Unknown Request Id', 'result': None, 'status': False}
# Exception occured while submissionname 'res' is not defined
# Parsing submission of alpha with index 162929829
# {'error': 'Unknown Request Id', 'result': None, 'status': False}
# Exception occured while submissionname 'res' is not defined
# Too many errors, function Parse_Submission finished
# 20

# %% [markdown]
# #
