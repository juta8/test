# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import json
import yaml
import os
import time
import glob
import sys
import re
import tqdm
import PIL

import clipboard as clip
from datetime import datetime, timedelta
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import h5py
import ctypes
import pyperclip
from pynput.keyboard import Key, Controller


sns.set() # matplotlib defaults
pd.set_option('display.float_format', lambda x: '%.4f' % x)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
pd.options.display.max_colwidth = 100

import sys
sys.path.append('../src/')

import warnings
warnings.filterwarnings('ignore')

from random import randint
import win32api, win32con, time
import pyautogui
import pyscreenshot as ImageGrab
import random
import pymongo
import requests

from bson.objectid import ObjectId
from dateutil.parser import parse as parse_date
# Out:
# C:\Users\krokh\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# <style>.container { width:100% !important; }</style>

# %%
import alpha_client
import alpha_creator
import alpha_parser
import alpha_requestor

# %%
import sys

del sys.modules['alpha_client']

import alpha_client

# %%
import sys

del sys.modules['alpha_requestor']

import alpha_requestor

# %%
import sys

del sys.modules['alpha_parser']

import alpha_parser

# %%
xsrf = '2|fb38ac16|5d2254a56b5d9fe3cbbeeace215a55ef|1529707760'
site_address = 'https://www.worldquantvrc.com'
origin = 'https://www.worldquantvrc.com'
mongo_connection_string = 'mongodb://dalisa1212:kloppolk_2017@wqserver-shard-00-00-ftqza.mongodb.net:27017,wqserver-shard-00-01-ftqza.mongodb.net:27017,wqserver-shard-00-02-ftqza.mongodb.net:27017/wq?ssl=true&replicaSet=WQServer-shard-0&authSource=admin&retryWrites=true'
collection_purgatory = 'alphas_purgatory'
collection_trash = 'alphas_trash'
collection_simulate = 'alphas_simulate'
collection_prod = 'alphas_prod'
login = 'dalisa1212@mail.ru'
password = 'playhard1212'

# %%
client = alpha_client.alpha_client(login=login, 
                                   password=password,
                                   collection_prod=collection_prod,
                                   collection_simulate=collection_simulate,
                                   collection_trash = collection_trash,
                                   collection_purgatory = collection_purgatory,
                                   mongo_connection_string = mongo_connection_string,
                                   origin=origin,
                                   xsrf=xsrf,
                                   site_address=site_address)

# %%
requestor = alpha_requestor.Request(login=login,
                                    password=password,
                                    origin=origin,
                                    xsrf=xsrf,
                                    site_address=site_address)

# %% [markdown]
# # Login

# %%
res = requestor.log_in()
cookie = res.cookies
full_cookie = requestor.build_cookie(cookie)

# %%
ids = pd.DataFrame(list(mongo['alphas_simulate'].find({'Status': 'InProgress', 'Executor': 'da'}).limit(1500)))
ids = list(ids['_id'])

# %%
import sys

del sys.modules['alpha_client']

import alpha_client

client = alpha_client.alpha_client(login=login, 
                                   password=password,
                                   collection_prod=collection_prod,
                                   collection_simulate=collection_simulate,
                                   collection_trash = collection_trash,
                                   collection_purgatory = collection_purgatory,
                                   mongo_connection_string = mongo_connection_string,
                                   origin=origin,
                                   xsrf=xsrf,
                                   site_address=site_address)

# %%
client.parse_alphas(cookie=cookie, ids=ids)
# Out:
# Parsing alpha (cogs > delay(cogs, 126)) ? 1 : -1
# {'error': '', 'result': [{'BookSize': 20000000.0, 'DrawDown': 1.02, 'Fitness': 0.57, 'LongCount': 1359, 'Margin': 6.2, 'PnL': 113828.87170000003, 'Returns': 1.59, 'Sharpe': 1.03, 'ShortCount': 1373, 'TurnOver': 5.13, 'Year': '2012', 'YearId': '2012'}, {'BookSize': 20000000.0, 'DrawDown': 0.75, 'Fitness': 0.25, 'LongCount': 1415, 'Margin': 3.89, 'PnL': 85018.67490000006, 'Returns': 0.84, 'Sharpe': 0.57, 'ShortCount': 1322, 'TurnOver': 4.34, 'Year': '2013', 'YearId': '2013'}, {'BookSize': 20000000.0, 'DrawDown': 0.41, 'Fitness': 3.15, 'LongCount': 1497, 'Margin': 21.86, 'PnL': 474816.4274000001, 'Returns': 4.71, 'Sharpe': 3.01, 'ShortCount': 1240, 'TurnOver': 4.31, 'Year': '2014', 'YearId': '2014'}, {'BookSize': 20000000.0, 'DrawDown': 0.39, 'Fitness': 0.86, 'LongCount': 1352, 'Margin': 9.1, 'PnL': 202538.85834000004, 'Returns': 2.01, 'Sharpe': 1.28, 'ShortCount': 1346, 'TurnOver': 4.42, 'Year': '2015', 'YearId': '2015'}, {'BookSize': 20000000.0, 'DrawDown': 1.58, 'Fitness': -0.89, 'LongCount': 1392, 'Margin': -11.14, 'PnL': -236322.4455, 'Returns': -2.34, 'Sharpe': -1.2, 'ShortCount': 1297, 'TurnOver': 4.21, 'Year': '2016', 'YearId': '2016'}, {'BookSize': 20000000.0, 'DrawDown': 0.13, 'Fitness': 5.89, 'LongCount': 1540, 'Margin': 26.46, 'PnL': 129767.2125, 'Returns': 6.12, 'Sharpe': 5.12, 'ShortCount': 1254, 'TurnOver': 4.63, 'Year': '2017', 'YearId': '2017'}, {'BookSize': 20000000.0, 'DrawDown': 1.58, 'Fitness': 0.56, 'LongCount': 1411, 'Margin': 6.98, 'PnL': 769647.5993400004, 'Returns': 1.55, 'Sharpe': 0.95, 'ShortCount': 1309, 'TurnOver': 4.45, 'Year': '2012-2017', 'YearId': 'TOTAL'}], 'status': True}
# Debug (cogs > delay(cogs, 126)) ? 1 : -1
# Debug {'AlphaId': ObjectId('5b995a884e28b34de0ebdfe9'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "(cogs > delay(cogs, 126)) ? 1 : -1", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': '(cogs > delay(cogs, 126)) ? 1 : -1', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-12 18:27:20.430362', 'Executor': 'mg', 'LogicName': 'A-20', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 139615873}
# Debug delete
# Parsing alpha (current_ratio > delay(current_ratio, 126)) ? 1 : -1
# {'error': '', 'result': [{'BookSize': 20000000.0, 'DrawDown': 1.21, 'Fitness': -0.02, 'LongCount': 1019, 'Margin': -0.88, 'PnL': -14570.766900000097, 'Returns': -0.2, 'Sharpe': -0.12, 'ShortCount': 1279, 'TurnOver': 4.65, 'Year': '2012', 'YearId': '2012'}, {'BookSize': 20000000.0, 'DrawDown': 0.51, 'Fitness': 1.02, 'LongCount': 1021, 'Margin': 10.57, 'PnL': 209900.53180000017, 'Returns': 2.08, 'Sharpe': 1.4, 'ShortCount': 1295, 'TurnOver': 3.94, 'Year': '2013', 'YearId': '2013'}, {'BookSize': 20000000.0, 'DrawDown': 1.14, 'Fitness': -0.3, 'LongCount': 997, 'Margin': -5.05, 'PnL': -101235.53400000001, 'Returns': -1.0, 'Sharpe': -0.6, 'ShortCount': 1306, 'TurnOver': 3.97, 'Year': '2014', 'YearId': '2014'}, {'BookSize': 20000000.0, 'DrawDown': 0.91, 'Fitness': -0.46, 'LongCount': 950, 'Margin': -6.66, 'PnL': -137776.48750000008, 'Returns': -1.37, 'Sharpe': -0.79, 'ShortCount': 1327, 'TurnOver': 4.1, 'Year': '2015', 'YearId': '2015'}, {'BookSize': 20000000.0, 'DrawDown': 2.62, 'Fitness': -2.16, 'LongCount': 885, 'Margin': -21.33, 'PnL': -419402.5243999998, 'Returns': -4.16, 'Sharpe': -2.09, 'ShortCount': 1375, 'TurnOver': 3.9, 'Year': '2016', 'YearId': '2016'}, {'BookSize': 20000000.0, 'DrawDown': 0.36, 'Fitness': -1.66, 'LongCount': 891, 'Margin': -14.12, 'PnL': -62491.58659999999, 'Returns': -2.95, 'Sharpe': -1.97, 'ShortCount': 1383, 'TurnOver': 4.17, 'Year': '2017', 'YearId': '2017'}, {'BookSize': 20000000.0, 'DrawDown': 3.98, 'Fitness': -0.32, 'LongCount': 968, 'Margin': -5.19, 'PnL': -525576.3675999996, 'Returns': -1.06, 'Sharpe': -0.62, 'ShortCount': 1321, 'TurnOver': 4.08, 'Year': '2012-2017', 'YearId': 'TOTAL'}], 'status': True}
# Debug (current_ratio > delay(current_ratio, 126)) ? 1 : -1
# Debug {'AlphaId': ObjectId('5b995a884e28b34de0ebdfea'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "(current_ratio > delay(current_ratio, 126)) ? 1 : -1", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': '(current_ratio > delay(current_ratio, 126)) ? 1 : -1', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-12 18:27:20.430362', 'Executor': 'mg', 'LogicName': 'A-20', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 139615893}
# Debug delete
# Parsing alpha (debt > delay(debt, 126)) ? 1 : -1
# {'error': '', 'result': [{'BookSize': 20000000.0, 'DrawDown': 0.78, 'Fitness': 0.37, 'LongCount': 949, 'Margin': 5.62, 'PnL': 88500.21100000001, 'Returns': 1.24, 'Sharpe': 0.69, 'ShortCount': 1730, 'TurnOver': 4.4, 'Year': '2012', 'YearId': '2012'}, {'BookSize': 20000000.0, 'DrawDown': 0.71, 'Fitness': -0.06, 'LongCount': 949, 'Margin': -1.69, 'PnL': -31525.184355299967, 'Returns': -0.31, 'Sharpe': -0.22, 'ShortCount': 1699, 'TurnOver': 3.7, 'Year': '2013', 'YearId': '2013'}, {'BookSize': 20000000.0, 'DrawDown': 1.21, 'Fitness': -0.73, 'LongCount': 988, 'Margin': -10.16, 'PnL': -186783.09259999974, 'Returns': -1.85, 'Sharpe': -1.02, 'ShortCount': 1684, 'TurnOver': 3.65, 'Year': '2014', 'YearId': '2014'}, {'BookSize': 20000000.0, 'DrawDown': 1.95, 'Fitness': -0.93, 'LongCount': 996, 'Margin': -11.75, 'PnL': -226986.182, 'Returns': -2.25, 'Sharpe': -1.21, 'ShortCount': 1669, 'TurnOver': 3.83, 'Year': '2015', 'YearId': '2015'}, {'BookSize': 20000000.0, 'DrawDown': 3.44, 'Fitness': -2.85, 'LongCount': 985, 'Margin': -27.43, 'PnL': -494405.1406299999, 'Returns': -4.9, 'Sharpe': -2.44, 'ShortCount': 1674, 'TurnOver': 3.58, 'Year': '2016', 'YearId': '2016'}, {'BookSize': 20000000.0, 'DrawDown': 0.79, 'Fitness': -2.16, 'LongCount': 919, 'Margin': -20.07, 'PnL': -80339.30899999996, 'Returns': -3.79, 'Sharpe': -2.16, 'ShortCount': 1749, 'TurnOver': 3.78, 'Year': '2017', 'YearId': '2017'}, {'BookSize': 20000000.0, 'DrawDown': 5.33, 'Fitness': -0.74, 'LongCount': 972, 'Margin': -9.9, 'PnL': -931538.6975852994, 'Returns': -1.88, 'Sharpe': -1.05, 'ShortCount': 1691, 'TurnOver': 3.8, 'Year': '2012-2017', 'YearId': 'TOTAL'}], 'status': True}
# Debug (debt > delay(debt, 126)) ? 1 : -1
# Debug {'AlphaId': ObjectId('5b995a884e28b34de0ebdfeb'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "(debt > delay(debt, 126)) ? 1 : -1", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': '(debt > delay(debt, 126)) ? 1 : -1', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-12 18:27:20.431359', 'Executor': 'mg', 'LogicName': 'A-20', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 139615921}
# Debug delete
# Parsing alpha (debt_lt > delay(debt_lt, 126)) ? 1 : -1
# {'error': '', 'result': [{'BookSize': 20000000.0, 'DrawDown': 0.57, 'Fitness': 0.42, 'LongCount': 995, 'Margin': 5.99, 'PnL': 87354.41739999999, 'Returns': 1.22, 'Sharpe': 0.76, 'ShortCount': 1743, 'TurnOver': 4.07, 'Year': '2012', 'YearId': '2012'}, {'BookSize': 20000000.0, 'DrawDown': 0.88, 'Fitness': -0.1, 'LongCount': 1017, 'Margin': -2.45, 'PnL': -41821.88509999997, 'Returns': -0.41, 'Sharpe': -0.29, 'ShortCount': 1704, 'TurnOver': 3.38, 'Year': '2013', 'YearId': '2013'}, {'BookSize': 20000000.0, 'DrawDown': 0.73, 'Fitness': -0.02, 'LongCount': 1062, 'Margin': -1.0, 'PnL': -17033.954700000028, 'Returns': -0.17, 'Sharpe': -0.1, 'ShortCount': 1687, 'TurnOver': 3.37, 'Year': '2014', 'YearId': '2014'}, {'BookSize': 20000000.0, 'DrawDown': 1.15, 'Fitness': -0.0, 'LongCount': 1103, 'Margin': -0.06, 'PnL': -1099.7979999999873, 'Returns': -0.01, 'Sharpe': -0.01, 'ShortCount': 1662, 'TurnOver': 3.45, 'Year': '2015', 'YearId': '2015'}, {'BookSize': 20000000.0, 'DrawDown': 2.07, 'Fitness': -1.43, 'LongCount': 1083, 'Margin': -17.1, 'PnL': -289233.8506099998, 'Returns': -2.87, 'Sharpe': -1.55, 'ShortCount': 1666, 'TurnOver': 3.36, 'Year': '2016', 'YearId': '2016'}, {'BookSize': 20000000.0, 'DrawDown': 0.65, 'Fitness': -0.92, 'LongCount': 1024, 'Margin': -12.09, 'PnL': -45290.476000000024, 'Returns': -2.14, 'Sharpe': -1.18, 'ShortCount': 1743, 'TurnOver': 3.53, 'Year': '2017', 'YearId': '2017'}, {'BookSize': 20000000.0, 'DrawDown': 2.61, 'Fitness': -0.16, 'LongCount': 1054, 'Margin': -3.54, 'PnL': -307125.5470099999, 'Returns': -0.62, 'Sharpe': -0.37, 'ShortCount': 1692, 'TurnOver': 3.49, 'Year': '2012-2017', 'YearId': 'TOTAL'}], 'status': True}
# Debug (debt_lt > delay(debt_lt, 126)) ? 1 : -1
# Debug {'AlphaId': ObjectId('5b995a884e28b34de0ebdfec'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "(debt_lt > delay(debt_lt, 126)) ? 1 : -1", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': '(debt_lt > delay(debt_lt, 126)) ? 1 : -1', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-12 18:27:20.431359', 'Executor': 'mg', 'LogicName': 'A-20', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 139615950}
# Debug delete
# Parsing alpha (debt_st > delay(debt_st, 126)) ? 1 : -1
# {'error': '', 'result': [{'BookSize': 20000000.0, 'DrawDown': 1.0, 'Fitness': 0.02, 'LongCount': 872, 'Margin': 0.69, 'PnL': 10950.006999999963, 'Returns': 0.15, 'Sharpe': 0.09, 'ShortCount': 1767, 'TurnOver': 4.45, 'Year': '2012', 'YearId': '2012'}, {'BookSize': 20000000.0, 'DrawDown': 0.33, 'Fitness': 1.62, 'LongCount': 851, 'Margin': 14.88, 'PnL': 282211.46050000004, 'Returns': 2.8, 'Sharpe': 1.88, 'ShortCount': 1775, 'TurnOver': 3.76, 'Year': '2013', 'YearId': '2013'}, {'BookSize': 20000000.0, 'DrawDown': 0.93, 'Fitness': -0.26, 'LongCount': 861, 'Margin': -4.55, 'PnL': -85037.0691, 'Returns': -0.84, 'Sharpe': -0.55, 'ShortCount': 1775, 'TurnOver': 3.71, 'Year': '2014', 'YearId': '2014'}, {'BookSize': 20000000.0, 'DrawDown': 2.04, 'Fitness': -1.74, 'LongCount': 836, 'Margin': -16.89, 'PnL': -326838.28859999997, 'Returns': -3.24, 'Sharpe': -1.89, 'ShortCount': 1773, 'TurnOver': 3.84, 'Year': '2015', 'YearId': '2015'}, {'BookSize': 20000000.0, 'DrawDown': 2.88, 'Fitness': -2.29, 'LongCount': 877, 'Margin': -20.1, 'PnL': -364379.1698000007, 'Returns': -3.61, 'Sharpe': -2.29, 'ShortCount': 1722, 'TurnOver': 3.6, 'Year': '2016', 'YearId': '2016'}, {'BookSize': 20000000.0, 'DrawDown': 0.23, 'Fitness': 0.16, 'LongCount': 848, 'Margin': 3.34, 'PnL': 13634.286599999994, 'Returns': 0.64, 'Sharpe': 0.4, 'ShortCount': 1734, 'TurnOver': 3.85, 'Year': '2017', 'YearId': '2017'}, {'BookSize': 20000000.0, 'DrawDown': 4.65, 'Fitness': -0.29, 'LongCount': 858, 'Margin': -4.94, 'PnL': -469458.77340000134, 'Returns': -0.95, 'Sharpe': -0.59, 'ShortCount': 1761, 'TurnOver': 3.84, 'Year': '2012-2017', 'YearId': 'TOTAL'}], 'status': True}
# Debug (debt_st > delay(debt_st, 126)) ? 1 : -1
# Debug {'AlphaId': ObjectId('5b995a884e28b34de0ebdfed'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "(debt_st > delay(debt_st, 126)) ? 1 : -1", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': '(debt_st > delay(debt_st, 126)) ? 1 : -1', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-12 18:27:20.431359', 'Executor': 'mg', 'LogicName': 'A-20', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 139615957}
# Debug delete

# %%
client.simulate_alphas(cookie, ids)
# Out:
# Simulating alpha Ts_ZScore(assets/assets_curr, 126)
# Simulating alpha Ts_ZScore(assets/bookvalue_ps, 126)
# Simulating alpha Ts_ZScore(assets/capex, 126)
# Simulating alpha Ts_ZScore(assets/cash, 126)
# Simulating alpha Ts_ZScore(assets/cashflow, 126)
# Simulating alpha Ts_ZScore(assets/cashflow_dividends, 126)
# Simulating alpha Ts_ZScore(assets/cashflow_fin, 126)
# Simulating alpha Ts_ZScore(assets/cashflow_invst, 126)
# Simulating alpha Ts_ZScore(assets/cashflow_op, 126)
# Simulating alpha Ts_ZScore(assets/cogs, 126)
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/current_ratio, 126)
# Simulating alpha Ts_ZScore(assets/debt, 126)
# Simulating alpha Ts_ZScore(assets/debt_lt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/debt_lt, 126)
# Simulating alpha Ts_ZScore(assets/debt_st, 126)
# Simulating alpha Ts_ZScore(assets/depre_amort, 126)
# Simulating alpha Ts_ZScore(assets/EBIT, 126)
# Simulating alpha Ts_ZScore(assets/EBITDA, 126)
# Simulating alpha Ts_ZScore(assets/employee, 126)
# Simulating alpha Ts_ZScore(assets/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/enterprise_value, 126)
# Simulating alpha Ts_ZScore(assets/eps, 126)
# Simulating alpha Ts_ZScore(assets/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/equity, 126)
# Simulating alpha Ts_ZScore(assets/goodwill, 126)
# Simulating alpha Ts_ZScore(assets/income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/income, 126)
# Simulating alpha Ts_ZScore(assets/income_beforeextra, 126)
# Simulating alpha Ts_ZScore(assets/income_tax, 126)
# Simulating alpha Ts_ZScore(assets/interest_expense, 126)
# Simulating alpha Ts_ZScore(assets/inventory, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/inventory, 126)
# Simulating alpha Ts_ZScore(assets/inventory_turnover, 126)
# Simulating alpha Ts_ZScore(assets/invested_capital, 126)
# Simulating alpha Ts_ZScore(assets/liabilities, 126)
# Simulating alpha Ts_ZScore(assets/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/liabilities_curr, 126)
# Simulating alpha Ts_ZScore(assets/operating_expense, 126)
# Simulating alpha Ts_ZScore(assets/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/operating_income, 126)
# Simulating alpha Ts_ZScore(assets/pretax_income, 126)
# Simulating alpha Ts_ZScore(assets/rd_expense, 126)
# Simulating alpha Ts_ZScore(assets/receivable, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/receivable, 126)
# Simulating alpha Ts_ZScore(assets/retained_earnings, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/retained_earnings, 126)
# Simulating alpha Ts_ZScore(assets/return_assets, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/return_assets, 126)
# Simulating alpha Ts_ZScore(assets/return_equity, 126)
# Simulating alpha Ts_ZScore(assets/revenue, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/revenue, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/revenue, 126)
# Simulating alpha Ts_ZScore(assets/sales, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/sales, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/sales, 126)
# Simulating alpha Ts_ZScore(assets/sales_growth, 126)
# Simulating alpha Ts_ZScore(assets/sales_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/sales_ps, 126)
# Simulating alpha Ts_ZScore(assets/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets/SGA_expense, 126)
# Simulating alpha Ts_ZScore(assets/working_capital, 126)
# Simulating alpha Ts_ZScore(assets_curr/bookvalue_ps, 126)
# Simulating alpha Ts_ZScore(assets_curr/capex, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/capex, 126)
# Simulating alpha Ts_ZScore(assets_curr/cash, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cash, 126)
# Simulating alpha Ts_ZScore(assets_curr/cashflow, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cashflow, 126)
# Simulating alpha Ts_ZScore(assets_curr/cashflow_dividends, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cashflow_dividends, 126)
# Simulating alpha Ts_ZScore(assets_curr/cashflow_fin, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cashflow_fin, 126)
# Simulating alpha Ts_ZScore(assets_curr/cashflow_invst, 126)
# Simulating alpha Ts_ZScore(assets_curr/cashflow_op, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cashflow_op, 126)
# Simulating alpha Ts_ZScore(assets_curr/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/cogs, 126)
# Simulating alpha Ts_ZScore(assets_curr/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/current_ratio, 126)
# Simulating alpha Ts_ZScore(assets_curr/debt, 126)
# Simulating alpha Ts_ZScore(assets_curr/debt_lt, 126)
# Simulating alpha Ts_ZScore(assets_curr/debt_st, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/debt_st, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/debt_st, 126)
# Simulating alpha Ts_ZScore(assets_curr/depre_amort, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/depre_amort, 126)
# Simulating alpha Ts_ZScore(assets_curr/EBIT, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/EBIT, 126)
# Simulating alpha Ts_ZScore(assets_curr/EBITDA, 126)
# Simulating alpha Ts_ZScore(assets_curr/employee, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/employee, 126)
# Simulating alpha Ts_ZScore(assets_curr/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/enterprise_value, 126)
# Simulating alpha Ts_ZScore(assets_curr/eps, 126)
# Simulating alpha Ts_ZScore(assets_curr/equity, 126)
# Simulating alpha Ts_ZScore(assets_curr/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/goodwill, 126)
# Simulating alpha Ts_ZScore(assets_curr/income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/income, 126)
# Simulating alpha Ts_ZScore(assets_curr/income_beforeextra, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/income_beforeextra, 126)
# Simulating alpha Ts_ZScore(assets_curr/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/income_tax, 126)
# Simulating alpha Ts_ZScore(assets_curr/interest_expense, 126)
# Simulating alpha Ts_ZScore(assets_curr/inventory, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/inventory, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/inventory, 126)
# Simulating alpha Ts_ZScore(assets_curr/inventory_turnover, 126)
# Simulating alpha Ts_ZScore(assets_curr/invested_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/invested_capital, 126)
# Simulating alpha Ts_ZScore(assets_curr/liabilities, 126)
# Simulating alpha Ts_ZScore(assets_curr/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/liabilities_curr, 126)
# Simulating alpha Ts_ZScore(assets_curr/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/operating_expense, 126)
# Simulating alpha Ts_ZScore(assets_curr/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/operating_income, 126)
# Simulating alpha Ts_ZScore(assets_curr/pretax_income, 126)
# Simulating alpha Ts_ZScore(assets_curr/rd_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/rd_expense, 126)
# Simulating alpha Ts_ZScore(assets_curr/receivable, 126)
# Simulating alpha Ts_ZScore(assets_curr/retained_earnings, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/retained_earnings, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/retained_earnings, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/retained_earnings, 126)
# Simulating alpha Ts_ZScore(assets_curr/return_assets, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/return_assets, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/return_assets, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/return_assets, 126)
# Simulating alpha Ts_ZScore(assets_curr/return_equity, 126)
# Simulating alpha Ts_ZScore(assets_curr/revenue, 126)
# Simulating alpha Ts_ZScore(assets_curr/sales, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/sales, 126)
# Simulating alpha Ts_ZScore(assets_curr/sales_growth, 126)
# Simulating alpha Ts_ZScore(assets_curr/sales_ps, 126)
# Simulating alpha Ts_ZScore(assets_curr/SGA_expense, 126)
# Simulating alpha Ts_ZScore(assets_curr/working_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(assets_curr/working_capital, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/capex, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/cash, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/cash, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/cash, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/cash, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/cashflow, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/cashflow, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/cashflow, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/cashflow_dividends, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/cashflow_fin, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/cashflow_invst, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/cashflow_op, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/cashflow_op, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/cogs, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/current_ratio, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/debt, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/debt_lt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/debt_lt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/debt_lt, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/debt_st, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/debt_st, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/depre_amort, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/depre_amort, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/EBIT, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/EBIT, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/EBITDA, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/EBITDA, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/employee, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/enterprise_value, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/eps, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/equity, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/goodwill, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/income, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/income_beforeextra, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/income_beforeextra, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/income_beforeextra, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/income_tax, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/interest_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/interest_expense, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/inventory, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/inventory, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/inventory_turnover, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/invested_capital, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/liabilities, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/liabilities, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/liabilities, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/liabilities_curr, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/operating_expense, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/operating_income, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/pretax_income, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/rd_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/rd_expense, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/receivable, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/retained_earnings, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/return_assets, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/return_assets, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/return_equity, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/revenue, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/revenue, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/sales, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/sales, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(bookvalue_ps/sales_growth, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/sales_ps, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/SGA_expense, 126)
# Simulating alpha Ts_ZScore(bookvalue_ps/working_capital, 126)
# Simulating alpha Ts_ZScore(capex/cash, 126)
# Simulating alpha Ts_ZScore(capex/cashflow, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/cashflow, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/cashflow, 126)
# Simulating alpha Ts_ZScore(capex/cashflow_dividends, 126)
# Simulating alpha Ts_ZScore(capex/cashflow_fin, 126)
# Simulating alpha Ts_ZScore(capex/cashflow_invst, 126)
# Simulating alpha Ts_ZScore(capex/cashflow_op, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/cashflow_op, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/cashflow_op, 126)
# Simulating alpha Ts_ZScore(capex/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/cogs, 126)
# Simulating alpha Ts_ZScore(capex/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/current_ratio, 126)
# Simulating alpha Ts_ZScore(capex/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/debt, 126)
# Simulating alpha Ts_ZScore(capex/debt_lt, 126)
# Simulating alpha Ts_ZScore(capex/debt_st, 126)
# Simulating alpha Ts_ZScore(capex/depre_amort, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/depre_amort, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/depre_amort, 126)
# Simulating alpha Ts_ZScore(capex/EBIT, 126)
# Simulating alpha Ts_ZScore(capex/EBITDA, 126)
# Simulating alpha Ts_ZScore(capex/employee, 126)
# Simulating alpha Ts_ZScore(capex/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/enterprise_value, 126)
# Simulating alpha Ts_ZScore(capex/eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/eps, 126)
# Simulating alpha Ts_ZScore(capex/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/equity, 126)
# Simulating alpha Ts_ZScore(capex/goodwill, 126)
# Simulating alpha Ts_ZScore(capex/income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/income, 126)
# Simulating alpha Ts_ZScore(capex/income_beforeextra, 126)
# Simulating alpha Ts_ZScore(capex/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/income_tax, 126)
# Simulating alpha Ts_ZScore(capex/interest_expense, 126)
# Simulating alpha Ts_ZScore(capex/inventory, 126)
# Simulating alpha Ts_ZScore(capex/inventory_turnover, 126)
# Simulating alpha Ts_ZScore(capex/invested_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/invested_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/invested_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/invested_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/invested_capital, 126)
# Simulating alpha Ts_ZScore(capex/liabilities, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/liabilities, 126)
# Simulating alpha Ts_ZScore(capex/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/liabilities_curr, 126)
# Simulating alpha Ts_ZScore(capex/operating_expense, 126)
# Simulating alpha Ts_ZScore(capex/operating_income, 126)
# Simulating alpha Ts_ZScore(capex/pretax_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/pretax_income, 126)
# Simulating alpha Ts_ZScore(capex/rd_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/rd_expense, 126)
# Simulating alpha Ts_ZScore(capex/receivable, 126)
# Simulating alpha Ts_ZScore(capex/retained_earnings, 126)
# Simulating alpha Ts_ZScore(capex/return_assets, 126)
# Simulating alpha Ts_ZScore(capex/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/return_equity, 126)
# Simulating alpha Ts_ZScore(capex/revenue, 126)
# Simulating alpha Ts_ZScore(capex/sales, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/sales, 126)
# Simulating alpha Ts_ZScore(capex/sales_growth, 126)
# Simulating alpha Ts_ZScore(capex/sales_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/sales_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/sales_ps, 126)
# Simulating alpha Ts_ZScore(capex/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(capex/SGA_expense, 126)
# Simulating alpha Ts_ZScore(capex/working_capital, 126)
# Simulating alpha Ts_ZScore(cash/cashflow, 126)
# Simulating alpha Ts_ZScore(cash/cashflow_dividends, 126)
# Simulating alpha Ts_ZScore(cash/cashflow_fin, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/cashflow_fin, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/cashflow_fin, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/cashflow_fin, 126)
# Simulating alpha Ts_ZScore(cash/cashflow_invst, 126)
# Simulating alpha Ts_ZScore(cash/cashflow_op, 126)
# Simulating alpha Ts_ZScore(cash/cogs, 126)
# Simulating alpha Ts_ZScore(cash/current_ratio, 126)
# Simulating alpha Ts_ZScore(cash/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/debt, 126)
# Simulating alpha Ts_ZScore(cash/debt_lt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/debt_lt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/debt_lt, 126)
# Simulating alpha Ts_ZScore(cash/debt_st, 126)
# Simulating alpha Ts_ZScore(cash/depre_amort, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/depre_amort, 126)
# Simulating alpha Ts_ZScore(cash/EBIT, 126)
# Simulating alpha Ts_ZScore(cash/EBITDA, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/EBITDA, 126)
# Simulating alpha Ts_ZScore(cash/employee, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/employee, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/employee, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/employee, 126)
# Simulating alpha Ts_ZScore(cash/enterprise_value, 126)
# Simulating alpha Ts_ZScore(cash/eps, 126)
# Simulating alpha Ts_ZScore(cash/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/equity, 126)
# Simulating alpha Ts_ZScore(cash/goodwill, 126)
# Simulating alpha Ts_ZScore(cash/income, 126)
# Simulating alpha Ts_ZScore(cash/income_beforeextra, 126)
# Simulating alpha Ts_ZScore(cash/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/income_tax, 126)
# Simulating alpha Ts_ZScore(cash/interest_expense, 126)
# Simulating alpha Ts_ZScore(cash/inventory, 126)
# Simulating alpha Ts_ZScore(cash/inventory_turnover, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/inventory_turnover, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/inventory_turnover, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/inventory_turnover, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/inventory_turnover, 126)
# Simulating alpha Ts_ZScore(cash/invested_capital, 126)
# Simulating alpha Ts_ZScore(cash/liabilities, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/liabilities, 126)
# Simulating alpha Ts_ZScore(cash/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/liabilities_curr, 126)
# Simulating alpha Ts_ZScore(cash/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/operating_expense, 126)
# Simulating alpha Ts_ZScore(cash/operating_income, 126)
# Simulating alpha Ts_ZScore(cash/pretax_income, 126)
# Simulating alpha Ts_ZScore(cash/rd_expense, 126)
# Simulating alpha Ts_ZScore(cash/receivable, 126)
# Simulating alpha Ts_ZScore(cash/retained_earnings, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/retained_earnings, 126)
# Simulating alpha Ts_ZScore(cash/return_assets, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/return_assets, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/return_assets, 126)
# Simulating alpha Ts_ZScore(cash/return_equity, 126)
# Simulating alpha Ts_ZScore(cash/revenue, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/revenue, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/revenue, 126)
# Simulating alpha Ts_ZScore(cash/sales, 126)
# Simulating alpha Ts_ZScore(cash/sales_growth, 126)
# Simulating alpha Ts_ZScore(cash/sales_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/sales_ps, 126)
# Simulating alpha Ts_ZScore(cash/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cash/SGA_expense, 126)
# Simulating alpha Ts_ZScore(cash/working_capital, 126)
# Simulating alpha Ts_ZScore(cashflow/cashflow_dividends, 126)
# Simulating alpha Ts_ZScore(cashflow/cashflow_fin, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/cashflow_fin, 126)
# Simulating alpha Ts_ZScore(cashflow/cashflow_invst, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/cashflow_invst, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/cashflow_invst, 126)
# Simulating alpha Ts_ZScore(cashflow/cashflow_op, 126)
# Simulating alpha Ts_ZScore(cashflow/cogs, 126)
# Simulating alpha Ts_ZScore(cashflow/current_ratio, 126)
# Simulating alpha Ts_ZScore(cashflow/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/debt, 126)
# Simulating alpha Ts_ZScore(cashflow/debt_lt, 126)
# Simulating alpha Ts_ZScore(cashflow/debt_st, 126)
# Simulating alpha Ts_ZScore(cashflow/depre_amort, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/depre_amort, 126)
# Simulating alpha Ts_ZScore(cashflow/EBIT, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/EBIT, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/EBIT, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/EBIT, 126)
# Simulating alpha Ts_ZScore(cashflow/EBITDA, 126)
# Simulating alpha Ts_ZScore(cashflow/employee, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/employee, 126)
# Simulating alpha Ts_ZScore(cashflow/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/enterprise_value, 126)
# Simulating alpha Ts_ZScore(cashflow/eps, 126)
# Simulating alpha Ts_ZScore(cashflow/equity, 126)
# Simulating alpha Ts_ZScore(cashflow/goodwill, 126)
# Simulating alpha Ts_ZScore(cashflow/income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/income, 126)
# Simulating alpha Ts_ZScore(cashflow/income_beforeextra, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/income_beforeextra, 126)
# Simulating alpha Ts_ZScore(cashflow/income_tax, 126)
# Simulating alpha Ts_ZScore(cashflow/interest_expense, 126)
# Simulating alpha Ts_ZScore(cashflow/inventory, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/inventory, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/inventory, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/inventory, 126)
# Simulating alpha Ts_ZScore(cashflow/inventory_turnover, 126)
# Simulating alpha Ts_ZScore(cashflow/invested_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/invested_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/invested_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/invested_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/invested_capital, 126)
# Simulating alpha Ts_ZScore(cashflow/liabilities, 126)
# Simulating alpha Ts_ZScore(cashflow/liabilities_curr, 126)
# Simulating alpha Ts_ZScore(cashflow/operating_expense, 126)
# Simulating alpha Ts_ZScore(cashflow/operating_income, 126)
# Simulating alpha Ts_ZScore(cashflow/pretax_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/pretax_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/pretax_income, 126)
# Simulating alpha Ts_ZScore(cashflow/rd_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/rd_expense, 126)
# Simulating alpha Ts_ZScore(cashflow/receivable, 126)
# Simulating alpha Ts_ZScore(cashflow/retained_earnings, 126)
# Simulating alpha Ts_ZScore(cashflow/return_assets, 126)
# Simulating alpha Ts_ZScore(cashflow/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/return_equity, 126)
# Simulating alpha Ts_ZScore(cashflow/revenue, 126)
# Simulating alpha Ts_ZScore(cashflow/sales, 126)
# Simulating alpha Ts_ZScore(cashflow/sales_growth, 126)
# Simulating alpha Ts_ZScore(cashflow/sales_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow/sales_ps, 126)
# Simulating alpha Ts_ZScore(cashflow/SGA_expense, 126)
# Simulating alpha Ts_ZScore(cashflow/working_capital, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/cashflow_fin, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/cashflow_fin, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/cashflow_invst, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/cashflow_invst, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/cashflow_op, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/cogs, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/current_ratio, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/debt, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/debt_lt, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/debt_st, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/debt_st, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/depre_amort, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/EBIT, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/EBIT, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/EBITDA, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/EBITDA, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/employee, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/employee, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/enterprise_value, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/eps, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/equity, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/goodwill, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/income, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/income_beforeextra, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/income_tax, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/interest_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/interest_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/interest_expense, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/inventory, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/inventory, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/inventory_turnover, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/invested_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/invested_capital, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/liabilities, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/liabilities, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/liabilities, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/liabilities_curr, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/operating_expense, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/operating_income, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/pretax_income, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/rd_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/rd_expense, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/receivable, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/retained_earnings, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/return_assets, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/return_assets, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/return_equity, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/revenue, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/revenue, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/sales, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/sales, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/sales, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/sales_growth, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/sales_ps, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_dividends/SGA_expense, 126)
# Simulating alpha Ts_ZScore(cashflow_dividends/working_capital, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/cashflow_invst, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/cashflow_invst, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/cashflow_op, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/cashflow_op, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/cogs, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/current_ratio, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/debt, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/debt_lt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/debt_lt, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/debt_st, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/debt_st, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/depre_amort, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/EBIT, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/EBIT, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/EBIT, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/EBITDA, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/employee, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/employee, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/employee, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/enterprise_value, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/enterprise_value, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/eps, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/equity, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/goodwill, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/income, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/income_beforeextra, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/income_beforeextra, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/income_tax, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/interest_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/interest_expense, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/inventory, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/inventory, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/inventory, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/inventory_turnover, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/invested_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/invested_capital, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/liabilities, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/liabilities_curr, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/operating_expense, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/operating_income, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/pretax_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/pretax_income, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/rd_expense, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/receivable, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/receivable, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/receivable, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/retained_earnings, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/retained_earnings, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/return_assets, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/return_equity, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/revenue, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/sales, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/sales, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/sales_growth, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/sales_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/sales_ps, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/SGA_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/SGA_expense, 126)
# Simulating alpha Ts_ZScore(cashflow_fin/working_capital, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_fin/working_capital, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/cashflow_op, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/cogs, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/cogs, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/current_ratio, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/debt, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/debt_lt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/debt_lt, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/debt_st, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/debt_st, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/depre_amort, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/EBIT, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/EBITDA, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/EBITDA, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/employee, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/employee, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/employee, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/enterprise_value, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/eps, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/equity, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/goodwill, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/income, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/income_beforeextra, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/income_tax, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/interest_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/interest_expense, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/inventory, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/inventory, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/inventory_turnover, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/inventory_turnover, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/invested_capital, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/liabilities, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/liabilities, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/liabilities_curr, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/operating_expense, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/operating_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/operating_income, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/pretax_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/pretax_income, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/rd_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/rd_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/rd_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/rd_expense, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/receivable, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/retained_earnings, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/return_assets, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/return_assets, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/return_equity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/return_equity, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/revenue, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/revenue, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/sales, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/sales, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/sales, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/sales_growth, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_invst/sales_growth, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/sales_ps, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/SGA_expense, 126)
# Simulating alpha Ts_ZScore(cashflow_invst/working_capital, 126)
# Simulating alpha Ts_ZScore(cashflow_op/cogs, 126)
# Simulating alpha Ts_ZScore(cashflow_op/current_ratio, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/current_ratio, 126)
# Simulating alpha Ts_ZScore(cashflow_op/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/debt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/debt, 126)
# Simulating alpha Ts_ZScore(cashflow_op/debt_lt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/debt_lt, 126)
# Simulating alpha Ts_ZScore(cashflow_op/debt_st, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/debt_st, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/debt_st, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/debt_st, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/debt_st, 126)
# Simulating alpha Ts_ZScore(cashflow_op/depre_amort, 126)
# Simulating alpha Ts_ZScore(cashflow_op/EBIT, 126)
# Simulating alpha Ts_ZScore(cashflow_op/EBITDA, 126)
# Simulating alpha Ts_ZScore(cashflow_op/employee, 126)
# Simulating alpha Ts_ZScore(cashflow_op/enterprise_value, 126)
# Simulating alpha Ts_ZScore(cashflow_op/eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/eps, 126)
# Simulating alpha Ts_ZScore(cashflow_op/equity, 126)
# Simulating alpha Ts_ZScore(cashflow_op/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/goodwill, 126)
# Simulating alpha Ts_ZScore(cashflow_op/income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/income, 126)
# Simulating alpha Ts_ZScore(cashflow_op/income_beforeextra, 126)
# Simulating alpha Ts_ZScore(cashflow_op/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/income_tax, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/income_tax, 126)
# Simulating alpha Ts_ZScore(cashflow_op/interest_expense, 126)
# Simulating alpha Ts_ZScore(cashflow_op/inventory, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/inventory, 126)
# Simulating alpha Ts_ZScore(cashflow_op/inventory_turnover, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/inventory_turnover, 126)
# Simulating alpha Ts_ZScore(cashflow_op/invested_capital, 126)
# Simulating alpha Ts_ZScore(cashflow_op/liabilities, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/liabilities, 126)
# Simulating alpha Ts_ZScore(cashflow_op/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/liabilities_curr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/liabilities_curr, 126)
# Simulating alpha Ts_ZScore(cashflow_op/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/operating_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/operating_expense, 126)
# Simulating alpha Ts_ZScore(cashflow_op/operating_income, 126)
# Simulating alpha Ts_ZScore(cashflow_op/pretax_income, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/pretax_income, 126)
# Simulating alpha Ts_ZScore(cashflow_op/rd_expense, 126)
# Simulating alpha Ts_ZScore(cashflow_op/receivable, 126)
# Simulating alpha Ts_ZScore(cashflow_op/retained_earnings, 126)
# Simulating alpha Ts_ZScore(cashflow_op/return_assets, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/return_assets, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(cashflow_op/return_assets, 126)
# Too many alphas simulating
# ...
# Simulating alpha Ts_ZScore(est_eps/est_tot_goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_eps/est_tot_goodwill, 126)
# Simulating alpha Ts_ZScore(est_eps/etz_eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_eps/etz_eps, 126)
# Simulating alpha Ts_ZScore(est_eps/etz_eps_delta, 126)
# Simulating alpha Ts_ZScore(est_eps/etz_eps_ret, 126)
# Simulating alpha Ts_ZScore(est_eps/etz_eps_tsrank, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_eps/etz_eps_tsrank, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_eps/etz_eps_tsrank, 126)
# Simulating alpha Ts_ZScore(est_eps/etz_revenue, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_eps/etz_revenue, 126)
# Simulating alpha Ts_ZScore(est_eps/etz_revenue_delta, 126)
# Simulating alpha Ts_ZScore(est_eps/etz_revenue_ret, 126)
# Simulating alpha Ts_ZScore(est_epsa/est_epsr, 126)
# Simulating alpha Ts_ZScore(est_epsa/est_fcf, 126)
# Simulating alpha Ts_ZScore(est_epsa/est_fcf_ps, 126)
# Simulating alpha Ts_ZScore(est_epsa/est_ffo, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsa/est_ffo, 126)
# Simulating alpha Ts_ZScore(est_epsa/est_ffoa, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsa/est_ffoa, 126)
# Simulating alpha Ts_ZScore(est_epsa/est_grossincome, 126)
# Simulating alpha Ts_ZScore(est_epsa/est_netdebt, 126)
# Simulating alpha Ts_ZScore(est_epsa/est_netprofit, 126)
# Simulating alpha Ts_ZScore(est_epsa/est_netprofit_adj, 126)
# Simulating alpha Ts_ZScore(est_epsa/est_ptp, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsa/est_ptp, 126)
# Simulating alpha Ts_ZScore(est_epsa/est_ptpr, 126)
# Simulating alpha Ts_ZScore(est_epsa/est_rd_expense, 126)
# Simulating alpha Ts_ZScore(est_epsa/est_sales, 126)
# Simulating alpha Ts_ZScore(est_epsa/est_sga, 126)
# Simulating alpha Ts_ZScore(est_epsa/est_shequity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsa/est_shequity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsa/est_shequity, 126)
# Simulating alpha Ts_ZScore(est_epsa/est_tbv_ps, 126)
# Simulating alpha Ts_ZScore(est_epsa/est_tot_assets, 126)
# Simulating alpha Ts_ZScore(est_epsa/est_tot_goodwill, 126)
# Simulating alpha Ts_ZScore(est_epsa/etz_eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsa/etz_eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsa/etz_eps, 126)
# Simulating alpha Ts_ZScore(est_epsa/etz_eps_delta, 126)
# Simulating alpha Ts_ZScore(est_epsa/etz_eps_ret, 126)
# Simulating alpha Ts_ZScore(est_epsa/etz_eps_tsrank, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsa/etz_eps_tsrank, 126)
# Simulating alpha Ts_ZScore(est_epsa/etz_revenue, 126)
# Simulating alpha Ts_ZScore(est_epsa/etz_revenue_delta, 126)
# Simulating alpha Ts_ZScore(est_epsa/etz_revenue_ret, 126)
# Simulating alpha Ts_ZScore(est_epsr/est_fcf, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsr/est_fcf, 126)
# Simulating alpha Ts_ZScore(est_epsr/est_fcf_ps, 126)
# Simulating alpha Ts_ZScore(est_epsr/est_ffo, 126)
# Simulating alpha Ts_ZScore(est_epsr/est_ffoa, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsr/est_ffoa, 126)
# Simulating alpha Ts_ZScore(est_epsr/est_grossincome, 126)
# Simulating alpha Ts_ZScore(est_epsr/est_netdebt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsr/est_netdebt, 126)
# Simulating alpha Ts_ZScore(est_epsr/est_netprofit, 126)
# Simulating alpha Ts_ZScore(est_epsr/est_netprofit_adj, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsr/est_netprofit_adj, 126)
# Simulating alpha Ts_ZScore(est_epsr/est_ptp, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsr/est_ptp, 126)
# Simulating alpha Ts_ZScore(est_epsr/est_ptpr, 126)
# Simulating alpha Ts_ZScore(est_epsr/est_rd_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsr/est_rd_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsr/est_rd_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsr/est_rd_expense, 126)
# Simulating alpha Ts_ZScore(est_epsr/est_sales, 126)
# Simulating alpha Ts_ZScore(est_epsr/est_sga, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsr/est_sga, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsr/est_sga, 126)
# Simulating alpha Ts_ZScore(est_epsr/est_shequity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsr/est_shequity, 126)
# Simulating alpha Ts_ZScore(est_epsr/est_tbv_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsr/est_tbv_ps, 126)
# Simulating alpha Ts_ZScore(est_epsr/est_tot_assets, 126)
# Simulating alpha Ts_ZScore(est_epsr/est_tot_goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsr/est_tot_goodwill, 126)
# Simulating alpha Ts_ZScore(est_epsr/etz_eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsr/etz_eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsr/etz_eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsr/etz_eps, 126)
# Simulating alpha Ts_ZScore(est_epsr/etz_eps_delta, 126)
# Simulating alpha Ts_ZScore(est_epsr/etz_eps_ret, 126)
# Simulating alpha Ts_ZScore(est_epsr/etz_eps_tsrank, 126)
# Simulating alpha Ts_ZScore(est_epsr/etz_revenue, 126)
# Simulating alpha Ts_ZScore(est_epsr/etz_revenue_delta, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_epsr/etz_revenue_delta, 126)
# Simulating alpha Ts_ZScore(est_epsr/etz_revenue_ret, 126)
# Simulating alpha Ts_ZScore(est_fcf/est_fcf_ps, 126)
# Simulating alpha Ts_ZScore(est_fcf/est_ffo, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_fcf/est_ffo, 126)
# Simulating alpha Ts_ZScore(est_fcf/est_ffoa, 126)
# Simulating alpha Ts_ZScore(est_fcf/est_grossincome, 126)
# Simulating alpha Ts_ZScore(est_fcf/est_netdebt, 126)
# Simulating alpha Ts_ZScore(est_fcf/est_netprofit, 126)
# Simulating alpha Ts_ZScore(est_fcf/est_netprofit_adj, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_fcf/est_netprofit_adj, 126)
# Simulating alpha Ts_ZScore(est_fcf/est_ptp, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_fcf/est_ptp, 126)
# Simulating alpha Ts_ZScore(est_fcf/est_ptpr, 126)
# Simulating alpha Ts_ZScore(est_fcf/est_rd_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_fcf/est_rd_expense, 126)
# Simulating alpha Ts_ZScore(est_fcf/est_sales, 126)
# Simulating alpha Ts_ZScore(est_fcf/est_sga, 126)
# Simulating alpha Ts_ZScore(est_fcf/est_shequity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_fcf/est_shequity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_fcf/est_shequity, 126)
# Simulating alpha Ts_ZScore(est_fcf/est_tbv_ps, 126)
# Simulating alpha Ts_ZScore(est_fcf/est_tot_assets, 126)
# Simulating alpha Ts_ZScore(est_fcf/est_tot_goodwill, 126)
# Simulating alpha Ts_ZScore(est_fcf/etz_eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_fcf/etz_eps, 126)
# Simulating alpha Ts_ZScore(est_fcf/etz_eps_delta, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_fcf/etz_eps_delta, 126)
# Simulating alpha Ts_ZScore(est_fcf/etz_eps_ret, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_fcf/etz_eps_ret, 126)
# Simulating alpha Ts_ZScore(est_fcf/etz_eps_tsrank, 126)
# Simulating alpha Ts_ZScore(est_fcf/etz_revenue, 126)
# Simulating alpha Ts_ZScore(est_fcf/etz_revenue_delta, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_fcf/etz_revenue_delta, 126)
# Simulating alpha Ts_ZScore(est_fcf/etz_revenue_ret, 126)
# Simulating alpha Ts_ZScore(est_fcf_ps/est_ffo, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_fcf_ps/est_ffo, 126)
# Simulating alpha Ts_ZScore(est_fcf_ps/est_ffoa, 126)
# Simulating alpha Ts_ZScore(est_fcf_ps/est_grossincome, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_fcf_ps/est_grossincome, 126)
# Simulating alpha Ts_ZScore(est_fcf_ps/est_netdebt, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_fcf_ps/est_netdebt, 126)
# Simulating alpha Ts_ZScore(est_fcf_ps/est_netprofit, 126)
# Simulating alpha Ts_ZScore(est_fcf_ps/est_netprofit_adj, 126)
# Simulating alpha Ts_ZScore(est_fcf_ps/est_ptp, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_fcf_ps/est_ptp, 126)
# Simulating alpha Ts_ZScore(est_fcf_ps/est_ptpr, 126)
# Simulating alpha Ts_ZScore(est_fcf_ps/est_rd_expense, 126)
# Simulating alpha Ts_ZScore(est_fcf_ps/est_sales, 126)
# Simulating alpha Ts_ZScore(est_fcf_ps/est_sga, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_fcf_ps/est_sga, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_fcf_ps/est_sga, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_fcf_ps/est_sga, 126)
# Simulating alpha Ts_ZScore(est_fcf_ps/est_shequity, 126)
# Simulating alpha Ts_ZScore(est_fcf_ps/est_tbv_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_fcf_ps/est_tbv_ps, 126)
# Simulating alpha Ts_ZScore(est_fcf_ps/est_tot_assets, 126)
# Simulating alpha Ts_ZScore(est_fcf_ps/est_tot_goodwill, 126)
# Simulating alpha Ts_ZScore(est_fcf_ps/etz_eps, 126)
# Simulating alpha Ts_ZScore(est_fcf_ps/etz_eps_delta, 126)
# Simulating alpha Ts_ZScore(est_fcf_ps/etz_eps_ret, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_fcf_ps/etz_eps_ret, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_fcf_ps/etz_eps_ret, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_fcf_ps/etz_eps_ret, 126)
# Simulating alpha Ts_ZScore(est_fcf_ps/etz_eps_tsrank, 126)
# Simulating alpha Ts_ZScore(est_fcf_ps/etz_revenue, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_fcf_ps/etz_revenue, 126)
# Simulating alpha Ts_ZScore(est_fcf_ps/etz_revenue_delta, 126)
# Simulating alpha Ts_ZScore(est_fcf_ps/etz_revenue_ret, 126)
# Simulating alpha Ts_ZScore(est_ffo/est_ffoa, 126)
# Simulating alpha Ts_ZScore(est_ffo/est_grossincome, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_ffo/est_grossincome, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_ffo/est_grossincome, 126)
# Simulating alpha Ts_ZScore(est_ffo/est_netdebt, 126)
# Simulating alpha Ts_ZScore(est_ffo/est_netprofit, 126)
# Simulating alpha Ts_ZScore(est_ffo/est_netprofit_adj, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_ffo/est_netprofit_adj, 126)
# Simulating alpha Ts_ZScore(est_ffo/est_ptp, 126)
# Simulating alpha Ts_ZScore(est_ffo/est_ptpr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_ffo/est_ptpr, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_ffo/est_ptpr, 126)
# Simulating alpha Ts_ZScore(est_ffo/est_rd_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_ffo/est_rd_expense, 126)
# Simulating alpha Ts_ZScore(est_ffo/est_sales, 126)
# Simulating alpha Ts_ZScore(est_ffo/est_sga, 126)
# Simulating alpha Ts_ZScore(est_ffo/est_shequity, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_ffo/est_shequity, 126)
# Simulating alpha Ts_ZScore(est_ffo/est_tbv_ps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_ffo/est_tbv_ps, 126)
# Simulating alpha Ts_ZScore(est_ffo/est_tot_assets, 126)
# Simulating alpha Ts_ZScore(est_ffo/est_tot_goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_ffo/est_tot_goodwill, 126)
# Simulating alpha Ts_ZScore(est_ffo/etz_eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_ffo/etz_eps, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_ffo/etz_eps, 126)
# Simulating alpha Ts_ZScore(est_ffo/etz_eps_delta, 126)
# Simulating alpha Ts_ZScore(est_ffo/etz_eps_ret, 126)
# Simulating alpha Ts_ZScore(est_ffo/etz_eps_tsrank, 126)
# Simulating alpha Ts_ZScore(est_ffo/etz_revenue, 126)
# Simulating alpha Ts_ZScore(est_ffo/etz_revenue_delta, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_ffo/etz_revenue_delta, 126)
# Simulating alpha Ts_ZScore(est_ffo/etz_revenue_ret, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_ffo/etz_revenue_ret, 126)
# Simulating alpha Ts_ZScore(est_ffoa/est_grossincome, 126)
# Simulating alpha Ts_ZScore(est_ffoa/est_netdebt, 126)
# Simulating alpha Ts_ZScore(est_ffoa/est_netprofit, 126)
# Simulating alpha Ts_ZScore(est_ffoa/est_netprofit_adj, 126)
# Simulating alpha Ts_ZScore(est_ffoa/est_ptp, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_ffoa/est_ptp, 126)
# Simulating alpha Ts_ZScore(est_ffoa/est_ptpr, 126)
# Simulating alpha Ts_ZScore(est_ffoa/est_rd_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_ffoa/est_rd_expense, 126)
# Simulating alpha Ts_ZScore(est_ffoa/est_sales, 126)
# Simulating alpha Ts_ZScore(est_ffoa/est_sga, 126)
# Simulating alpha Ts_ZScore(est_ffoa/est_shequity, 126)
# Simulating alpha Ts_ZScore(est_ffoa/est_tbv_ps, 126)
# Simulating alpha Ts_ZScore(est_ffoa/est_tot_assets, 126)
# Simulating alpha Ts_ZScore(est_ffoa/est_tot_goodwill, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_ffoa/est_tot_goodwill, 126)
# Simulating alpha Ts_ZScore(est_ffoa/etz_eps, 126)
# Simulating alpha Ts_ZScore(est_ffoa/etz_eps_delta, 126)
# Simulating alpha Ts_ZScore(est_ffoa/etz_eps_ret, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_ffoa/etz_eps_ret, 126)
# Simulating alpha Ts_ZScore(est_ffoa/etz_eps_tsrank, 126)
# Simulating alpha Ts_ZScore(est_ffoa/etz_revenue, 126)
# Simulating alpha Ts_ZScore(est_ffoa/etz_revenue_delta, 126)
# Simulating alpha Ts_ZScore(est_ffoa/etz_revenue_ret, 126)
# Simulating alpha Ts_ZScore(est_grossincome/est_netdebt, 126)
# Simulating alpha Ts_ZScore(est_grossincome/est_netprofit, 126)
# Simulating alpha Ts_ZScore(est_grossincome/est_netprofit_adj, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_grossincome/est_netprofit_adj, 126)
# Simulating alpha Ts_ZScore(est_grossincome/est_ptp, 126)
# Simulating alpha Ts_ZScore(est_grossincome/est_ptpr, 126)
# Simulating alpha Ts_ZScore(est_grossincome/est_rd_expense, 126)
# Simulating alpha Ts_ZScore(est_grossincome/est_sales, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_grossincome/est_sales, 126)
# Simulating alpha Ts_ZScore(est_grossincome/est_sga, 126)
# Simulating alpha Ts_ZScore(est_grossincome/est_shequity, 126)
# Simulating alpha Ts_ZScore(est_grossincome/est_tbv_ps, 126)
# Simulating alpha Ts_ZScore(est_grossincome/est_tot_assets, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_grossincome/est_tot_assets, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_grossincome/est_tot_assets, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_grossincome/est_tot_assets, 126)
# Simulating alpha Ts_ZScore(est_grossincome/est_tot_goodwill, 126)
# Simulating alpha Ts_ZScore(est_grossincome/etz_eps, 126)
# Simulating alpha Ts_ZScore(est_grossincome/etz_eps_delta, 126)
# Simulating alpha Ts_ZScore(est_grossincome/etz_eps_ret, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_grossincome/etz_eps_ret, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_grossincome/etz_eps_ret, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_grossincome/etz_eps_ret, 126)
# Simulating alpha Ts_ZScore(est_grossincome/etz_eps_tsrank, 126)
# Simulating alpha Ts_ZScore(est_grossincome/etz_revenue, 126)
# Simulating alpha Ts_ZScore(est_grossincome/etz_revenue_delta, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_grossincome/etz_revenue_delta, 126)
# Simulating alpha Ts_ZScore(est_grossincome/etz_revenue_ret, 126)
# Simulating alpha Ts_ZScore(est_netdebt/est_netprofit, 126)
# Simulating alpha Ts_ZScore(est_netdebt/est_netprofit_adj, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_netdebt/est_netprofit_adj, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_netdebt/est_netprofit_adj, 126)
# Simulating alpha Ts_ZScore(est_netdebt/est_ptp, 126)
# Simulating alpha Ts_ZScore(est_netdebt/est_ptpr, 126)
# Simulating alpha Ts_ZScore(est_netdebt/est_rd_expense, 126)
# Too many alphas simulating
# Simulating alpha Ts_ZScore(est_netdebt/est_rd_expense, 126)
# Simulating alpha Ts_ZScore(est_netdebt/est_sales, 126)

# %%
ids = pd.DataFrame(list(mongo['alphas_purgatory'].find({'Status': 'InProgress'}).limit(5)))
ids = list(ids['_id'])

# %%
client.parse_alphas(cookie=cookie, ids=ids)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-128-f71f399544df> in <module>()
# ----> 1 client.parse_alphas(cookie=cookie, ids=ids)
#
# C:\Users\krokh\Desktop\wq_project\alpha_client.py in parse_alphas(self, cookie, ids, id_type)
#     144             if error_attempts < self.max_error_attempts:
#     145                 # try:
# --> 146                 print('Parsing alpha {}'.format(json.loads(alphas[i]['Code'])))
#     147                 stats = json.loads(self.requestor.stats_alpha(cookie=cookie,
#     148                                                               index=alphas[i]['Index']).content)
#
# C:\Users\krokh\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# C:\Users\krokh\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# C:\Users\krokh\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
xx = {'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "(interest_expense > delay(interest_expense, 126)) ? 1 : -1", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': '(interest_expense > delay(interest_expense, 126)) ? 1 : -1', 'Comment': '', 'DataType': 'Fundamental', 'Delay': 1, 'Executor': 'mg', 'LogicName': 'A-20', 'Neutralization': 'market', 'Region': 'USA', 'Status': 'InProgress', 'Time': '2018-09-12 18:27:20.433369', 'Type': 'Base0', 'Universe': 'TOP3000', 'AlphaId': ObjectId('5b995a884e28b34de0ebdff9'), 'Index': 138470844}

# %%
xx['Status']
# Out:
# 'InProgress'

# %%
# running_alphas = client.simulate_alphas(cookie, alphas)
reverse_alphas, submission_ids = client.parse_alphas(cookie, running_alphas[2:])
running_reverse_alphas = client.simulate_alphas(cookie, reverse_alphas)
reverse_reverse_alphas, reverse_submission_ids = client.parse_alphas(cookie, running_reverse_alphas)
client.parse_submissions(cookie, submission_ids)
client.parse_submissions(cookie, reverse_submission_ids)
# Out:
# Parsing alpha (bookvalue_ps > delay(bookvalue_ps, 126)) ? 1 : -1
# Parsing alpha (capex > delay(capex, 126)) ? 1 : -1
# Parsing alpha (cash > delay(cash, 126)) ? 1 : -1
# Parsing alpha (cashflow > delay(cashflow, 126)) ? 1 : -1
# Parsing alpha (cashflow_dividends > delay(cashflow_dividends, 126)) ? 1 : -1
# Parsing alpha (cashflow_fin > delay(cashflow_fin, 126)) ? 1 : -1
# Parsing alpha (cashflow_invst > delay(cashflow_invst, 126)) ? 1 : -1
# Parsing alpha (cashflow_op > delay(cashflow_op, 126)) ? 1 : -1

# %%
res = requestor.log_in()
cookie = res.cookies
full_cookie = requestor.build_cookie(cookie)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e04f0786e78d> in <module>()
#       2 # res = wq.log_in()
#       3 cookie = res.cookies
# ----> 4 full_cookie = wq.build_cookie(cookie)
#
# NameError: name 'wq' is not defined

# %%
full_cookie = requestor.build_cookie(cookie)

# %%
mongo = pymongo.MongoClient(mongo_connection_string).wq

# %%
cookie
# Out:
# <RequestsCookieJar[Cookie(version=0, name='UID', value='0006412efdac205d9da274bf441e567da353fc59ee098239255bf532c9562e90', port=None, port_specified=False, domain='.worldquantvrc.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=None, discard=True, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='WSSID', value='"2|1:0|10:1537213597|5:WSSID|60:bitQTU1TWHN1VVpXaDNhaE1qSWxCN0IzWmNTTUQ0UmlhRzRhK1dWdmZwYz0=|e385add98b218054ecfacb6801b0b45a98c2758b45ae67d67b79ac94ef264c76"', port=None, port_specified=False, domain='.worldquantvrc.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False)]>

# %%
df = pd.DataFrame(list(mongo['alphas_simulate'].find({}).limit(10)))

# %%
alphas = list(df['Alpha'])
alphas
# Out:
# ['[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "(assets > delay(assets, 126)) ? 1 : -1", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]',
#  '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "(assets_curr > delay(assets_curr, 126)) ? 1 : -1", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]',
#  '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "(bookvalue_ps > delay(bookvalue_ps, 126)) ? 1 : -1", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]',
#  '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "(capex > delay(capex, 126)) ? 1 : -1", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]',
#  '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "(cash > delay(cash, 126)) ? 1 : -1", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]',
#  '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "(cashflow > delay(cashflow, 126)) ? 1 : -1", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]',
#  '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "(cashflow_dividends > delay(cashflow_dividends, 126)) ? 1 : -1", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]',
#  '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "(cashflow_fin > delay(cashflow_fin, 126)) ? 1 : -1", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]',
#  '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "(cashflow_invst > delay(cashflow_invst, 126)) ? 1 : -1", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]',
#  '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "(cashflow_op > delay(cashflow_op, 126)) ? 1 : -1", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]']

# %%
running_alphas = client.simulate_alphas(cookie, alphas[10:])
reverse_alphas, submission_ids = client.parse_alphas(cookie, running_alphas)
running_reverse_alphas = client.simulate_alphas(cookie, reverse_alphas)
reverse_reverse_alphas, reverse_submission_ids = client.parse_alphas(cookie, running_reverse_alphas)
client.parse_submissions(cookie, submission_ids)
client.parse_submissions(cookie, reverse_submission_ids)
# Out:
# Simulating alpha (eps > delay(eps, 126)) ? 1 : -1
# Simulating alpha (equity > delay(equity, 126)) ? 1 : -1
# Simulating alpha (goodwill > delay(goodwill, 126)) ? 1 : -1
# Simulating alpha (income > delay(income, 126)) ? 1 : -1
# Simulating alpha (income_beforeextra > delay(income_beforeextra, 126)) ? 1 : -1
# Simulating alpha (income_tax > delay(income_tax, 126)) ? 1 : -1
# Simulating alpha (interest_expense > delay(interest_expense, 126)) ? 1 : -1
# Simulating alpha (inventory > delay(inventory, 126)) ? 1 : -1
# Simulating alpha (inventory_turnover > delay(inventory_turnover, 126)) ? 1 : -1
# Simulating alpha (invested_capital > delay(invested_capital, 126)) ? 1 : -1
# Simulating alpha (liabilities > delay(liabilities, 126)) ? 1 : -1
# Simulating alpha (liabilities_curr > delay(liabilities_curr, 126)) ? 1 : -1
# Simulating alpha (operating_expense > delay(operating_expense, 126)) ? 1 : -1
# Simulating alpha (operating_income > delay(operating_income, 126)) ? 1 : -1
# Simulating alpha (pretax_income > delay(pretax_income, 126)) ? 1 : -1
# Simulating alpha (rd_expense > delay(rd_expense, 126)) ? 1 : -1
# Simulating alpha (receivable > delay(receivable, 126)) ? 1 : -1
# Simulating alpha (retained_earnings > delay(retained_earnings, 126)) ? 1 : -1
# Simulating alpha (return_assets > delay(return_assets, 126)) ? 1 : -1
# Simulating alpha (return_equity > delay(return_equity, 126)) ? 1 : -1
# Simulating alpha (revenue > delay(revenue, 126)) ? 1 : -1
# Simulating alpha (sales > delay(sales, 126)) ? 1 : -1
# Simulating alpha (sales_growth > delay(sales_growth, 126)) ? 1 : -1
# Simulating alpha (sales_ps > delay(sales_ps, 126)) ? 1 : -1
# Simulating alpha (SGA_expense > delay(SGA_expense, 126)) ? 1 : -1
# Simulating alpha (working_capital > delay(working_capital, 126)) ? 1 : -1
# Simulating alpha (est_bookvalue_ps > delay(est_bookvalue_ps, 126)) ? 1 : -1
# Simulating alpha (est_capex > delay(est_capex, 126)) ? 1 : -1
# Simulating alpha (est_cashflow_fin > delay(est_cashflow_fin, 126)) ? 1 : -1
# Simulating alpha (est_cashflow_invst > delay(est_cashflow_invst, 126)) ? 1 : -1
# Simulating alpha (est_cashflow_op > delay(est_cashflow_op, 126)) ? 1 : -1
# Simulating alpha (est_cashflow_ps > delay(est_cashflow_ps, 126)) ? 1 : -1
# Simulating alpha (est_dividend_ps > delay(est_dividend_ps, 126)) ? 1 : -1
# Simulating alpha (est_ebit > delay(est_ebit, 126)) ? 1 : -1
# Simulating alpha (est_ebitda > delay(est_ebitda, 126)) ? 1 : -1
# Simulating alpha (est_eps > delay(est_eps, 126)) ? 1 : -1
# Simulating alpha (est_epsa > delay(est_epsa, 126)) ? 1 : -1
# Simulating alpha (est_epsr > delay(est_epsr, 126)) ? 1 : -1
# Simulating alpha (est_fcf > delay(est_fcf, 126)) ? 1 : -1
# Simulating alpha (est_fcf_ps > delay(est_fcf_ps, 126)) ? 1 : -1
# Simulating alpha (est_ffo > delay(est_ffo, 126)) ? 1 : -1
# Simulating alpha (est_ffoa > delay(est_ffoa, 126)) ? 1 : -1
# Simulating alpha (est_grossincome > delay(est_grossincome, 126)) ? 1 : -1
# Simulating alpha (est_netdebt > delay(est_netdebt, 126)) ? 1 : -1
# Simulating alpha (est_netprofit > delay(est_netprofit, 126)) ? 1 : -1
# Simulating alpha (est_netprofit_adj > delay(est_netprofit_adj, 126)) ? 1 : -1
# Simulating alpha (est_ptp > delay(est_ptp, 126)) ? 1 : -1
# Simulating alpha (est_ptpr > delay(est_ptpr, 126)) ? 1 : -1
# Simulating alpha (est_rd_expense > delay(est_rd_expense, 126)) ? 1 : -1
# Simulating alpha (est_sales > delay(est_sales, 126)) ? 1 : -1
# Simulating alpha (est_sga > delay(est_sga, 126)) ? 1 : -1
# Simulating alpha (est_shequity > delay(est_shequity, 126)) ? 1 : -1
# Simulating alpha (est_tbv_ps > delay(est_tbv_ps, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (est_tbv_ps > delay(est_tbv_ps, 126)) ? 1 : -1
# Simulating alpha (est_tot_assets > delay(est_tot_assets, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (est_tot_assets > delay(est_tot_assets, 126)) ? 1 : -1
# Simulating alpha (est_tot_goodwill > delay(est_tot_goodwill, 126)) ? 1 : -1
# Simulating alpha (etz_eps > delay(etz_eps, 126)) ? 1 : -1
# Simulating alpha (etz_eps_delta > delay(etz_eps_delta, 126)) ? 1 : -1
# Simulating alpha (etz_eps_ret > delay(etz_eps_ret, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (etz_eps_ret > delay(etz_eps_ret, 126)) ? 1 : -1
# Simulating alpha (etz_eps_tsrank > delay(etz_eps_tsrank, 126)) ? 1 : -1
# Simulating alpha (etz_revenue > delay(etz_revenue, 126)) ? 1 : -1
# Simulating alpha (etz_revenue_delta > delay(etz_revenue_delta, 126)) ? 1 : -1
# Simulating alpha (etz_revenue_ret > delay(etz_revenue_ret, 126)) ? 1 : -1
# Simulating alpha (rel_num_all > delay(rel_num_all, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (rel_num_all > delay(rel_num_all, 126)) ? 1 : -1
# Simulating alpha (rel_num_comp > delay(rel_num_comp, 126)) ? 1 : -1
# Simulating alpha (rel_num_cust > delay(rel_num_cust, 126)) ? 1 : -1
# Simulating alpha (rel_num_part > delay(rel_num_part, 126)) ? 1 : -1
# Simulating alpha (rel_ret_all > delay(rel_ret_all, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (rel_ret_all > delay(rel_ret_all, 126)) ? 1 : -1
# Too many alphas simulating
# Simulating alpha (rel_ret_all > delay(rel_ret_all, 126)) ? 1 : -1
# Simulating alpha (rel_ret_comp > delay(rel_ret_comp, 126)) ? 1 : -1
# Simulating alpha (rel_ret_cust > delay(rel_ret_cust, 126)) ? 1 : -1
# Simulating alpha (rel_ret_part > delay(rel_ret_part, 126)) ? 1 : -1
# Local error happen the JSON object must be str, bytes or bytearray, not 'float'
# Local error happen the JSON object must be str, bytes or bytearray, not 'float'
# Local error happen the JSON object must be str, bytes or bytearray, not 'float'
# Local error happen the JSON object must be str, bytes or bytearray, not 'float'
# Local error happen the JSON object must be str, bytes or bytearray, not 'float'
# Too many errors, function Simulate Alphas finished
# Parsing alpha (eps > delay(eps, 126)) ? 1 : -1
# Parsing alpha (equity > delay(equity, 126)) ? 1 : -1
# Parsing alpha (goodwill > delay(goodwill, 126)) ? 1 : -1
# Parsing alpha (income > delay(income, 126)) ? 1 : -1
# Parsing alpha (income_beforeextra > delay(income_beforeextra, 126)) ? 1 : -1
# Parsing alpha (income_tax > delay(income_tax, 126)) ? 1 : -1
# Parse exception {e} 'alpha_client' object has no attribute 'get_alphaid'
# Parsing alpha (income_tax > delay(income_tax, 126)) ? 1 : -1
# No such index
# Parse exception {e} 'alpha_client' object has no attribute 'get_alphaid'
# Parsing alpha (income_tax > delay(income_tax, 126)) ? 1 : -1
# No such index
# Parse exception {e} 'alpha_client' object has no attribute 'get_alphaid'
# Parsing alpha (income_tax > delay(income_tax, 126)) ? 1 : -1
# No such index
# Parse exception {e} 'alpha_client' object has no attribute 'get_alphaid'
# Parsing alpha (income_tax > delay(income_tax, 126)) ? 1 : -1
# No such index
# Parse exception {e} 'alpha_client' object has no attribute 'get_alphaid'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\krokh\Desktop\wq_project\alpha_client.py in parse_alphas(self, cookie, running_alphas)
#     164                                                         inverse=is_inverse)
# --> 165                                 alpha_id = json.loads(self.get_alphaid(cookie, running_alphas[i]['index']).content)['result']['clientAlphaId']
#     166                                 submission_id = json.loads(self.get_submissionid(cookie, alpha_id).content)['result']['RequestId']
#
# AttributeError: 'alpha_client' object has no attribute 'get_alphaid'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-340-4697b24ea0aa> in <module>()
#       1 running_alphas = client.simulate_alphas(cookie, alphas[10:])
# ----> 2 reverse_alphas, submission_ids = client.parse_alphas(cookie, running_alphas)
#       3 running_reverse_alphas = client.simulate_alphas(cookie, reverse_alphas)
#       4 reverse_reverse_alphas, reverse_submission_ids = client.parse_alphas(cookie, running_reverse_alphas)
#       5 client.parse_submissions(cookie, submission_ids)
#
# C:\Users\krokh\Desktop\wq_project\alpha_client.py in parse_alphas(self, cookie, running_alphas)
#     214                             parse_attempts = 0
#     215                             i+= 1
# --> 216                         time.sleep(self.pause)
#     217
#     218                 except Exception as e:
#
# KeyboardInterrupt:

# %%
mongo = pymongo.MongoClient(mongo_connection_string).wq
# alpha_current_info = dict(pd.DataFrame(list(mongo.db[collection_purgatory].find({'Index': alpha['index']}))[0]).iloc[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-121-9e92e04450fa> in <module>()
#       1 mongo = pymongo.MongoClient(mongo_connection_string).wq
# ----> 2 alpha_current_info = dict(pd.DataFrame(list(mongo.db[collection_old].find({'Index': alpha['index']}))[0]).iloc[0])
#
# NameError: name 'collection_old' is not defined

# %%
mongo[collection_purgatory].insert({'Alpha': 'hdsj'})
# Out:
# ObjectId('5ba15d614e28b3159462b5e4')

# %%
tmp = list(mongo[collection_purgatory].find({'Index': 137256934}))

# %%
from bson.objectid import ObjectId

ids = [ObjectId('5b995a884e28b34de0ebe1fa')]
xx = mongo['alphas_simulate'].find({"_id": {"$in": ids}})

# %%
yy = pd.DataFrame(list(xx))

# %%
data = yy.iloc[0, :].to_dict()

# %%
def function(key, old_key, new_key):
    if key == old_key:
        return new_key
    else:
        return key

# %%
oldkey, newkey = '_id', 'Id' 
data = {function(k, oldkey, newkey):v  for k, v in data.items()}
data
# Out:
# {'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "(rel_ret_part > delay(rel_ret_part, 126)) ? 1 : -1", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]',
#  'Code': '(rel_ret_part > delay(rel_ret_part, 126)) ? 1 : -1',
#  'Comment': '',
#  'DataType': 'Relationship',
#  'Delay': 1,
#  'Executor': 'mg',
#  'Id': ObjectId('5b995a884e28b34de0ebe1fa'),
#  'LogicName': 'A-20',
#  'Neutralization': 'industry',
#  'Region': 'USA',
#  'Status': 'InProgress',
#  'Time': '2018-09-12 18:27:20.504354',
#  'Type': 'Base0',
#  'Universe': 'TOP1000'}

# %%
pd.DataFrame(list(mongo['alphas_simulate'].find({"_id": ObjectId("5b995a884e28b34de0ebe1fa")})))
# Out:
#                                                                                                  Alpha  \
# 0  [{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetcla...
#
#                                                  Code Comment      DataType  \
# 0  (rel_ret_part > delay(rel_ret_part, 126)) ? 1 : -1          Relationship
#
#    Delay Executor LogicName Neutralization Region      Status  \
# 0      1       mg      A-20       industry    USA  InProgress
#
#                          Time   Type Universe                       _id
# 0  2018-09-12 18:27:20.504354  Base0  TOP1000  5b995a884e28b34de0ebe1fa

# %%
requests.get('https://google.com')

# %%
import requests

proxies = {
  'http': 'http://83.171.112.153',
  'https': 'http://83.171.112.153',
}

requests.get('https://google.com', proxies=proxies)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# C:\Users\krokh\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# C:\Users\krokh\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# C:\Users\krokh\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# TimeoutError: [WinError 10060] Попытка установить соединение была безуспешной, т.к. от другого компьютера за требуемое время не получен нужный отклик, или было разорвано уже установленное соединение из-за неверного отклика уже подключенного компьютера
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# C:\Users\krokh\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# C:\Users\krokh\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     356         else:
# --> 357             conn.request(method, url, **httplib_request_kw)
#     358
#
# C:\Users\krokh\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# C:\Users\krokh\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# C:\Users\krokh\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# C:\Users\krokh\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# C:\Users\krokh\Anaconda3\lib\http\client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# C:\Users\krokh\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     165     def connect(self):
# --> 166         conn = self._new_conn()
#     167         self._prepare_conn(conn)
#
# C:\Users\krokh\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000001BC9DD62DA0>: Failed to establish a new connection: [WinError 10060] Попытка установить соединение была безуспешной, т.к. от другого компьютера за требуемое время не получен нужный отклик, или было разорвано уже установленное соединение из-за неверного отклика уже подключенного компьютера
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# C:\Users\krokh\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     444                     retries=self.max_retries,
# --> 445                     timeout=timeout
#     446                 )
#
# C:\Users\krokh\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# C:\Users\krokh\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPConnectionPool(host='83.171.112.153', port=80): Max retries exceeded with url: http://example.org/ (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001BC9DD62DA0>: Failed to establish a new connection: [WinError 10060] Попытка установить соединение была безуспешной, т.к. от другого компьютера за требуемое время не получен нужный отклик, или было разорвано уже установленное соединение из-за неверного отклика уже подключенного компьютера',)))
#
# During handling of the above exception, another exception occurred:
#
# ProxyError                                Traceback (most recent call last)
# <ipython-input-4-8e265e1212a9> in <module>()
#       6 }
#       7
# ----> 8 requests.get('http://example.org', proxies=proxies)
#
# C:\Users\krokh\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# C:\Users\krokh\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# C:\Users\krokh\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# C:\Users\krokh\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     620
#     621         # Send the request
# --> 622         r = adapter.send(request, **kwargs)
#     623
#     624         # Total elapsed time of the request (approximately)
#
# C:\Users\krokh\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     505
#     506             if isinstance(e.reason, _ProxyError):
# --> 507                 raise ProxyError(e, request=request)
#     508
#     509             if isinstance(e.reason, _SSLError):
#
# ProxyError: HTTPConnectionPool(host='83.171.112.153', port=80): Max retries exceeded with url: http://example.org/ (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001BC9DD62DA0>: Failed to establish a new connection: [WinError 10060] Попытка установить соединение была безуспешной, т.к. от другого компьютера за требуемое время не получен нужный отклик, или было разорвано уже установленное соединение из-за неверного отклика уже подключенного компьютера',)))

# %%
res = requests.get('https://google.com')
