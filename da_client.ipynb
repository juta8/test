# %%
import alpha_client
import alpha_creator
import alpha_parser
import alpha_requestor
import alpha_mode
# Out:
# C:\Users\krokh\Anaconda3\lib\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.22) or chardet (2.0.3) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
runner = alpha_mode.AlphaMode('da')

# %%
import alpha_client
import alpha_creator
import alpha_parser
import alpha_requestor
import alpha_mode

# %%
mode = alpha_mode.AlphaMode('da')

# %%
mode.mix_mode(iteration=1,pack_number=1,mix_iteration=5)
# Out:
# [{'Alpha': '[{"nanhandling": "on", "delay": "1", "unitcheck": "off", "pasteurize": "on", "univid": "TOP100", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "rank(-rank(Ts_ZScore(pretax_income/sales, 126))) * rank(Ts_Moment(debt/eps, 3, 126))", "region": "EUR", "opneut": "market", "IntradayType": null, "tags": "equity", "decay": "12", "dataviz": "0", "backdays": "512", "simtime": "Y10"}]', 'Code': 'rank(-rank(Ts_ZScore(pretax_income/sales, 126))) * rank(Ts_Moment(debt/eps, 3, 126))', 'Neutralization': 'market', 'Universe': 'TOP100', 'Delay': 1, 'Region': 'EUR', 'Time': '2018-11-12 17:34:56.118113', 'Executor': 'da', 'LogicName': '-rank(Ts_ZScore(pretax_income/sales, 126))', 'Comment': '', 'Status': 'InMix', 'Type': 'Base0', 'DataType': 'Base0', 'Iteration': 1, 'Params': []}, {'Alpha': '[{"nanhandling": "on", "delay": "1", "unitcheck": "off", "pasteurize": "on", "univid": "TOP100", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "rank(-rank(Ts_ZScore(pretax_income/sales, 126))) * rank(rank(Correlation(EBIT, delay(receivable, 100), 100) * delta(receivable, 100)))", "region": "EUR", "opneut": "market", "IntradayType": null, "tags": "equity", "decay": "12", "dataviz": "0", "backdays": "512", "simtime": "Y10"}]', 'Code': 'rank(-rank(Ts_ZScore(pretax_income/sales, 126))) * rank(rank(Correlation(EBIT, delay(receivable, 100), 100) * delta(receivable, 100)))', 'Neutralization': 'market', 'Universe': 'TOP100', 'Delay': 1, 'Region': 'EUR', 'Time': '2018-11-12 17:34:56.118113', 'Executor': 'da', 'LogicName': '-rank(Ts_ZScore(pretax_income/sales, 126))', 'Comment': '', 'Status': 'InMix', 'Type': 'Base0', 'DataType': 'Base0', 'Iteration': 1, 'Params': []}, {'Alpha': '[{"nanhandling": "on", "delay": "1", "unitcheck": "off", "pasteurize": "on", "univid": "TOP100", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "rank(-rank(Ts_ZScore(pretax_income/sales, 126))) * rank(-rank(StdDev(EBIT/return_assets, 126)))", "region": "EUR", "opneut": "market", "IntradayType": null, "tags": "equity", "decay": "12", "dataviz": "0", "backdays": "512", "simtime": "Y10"}]', 'Code': 'rank(-rank(Ts_ZScore(pretax_income/sales, 126))) * rank(-rank(StdDev(EBIT/return_assets, 126)))', 'Neutralization': 'market', 'Universe': 'TOP100', 'Delay': 1, 'Region': 'EUR', 'Time': '2018-11-12 17:34:56.118113', 'Executor': 'da', 'LogicName': '-rank(Ts_ZScore(pretax_income/sales, 126))', 'Comment': '', 'Status': 'InMix', 'Type': 'Base0', 'DataType': 'Base0', 'Iteration': 1, 'Params': []}, {'Alpha': '[{"nanhandling": "on", "delay": "1", "unitcheck": "off", "pasteurize": "on", "univid": "TOP100", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "rank(-rank(Ts_ZScore(pretax_income/sales, 126))) * rank(-rank(StdDev(cogs/return_assets, 126)))", "region": "EUR", "opneut": "market", "IntradayType": null, "tags": "equity", "decay": "12", "dataviz": "0", "backdays": "512", "simtime": "Y10"}]', 'Code': 'rank(-rank(Ts_ZScore(pretax_income/sales, 126))) * rank(-rank(StdDev(cogs/return_assets, 126)))', 'Neutralization': 'market', 'Universe': 'TOP100', 'Delay': 1, 'Region': 'EUR', 'Time': '2018-11-12 17:34:56.118113', 'Executor': 'da', 'LogicName': '-rank(Ts_ZScore(pretax_income/sales, 126))', 'Comment': '', 'Status': 'InMix', 'Type': 'Base0', 'DataType': 'Base0', 'Iteration': 1, 'Params': []}, {'Alpha': '[{"nanhandling": "on", "delay": "1", "unitcheck": "off", "pasteurize": "on", "univid": "TOP100", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "rank(-rank(Ts_ZScore(pretax_income/sales, 126))) * rank(indneutralize(rank(Ts_Skewness(assets/receivable, 126)), 5 * rank(-rank(StdDev(depre_amort/revenue, 126))) + 0.5))", "region": "EUR", "opneut": "market", "IntradayType": null, "tags": "equity", "decay": "12", "dataviz": "0", "backdays": "512", "simtime": "Y10"}]', 'Code': 'rank(-rank(Ts_ZScore(pretax_income/sales, 126))) * rank(indneutraliz ...
# Function simulating alphas started
# Simulating alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(indneutralize(rank(Ts_Skewness(assets/receivable, 126)), 5 * rank(-Ts_Kurtosis(assets_curr/preferred_dividends, 126)) + 0.5))
# Simulating alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(indneutralize(rank(-rank(Ts_ZScore(capex/employee, 126))), 5 * rank(Ts_ZScore(cash_st/preferred_dividends, 126)) + 0.5))
# Simulating alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126))
# Simulating alpha rank(-rank(Ts_ZScore(pretax_income/sales, 126))) * rank(Ts_Moment(debt/eps, 3, 126))
# Simulating alpha rank(-rank(Ts_ZScore(pretax_income/sales, 126))) * rank(rank(Correlation(EBIT, delay(receivable, 100), 100) * delta(receivable, 100)))
# Function simulating alphas finished
#
#
# Function parsing alphas started
# Parsing alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(indneutralize(rank(Ts_Skewness(assets/receivable, 126)), 5 * rank(-Ts_Kurtosis(assets_curr/preferred_dividends, 126)) + 0.5))
# b'"DONE"'
# {'error': '', 'result': [{'BookSize': 20000000.0, 'DrawDown': 2.57, 'Fitness': 0.14, 'LongCount': 20, 'Margin': 6.85, 'PnL': 56229.319999999985, 'Returns': 2.56, 'Sharpe': 0.24, 'ShortCount': 28, 'TurnOver': 7.46, 'Year': '2007', 'YearId': '2007'}, {'BookSize': 20000000.0, 'DrawDown': 7.1, 'Fitness': 3.67, 'LongCount': 22, 'Margin': 126.58, 'PnL': 3888136.597, 'Returns': 37.82, 'Sharpe': 1.46, 'ShortCount': 30, 'TurnOver': 5.98, 'Year': '2008', 'YearId': '2008'}, {'BookSize': 20000000.0, 'DrawDown': 3.03, 'Fitness': 2.46, 'LongCount': 25, 'Margin': 54.47, 'PnL': 1624297.1910000003, 'Returns': 15.8, 'Sharpe': 1.49, 'ShortCount': 38, 'TurnOver': 5.8, 'Year': '2009', 'YearId': '2009'}, {'BookSize': 20000000.0, 'DrawDown': 4.3, 'Fitness': -0.63, 'LongCount': 25, 'Margin': -19.08, 'PnL': -492847.8650000003, 'Returns': -4.78, 'Sharpe': -0.65, 'ShortCount': 37, 'TurnOver': 5.01, 'Year': '2010', 'YearId': '2010'}, {'BookSize': 20000000.0, 'DrawDown': 1.55, 'Fitness': 4.34, 'LongCount': 27, 'Margin': 63.36, 'PnL': 1737464.264899999, 'Returns': 16.9, 'Sharpe': 2.44, 'ShortCount': 38, 'TurnOver': 5.34, 'Year': '2011', 'YearId': '2011'}, {'BookSize': 20000000.0, 'DrawDown': 2.1, 'Fitness': 2.18, 'LongCount': 27, 'Margin': 35.43, 'PnL': 985427.4040000009, 'Returns': 9.59, 'Sharpe': 1.64, 'ShortCount': 37, 'TurnOver': 5.41, 'Year': '2012', 'YearId': '2012'}, {'BookSize': 20000000.0, 'DrawDown': 1.66, 'Fitness': 5.51, 'LongCount': 24, 'Margin': 68.36, 'PnL': 2035313.434000001, 'Returns': 19.88, 'Sharpe': 2.98, 'ShortCount': 35, 'TurnOver': 5.81, 'Year': '2013', 'YearId': '2013'}, {'BookSize': 20000000.0, 'DrawDown': 2.12, 'Fitness': -0.1, 'LongCount': 24, 'Margin': -4.82, 'PnL': -129121.57139999997, 'Returns': -1.26, 'Sharpe': -0.21, 'ShortCount': 36, 'TurnOver': 5.24, 'Year': '2014', 'YearId': '2014'}, {'BookSize': 20000000.0, 'DrawDown': 1.51, 'Fitness': 2.24, 'LongCount': 24, 'Margin': 41.3, 'PnL': 1080425.1549999996, 'Returns': 10.51, 'Sharpe': 1.56, 'ShortCount': 36, 'TurnOver': 5.09, 'Year': '2015', 'YearId': '2015'}, {'BookSize': 20000000.0, 'DrawDown': 3.69, 'Fitness': 0.61, 'LongCount': 25, 'Margin': 18.84, 'PnL': 514605.33550000016, 'Returns': 5.01, 'Sharpe': 0.63, 'ShortCount': 37, 'TurnOver': 5.31, 'Year': '2016', 'YearId': '2016'}, {'BookSize': 20000000.0, 'DrawDown': 1.68, 'Fitness': 5.53, 'LongCount': 25, 'Margin': 74.6, 'PnL': 1373951.2226000007, 'Returns': 20.94, 'Sharpe': 2.86, 'ShortCount': 34, 'TurnOver': 5.61, 'Year': '2017', 'YearId': '2017'}, {'BookSize': 20000000.0, 'DrawDown': 7.1, 'Fitness': 1.74, 'LongCount': 25, 'Margin': 45.54, 'PnL': 12673880.487599995, 'Returns': 12.52, 'Sharpe': 1.15, 'ShortCount': 36, 'TurnOver': 5.5, 'Year': '2007-2017', 'YearId': 'TOTAL'}], 'status': True}
# Parsing alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(indneutralize(rank(-rank(Ts_ZScore(capex/employee, 126))), 5 * rank(Ts_ZScore(cash_st/preferred_dividends, 126)) + 0.5))
# b'"DONE"'
# {'error': '', 'result': [{'BookSize': 20000000.0, 'DrawDown': 3.57, 'Fitness': 0.19, 'LongCount': 7, 'Margin': 8.91, 'PnL': 80698.73799999997, 'Returns': 3.67, 'Sharpe': 0.29, 'ShortCount': 10, 'TurnOver': 8.24, 'Year': '2007', 'YearId': '2007'}, {'BookSize': 20000000.0, 'DrawDown': 9.34, 'Fitness': 4.29, 'LongCount': 9, 'Margin': 147.77, 'PnL': 5246842.1959999995, 'Returns': 51.04, 'Sharpe': 1.58, 'ShortCount': 12, 'TurnOver': 6.91, 'Year': '2008', 'YearId': '2008'}, {'BookSize': 20000000.0, 'DrawDown': 10.99, 'Fitness': -1.74, 'LongCount': 12, 'Margin': -49.17, 'PnL': -1603687.8430000008, 'Returns': -15.6, 'Sharpe': -1.11, 'ShortCount': 18, 'TurnOver': 6.35, 'Year': '2009', 'YearId': '2009'}, {'BookSize': 20000000.0, 'DrawDown': 5.89, 'Fitness': -0.72, 'LongCount': 14, 'Margin': -22.8, 'PnL': -595618.9439999994, 'Returns': -5.77, 'Sharpe': -0.67, 'ShortCount': 18, 'TurnOver': 5.06, 'Year': '2010', 'YearId': '2010'}, {'BookSize': 20000000.0, 'DrawDown': 4.95, 'Fitness': -0.23, 'LongCount': 16, 'Margin': -10.0, 'PnL': -293553.2309999998, 'Returns': -2.86, 'Sharpe': -0.32, 'ShortCount': 20, 'TurnOver': 5.71, 'Year': '2011', 'YearId': '2011'}, {'BookSize': 20000000.0, 'DrawDown': 3.1, 'Fitness': 2.97, 'LongCount': 14, 'Margin': 59.62, 'PnL': 1752488.0264000015, 'Returns': 17.05, 'Sharpe': 1.72, 'ShortCount': 19, 'TurnOver': 5.72, 'Year': '2012', 'YearId': '2012'}, {'BookSize': 20000000.0, 'DrawDown': 2.13, 'Fitness': 3.47, 'LongCount': 14, 'Margin': 54.74, 'PnL': 1941785.857, 'Returns': 18.96, 'Sharpe': 2.1, 'ShortCount': 16, 'TurnOver': 6.93, 'Year': '2013', 'YearId': '2013'}, {'BookSize': 20000000.0, 'DrawDown': 2.43, 'Fitness': 3.52, 'LongCount': 12, 'Margin': 54.12, 'PnL': 1631224.6759999995, 'Returns': 15.93, 'Sharpe': 2.14, 'ShortCount': 17, 'TurnOver': 5.89, 'Year': '2014', 'YearId': '2014'}, {'BookSize': 20000000.0, 'DrawDown': 2.55, 'Fitness': 1.67, 'LongCount': 13, 'Margin': 37.62, 'PnL': 1066897.4440000006, 'Returns': 10.38, 'Sharpe': 1.22, 'ShortCount': 19, 'TurnOver': 5.52, 'Year': '2015', 'YearId': '2015'}, {'BookSize': 20000000.0, 'DrawDown': 2.6, 'Fitness': 0.2, 'LongCount': 15, 'Margin': 9.42, 'PnL': 257363.97299999985, 'Returns': 2.5, 'Sharpe': 0.29, 'ShortCount': 24, 'TurnOver': 5.31, 'Year': '2016', 'YearId': '2016'}, {'BookSize': 20000000.0, 'DrawDown': 2.32, 'Fitness': 0.02, 'LongCount': 16, 'Margin': 1.27, 'PnL': 26855.61899999974, 'Returns': 0.41, 'Sharpe': 0.07, 'ShortCount': 22, 'TurnOver': 6.44, 'Year': '2017', 'YearId': '2017'}, {'BookSize': 20000000.0, 'DrawDown': 19.26, 'Fitness': 0.86, 'LongCount': 13, 'Margin': 31.24, 'PnL': 9511296.511400007, 'Returns': 9.39, 'Sharpe': 0.69, 'ShortCount': 18, 'TurnOver': 6.01, 'Year': '2007-2017', 'YearId': 'TOTAL'}], 'status': True}
# Parsing alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(indneutralize(rank(Ts_Skewness(assets/receivable, 126)), 5 * rank(-Ts_Kurtosis(assets_curr/preferred_dividends, 126)) + 0.5))
# b'"DONE"'
# {'error': '', 'result': [{'BookSize': 20000000.0, 'DrawDown': 2.57, 'Fitness': 0.14, 'LongCount': 20, 'Margin': 6.85, 'PnL': 56229.319999999985, 'Returns': 2.56, 'Sharpe': 0.24, 'ShortCount': 28, 'TurnOver': 7.46, 'Year': '2007', 'YearId': '2007'}, {'BookSize': 20000000.0, 'DrawDown': 7.1, 'Fitness': 3.67, 'LongCount': 22, 'Margin': 126.58, 'PnL': 3888136.597, 'Returns': 37.82, 'Sharpe': 1.46, 'ShortCount': 30, 'TurnOver': 5.98, 'Year': '2008', 'YearId': '2008'}, {'BookSize': 20000000.0, 'DrawDown': 3.03, 'Fitness': 2.46, 'LongCount': 25, 'Margin': 54.47, 'PnL': 1624297.1910000003, 'Returns': 15.8, 'Sharpe': 1.49, 'ShortCount': 38, 'TurnOver': 5.8, 'Year': '2009', 'YearId': '2009'}, {'BookSize': 20000000.0, 'DrawDown': 4.3, 'Fitness': -0.63, 'LongCount': 25, 'Margin': -19.08, 'PnL': -492847.8650000003, 'Returns': -4.78, 'Sharpe': -0.65, 'ShortCount': 37, 'TurnOver': 5.01, 'Year': '2010', 'YearId': '2010'}, {'BookSize': 20000000.0, 'DrawDown': 1.55, 'Fitness': 4.34, 'LongCount': 27, 'Margin': 63.36, 'PnL': 1737464.264899999, 'Returns': 16.9, 'Sharpe': 2.44, 'ShortCount': 38, 'TurnOver': 5.34, 'Year': '2011', 'YearId': '2011'}, {'BookSize': 20000000.0, 'DrawDown': 2.1, 'Fitness': 2.18, 'LongCount': 27, 'Margin': 35.43, 'PnL': 985427.4040000009, 'Returns': 9.59, 'Sharpe': 1.64, 'ShortCount': 37, 'TurnOver': 5.41, 'Year': '2012', 'YearId': '2012'}, {'BookSize': 20000000.0, 'DrawDown': 1.66, 'Fitness': 5.51, 'LongCount': 24, 'Margin': 68.36, 'PnL': 2035313.434000001, 'Returns': 19.88, 'Sharpe': 2.98, 'ShortCount': 35, 'TurnOver': 5.81, 'Year': '2013', 'YearId': '2013'}, {'BookSize': 20000000.0, 'DrawDown': 2.12, 'Fitness': -0.1, 'LongCount': 24, 'Margin': -4.82, 'PnL': -129121.57139999997, 'Returns': -1.26, 'Sharpe': -0.21, 'ShortCount': 36, 'TurnOver': 5.24, 'Year': '2014', 'YearId': '2014'}, {'BookSize': 20000000.0, 'DrawDown': 1.51, 'Fitness': 2.24, 'LongCount': 24, 'Margin': 41.3, 'PnL': 1080425.1549999996, 'Returns': 10.51, 'Sharpe': 1.56, 'ShortCount': 36, 'TurnOver': 5.09, 'Year': '2015', 'YearId': '2015'}, {'BookSize': 20000000.0, 'DrawDown': 3.69, 'Fitness': 0.61, 'LongCount': 25, 'Margin': 18.84, 'PnL': 514605.33550000016, 'Returns': 5.01, 'Sharpe': 0.63, 'ShortCount': 37, 'TurnOver': 5.31, 'Year': '2016', 'YearId': '2016'}, {'BookSize': 20000000.0, 'DrawDown': 1.68, 'Fitness': 5.53, 'LongCount': 25, 'Margin': 74.6, 'PnL': 1373951.2226000007, 'Returns': 20.94, 'Sharpe': 2.86, 'ShortCount': 34, 'TurnOver': 5.61, 'Year': '2017', 'YearId': '2017'}, {'BookSize': 20000000.0, 'DrawDown': 7.1, 'Fitness': 1.74, 'LongCount': 25, 'Margin': 45.54, 'PnL': 12673880.487599995, 'Returns': 12.52, 'Sharpe': 1.15, 'ShortCount': 36, 'TurnOver': 5.5, 'Year': '2007-2017', 'YearId': 'TOTAL'}], 'status': True}
# Parsing alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(indneutralize(rank(-rank(Ts_ZScore(capex/employee, 126))), 5 * rank(Ts_ZScore(cash_st/preferred_dividends, 126)) + 0.5))
# b'"DONE"'
# {'error': '', 'result': [{'BookSize': 20000000.0, 'DrawDown': 3.57, 'Fitness': 0.19, 'LongCount': 7, 'Margin': 8.91, 'PnL': 80698.73799999997, 'Returns': 3.67, 'Sharpe': 0.29, 'ShortCount': 10, 'TurnOver': 8.24, 'Year': '2007', 'YearId': '2007'}, {'BookSize': 20000000.0, 'DrawDown': 9.34, 'Fitness': 4.29, 'LongCount': 9, 'Margin': 147.77, 'PnL': 5246842.1959999995, 'Returns': 51.04, 'Sharpe': 1.58, 'ShortCount': 12, 'TurnOver': 6.91, 'Year': '2008', 'YearId': '2008'}, {'BookSize': 20000000.0, 'DrawDown': 10.99, 'Fitness': -1.74, 'LongCount': 12, 'Margin': -49.17, 'PnL': -1603687.8430000008, 'Returns': -15.6, 'Sharpe': -1.11, 'ShortCount': 18, 'TurnOver': 6.35, 'Year': '2009', 'YearId': '2009'}, {'BookSize': 20000000.0, 'DrawDown': 5.89, 'Fitness': -0.72, 'LongCount': 14, 'Margin': -22.8, 'PnL': -595618.9439999994, 'Returns': -5.77, 'Sharpe': -0.67, 'ShortCount': 18, 'TurnOver': 5.06, 'Year': '2010', 'YearId': '2010'}, {'BookSize': 20000000.0, 'DrawDown': 4.95, 'Fitness': -0.23, 'LongCount': 16, 'Margin': -10.0, 'PnL': -293553.2309999998, 'Returns': -2.86, 'Sharpe': -0.32, 'ShortCount': 20, 'TurnOver': 5.71, 'Year': '2011', 'YearId': '2011'}, {'BookSize': 20000000.0, 'DrawDown': 3.1, 'Fitness': 2.97, 'LongCount': 14, 'Margin': 59.62, 'PnL': 1752488.0264000015, 'Returns': 17.05, 'Sharpe': 1.72, 'ShortCount': 19, 'TurnOver': 5.72, 'Year': '2012', 'YearId': '2012'}, {'BookSize': 20000000.0, 'DrawDown': 2.13, 'Fitness': 3.47, 'LongCount': 14, 'Margin': 54.74, 'PnL': 1941785.857, 'Returns': 18.96, 'Sharpe': 2.1, 'ShortCount': 16, 'TurnOver': 6.93, 'Year': '2013', 'YearId': '2013'}, {'BookSize': 20000000.0, 'DrawDown': 2.43, 'Fitness': 3.52, 'LongCount': 12, 'Margin': 54.12, 'PnL': 1631224.6759999995, 'Returns': 15.93, 'Sharpe': 2.14, 'ShortCount': 17, 'TurnOver': 5.89, 'Year': '2014', 'YearId': '2014'}, {'BookSize': 20000000.0, 'DrawDown': 2.55, 'Fitness': 1.67, 'LongCount': 13, 'Margin': 37.62, 'PnL': 1066897.4440000006, 'Returns': 10.38, 'Sharpe': 1.22, 'ShortCount': 19, 'TurnOver': 5.52, 'Year': '2015', 'YearId': '2015'}, {'BookSize': 20000000.0, 'DrawDown': 2.6, 'Fitness': 0.2, 'LongCount': 15, 'Margin': 9.42, 'PnL': 257363.97299999985, 'Returns': 2.5, 'Sharpe': 0.29, 'ShortCount': 24, 'TurnOver': 5.31, 'Year': '2016', 'YearId': '2016'}, {'BookSize': 20000000.0, 'DrawDown': 2.32, 'Fitness': 0.02, 'LongCount': 16, 'Margin': 1.27, 'PnL': 26855.61899999974, 'Returns': 0.41, 'Sharpe': 0.07, 'ShortCount': 22, 'TurnOver': 6.44, 'Year': '2017', 'YearId': '2017'}, {'BookSize': 20000000.0, 'DrawDown': 19.26, 'Fitness': 0.86, 'LongCount': 13, 'Margin': 31.24, 'PnL': 9511296.511400007, 'Returns': 9.39, 'Sharpe': 0.69, 'ShortCount': 18, 'TurnOver': 6.01, 'Year': '2007-2017', 'YearId': 'TOTAL'}], 'status': True}
# Parsing alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126))
# b'69'
# Alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126)) not finished simulation, 69 percent proceeded
# Parsing alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126))
# b'69'
# Alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126)) not finished simulation, 69 percent proceeded
# Parsing alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126))
# b'69'
# Alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126)) not finished simulation, 69 percent proceeded
# Parsing alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126))
# b'69'
# Alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126)) not finished simulation, 69 percent proceeded
# Parsing alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126))
# b'69'
# Alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126)) not finished simulation, 69 percent proceeded
# Parsing alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126))
# b'69'
# Alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126)) not finished simulation, 69 percent proceeded
# Parsing alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126))
# b'69'
# Alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126)) not finished simulation, 69 percent proceeded
# Parsing alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126))
# b'69'
# Alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126)) not finished simulation, 69 percent proceeded
# Parsing alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126))
# b'69'
# Alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126)) not finished simulation, 69 percent proceeded
# Parsing alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126))
# b'69'
# Alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126)) not finished simulation, 69 percent proceeded
# Parsing alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126))
# b'69'
# Alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126)) not finished simulation, 69 percent proceeded
# Alpha rank(rank(Ts_ZScore(inventory_turnover/pretax_income, 126))) * rank(Ts_Skewness((accounts_payable - cashflow_op)/ppent, 126)) has been processing too long, start to parse next alpha
# Function parsing alphas finished
#
#
# Function parse submissions started
# Function parse submissions finished
# ['-rank(Ts_ZScore(pretax_income/sales, 126))']
# -rank(Ts_ZScore(pretax_income/sales, 126))
# (0, 0)
# (1, 32)

# %%
for i in range(50):
    mode.simulate_base_pack(300)
    mode.parse_pack(50)
# Out:
# Function simulating alphas started
# Simulating alpha rank(Ts_ZScore(assets/cashflow, 126))
# Simulating alpha rank(Ts_ZScore(assets/cashflow_dividends, 126))
# Simulating alpha rank(Ts_ZScore(assets/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(assets/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(assets/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(assets/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(assets/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/cashflow, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/cashflow_dividends, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/cashflow, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/cashflow_dividends, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(capex/cashflow, 126))
# Simulating alpha rank(Ts_ZScore(capex/cashflow_dividends, 126))
# Simulating alpha rank(Ts_ZScore(capex/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(capex/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(capex/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(capex/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(capex/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(cash/cashflow, 126))
# Simulating alpha rank(Ts_ZScore(cash/cashflow_dividends, 126))
# Simulating alpha rank(Ts_ZScore(cash/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(cash/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(cash/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(cash/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(cash/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/cashflow_dividends, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/cashflow_fin, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/cashflow_invst, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/cashflow_op, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/cogs, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/current_ratio, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/debt, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/debt_lt, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/debt_st, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/depre_amort, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/EBIT, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/EBITDA, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/employee, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/enterprise_value, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/eps, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/equity, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/goodwill, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/income, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/income_beforeextra, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/income_tax, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/interest_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/inventory, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/inventory_turnover, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/liabilities, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/liabilities_curr, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/operating_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/operating_income, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/pretax_income, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/receivable, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/retained_earnings, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/return_assets, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/return_equity, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/revenue, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/sales, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/SGA_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/cashflow_fin, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/cashflow_invst, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/cashflow_op, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/cogs, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/current_ratio, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/debt, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/debt_lt, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/debt_st, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/depre_amort, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/EBIT, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/EBITDA, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/employee, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/enterprise_value, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/eps, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/equity, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/goodwill, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/income, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/income_beforeextra, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/income_tax, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/interest_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/inventory, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/inventory_turnover, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/liabilities, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/liabilities_curr, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/operating_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/operating_income, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/pretax_income, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/receivable, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/retained_earnings, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/return_assets, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/return_equity, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/revenue, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/sales, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/SGA_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_op/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_op/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_op/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_op/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_op/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(cogs/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(cogs/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(cogs/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(cogs/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(cogs/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(current_ratio/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(current_ratio/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(current_ratio/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(current_ratio/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(current_ratio/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(debt/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(debt/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(debt/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(debt/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(debt/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(debt_lt/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(debt_lt/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(debt_lt/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(debt_lt/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(debt_lt/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(debt_st/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(debt_st/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(debt_st/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(debt_st/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(debt_st/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(depre_amort/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(depre_amort/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(depre_amort/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(depre_amort/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(depre_amort/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(EBIT/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(EBIT/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(EBIT/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(EBIT/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(EBIT/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(EBITDA/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(EBITDA/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(EBITDA/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(EBITDA/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(EBITDA/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(employee/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(employee/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(employee/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(employee/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(employee/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(enterprise_value/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(enterprise_value/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(enterprise_value/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(enterprise_value/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(enterprise_value/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(eps/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(eps/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(eps/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(eps/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(eps/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(equity/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(equity/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(equity/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(equity/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(equity/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(goodwill/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(goodwill/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(goodwill/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(goodwill/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(goodwill/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(income/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(income/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(income/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(income/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(income/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(income_beforeextra/inventory_turnover, 126))
# Simulating alpha rank(Ts_ZScore(income_beforeextra/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(income_beforeextra/liabilities, 126))
# Simulating alpha rank(Ts_ZScore(income_beforeextra/liabilities_curr, 126))
# Simulating alpha rank(Ts_ZScore(income_beforeextra/operating_expense, 126))
# Simulating alpha rank(Ts_ZScore(income_beforeextra/operating_income, 126))
# Simulating alpha rank(Ts_ZScore(income_beforeextra/pretax_income, 126))
# Simulating alpha rank(Ts_ZScore(income_beforeextra/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(income_beforeextra/receivable, 126))
# Simulating alpha rank(Ts_ZScore(income_beforeextra/retained_earnings, 126))
# Simulating alpha rank(Ts_ZScore(income_beforeextra/return_assets, 126))
# Simulating alpha rank(Ts_ZScore(income_beforeextra/return_equity, 126))
# Simulating alpha rank(Ts_ZScore(income_beforeextra/revenue, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(income_beforeextra/revenue, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(income_beforeextra/revenue, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(income_beforeextra/revenue, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(income_beforeextra/revenue, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(income_beforeextra/revenue, 126))
# Simulating alpha rank(Ts_ZScore(income_beforeextra/sales, 126))
# Simulating alpha rank(Ts_ZScore(income_beforeextra/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(income_beforeextra/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(income_beforeextra/SGA_expense, 126))
# Simulating alpha rank(Ts_ZScore(income_beforeextra/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(income_tax/interest_expense, 126))
# Simulating alpha rank(Ts_ZScore(income_tax/inventory, 126))
# Simulating alpha rank(Ts_ZScore(income_tax/inventory_turnover, 126))
# Simulating alpha rank(Ts_ZScore(income_tax/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(income_tax/liabilities, 126))
# Simulating alpha rank(Ts_ZScore(income_tax/liabilities_curr, 126))
# Simulating alpha rank(Ts_ZScore(income_tax/operating_expense, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(income_tax/operating_expense, 126))
# Simulating alpha rank(Ts_ZScore(income_tax/operating_income, 126))
# Simulating alpha rank(Ts_ZScore(income_tax/pretax_income, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(income_tax/pretax_income, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(income_tax/pretax_income, 126))
# Simulating alpha rank(Ts_ZScore(income_tax/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(income_tax/receivable, 126))
# Simulating alpha rank(Ts_ZScore(income_tax/retained_earnings, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(income_tax/retained_earnings, 126))
# Simulating alpha rank(Ts_ZScore(income_tax/return_assets, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(income_tax/return_assets, 126))
# Simulating alpha rank(Ts_ZScore(income_tax/return_equity, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(income_tax/return_equity, 126))
# Simulating alpha rank(Ts_ZScore(income_tax/revenue, 126))
# Simulating alpha rank(Ts_ZScore(income_tax/sales, 126))
# Simulating alpha rank(Ts_ZScore(income_tax/sales_growth, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(income_tax/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(income_tax/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(income_tax/SGA_expense, 126))
# Simulating alpha rank(Ts_ZScore(income_tax/working_capital, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(income_tax/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(interest_expense/inventory, 126))
# Simulating alpha rank(Ts_ZScore(interest_expense/inventory_turnover, 126))
# Simulating alpha rank(Ts_ZScore(interest_expense/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(interest_expense/liabilities, 126))
# Simulating alpha rank(Ts_ZScore(interest_expense/liabilities_curr, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(interest_expense/liabilities_curr, 126))
# Simulating alpha rank(Ts_ZScore(interest_expense/operating_expense, 126))
# Simulating alpha rank(Ts_ZScore(interest_expense/operating_income, 126))
# Simulating alpha rank(Ts_ZScore(interest_expense/pretax_income, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(interest_expense/pretax_income, 126))
# Simulating alpha rank(Ts_ZScore(interest_expense/rd_expense, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(interest_expense/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(interest_expense/receivable, 126))
# Simulating alpha rank(Ts_ZScore(interest_expense/retained_earnings, 126))
# Simulating alpha rank(Ts_ZScore(interest_expense/return_assets, 126))
# Simulating alpha rank(Ts_ZScore(interest_expense/return_equity, 126))
# Simulating alpha rank(Ts_ZScore(interest_expense/revenue, 126))
# Simulating alpha rank(Ts_ZScore(interest_expense/sales, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(interest_expense/sales, 126))
# Simulating alpha rank(Ts_ZScore(interest_expense/sales_growth, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(interest_expense/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(interest_expense/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(interest_expense/SGA_expense, 126))
# Simulating alpha rank(Ts_ZScore(interest_expense/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(inventory/inventory_turnover, 126))
# Simulating alpha rank(Ts_ZScore(inventory/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(inventory/liabilities, 126))
# Simulating alpha rank(Ts_ZScore(inventory/liabilities_curr, 126))
# Simulating alpha rank(Ts_ZScore(inventory/operating_expense, 126))
# Simulating alpha rank(Ts_ZScore(inventory/operating_income, 126))
# Simulating alpha rank(Ts_ZScore(inventory/pretax_income, 126))
# Simulating alpha rank(Ts_ZScore(inventory/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(inventory/receivable, 126))
# Simulating alpha rank(Ts_ZScore(inventory/retained_earnings, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(inventory/retained_earnings, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(inventory/retained_earnings, 126))
# Simulating alpha rank(Ts_ZScore(inventory/return_assets, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(inventory/return_assets, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(inventory/return_assets, 126))
# Simulating alpha rank(Ts_ZScore(inventory/return_equity, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(inventory/return_equity, 126))
# Simulating alpha rank(Ts_ZScore(inventory/revenue, 126))
# Simulating alpha rank(Ts_ZScore(inventory/sales, 126))
# Simulating alpha rank(Ts_ZScore(inventory/sales_growth, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(inventory/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(inventory/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(inventory/SGA_expense, 126))
# Simulating alpha rank(Ts_ZScore(inventory/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(inventory_turnover/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(inventory_turnover/liabilities, 126))
# Simulating alpha rank(Ts_ZScore(inventory_turnover/liabilities_curr, 126))
# Simulating alpha rank(Ts_ZScore(inventory_turnover/operating_expense, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(inventory_turnover/operating_expense, 126))
# Simulating alpha rank(Ts_ZScore(inventory_turnover/operating_income, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(inventory_turnover/operating_income, 126))
# Simulating alpha rank(Ts_ZScore(inventory_turnover/pretax_income, 126))
# Simulating alpha rank(Ts_ZScore(inventory_turnover/rd_expense, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(inventory_turnover/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(inventory_turnover/receivable, 126))
# Simulating alpha rank(Ts_ZScore(inventory_turnover/retained_earnings, 126))
# Simulating alpha rank(Ts_ZScore(inventory_turnover/return_assets, 126))
# Simulating alpha rank(Ts_ZScore(inventory_turnover/return_equity, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(inventory_turnover/return_equity, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(inventory_turnover/return_equity, 126))
# Simulating alpha rank(Ts_ZScore(inventory_turnover/revenue, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(inventory_turnover/revenue, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(inventory_turnover/revenue, 126))
# Simulating alpha rank(Ts_ZScore(inventory_turnover/sales, 126))
# Simulating alpha rank(Ts_ZScore(inventory_turnover/sales_growth, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(inventory_turnover/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(inventory_turnover/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(inventory_turnover/SGA_expense, 126))
# Simulating alpha rank(Ts_ZScore(inventory_turnover/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(invested_capital/liabilities, 126))
# Simulating alpha rank(Ts_ZScore(invested_capital/liabilities_curr, 126))
# Simulating alpha rank(Ts_ZScore(invested_capital/operating_expense, 126))
# Simulating alpha rank(Ts_ZScore(invested_capital/operating_income, 126))
# Simulating alpha rank(Ts_ZScore(invested_capital/pretax_income, 126))
# Simulating alpha rank(Ts_ZScore(invested_capital/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(invested_capital/receivable, 126))
# Simulating alpha rank(Ts_ZScore(invested_capital/retained_earnings, 126))
# Simulating alpha rank(Ts_ZScore(invested_capital/return_assets, 126))
# Function simulating alphas finished
#
#
# Function parsing alphas started
# Parsing alpha rank(Ts_ZScore(assets/cashflow, 126))
# Alpha rank(Ts_ZScore(assets/cashflow, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/cashflow, 126))
# Alpha rank(Ts_ZScore(assets/cashflow, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/cashflow, 126))
# Alpha rank(Ts_ZScore(assets/cashflow, 126)) not finished simulation
# Deleting alpha rank(Ts_ZScore(assets/cashflow, 126)) from purgatory
# Parsing alpha rank(Ts_ZScore(assets/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(assets/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(assets/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(assets/cashflow_dividends, 126)) not finished simulation
# Deleting alpha rank(Ts_ZScore(assets/cashflow_dividends, 126)) from purgatory
# Parsing alpha rank(Ts_ZScore(assets/invested_capital, 126))
# Alpha rank(Ts_ZScore(assets/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/invested_capital, 126))
# Alpha rank(Ts_ZScore(assets/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/invested_capital, 126))
# Alpha rank(Ts_ZScore(assets/invested_capital, 126)) not finished simulation
# Deleting alpha rank(Ts_ZScore(assets/invested_capital, 126)) from purgatory
# Parsing alpha rank(Ts_ZScore(assets/rd_expense, 126))
# Alpha rank(Ts_ZScore(assets/rd_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/rd_expense, 126))
# Alpha rank(Ts_ZScore(assets/rd_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/rd_expense, 126))
# Alpha rank(Ts_ZScore(assets/rd_expense, 126)) not finished simulation
# Deleting alpha rank(Ts_ZScore(assets/rd_expense, 126)) from purgatory
# Parsing alpha rank(Ts_ZScore(assets/sales_growth, 126))
# Alpha rank(Ts_ZScore(assets/sales_growth, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/sales_growth, 126))
# Alpha rank(Ts_ZScore(assets/sales_growth, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/sales_growth, 126))
# Alpha rank(Ts_ZScore(assets/sales_growth, 126)) not finished simulation
# Deleting alpha rank(Ts_ZScore(assets/sales_growth, 126)) from purgatory
# Parsing alpha rank(Ts_ZScore(assets/sales_ps, 126))
# Alpha rank(Ts_ZScore(assets/sales_ps, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/sales_ps, 126))
# Alpha rank(Ts_ZScore(assets/sales_ps, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/sales_ps, 126))
# Alpha rank(Ts_ZScore(assets/sales_ps, 126)) not finished simulation
# Deleting alpha rank(Ts_ZScore(assets/sales_ps, 126)) from purgatory
# Parsing alpha rank(Ts_ZScore(assets/working_capital, 126))
# Alpha rank(Ts_ZScore(assets/working_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/working_capital, 126))
# Alpha rank(Ts_ZScore(assets/working_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/working_capital, 126))
# Alpha rank(Ts_ZScore(assets/working_capital, 126)) not finished simulation
# Deleting alpha rank(Ts_ZScore(assets/working_capital, 126)) from purgatory
# Parsing alpha rank(Ts_ZScore(assets_curr/cashflow, 126))
# Alpha rank(Ts_ZScore(assets_curr/cashflow, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/cashflow, 126))
# Alpha rank(Ts_ZScore(assets_curr/cashflow, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/cashflow, 126))
# Alpha rank(Ts_ZScore(assets_curr/cashflow, 126)) not finished simulation
# Deleting alpha rank(Ts_ZScore(assets_curr/cashflow, 126)) from purgatory
# Parsing alpha rank(Ts_ZScore(assets_curr/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(assets_curr/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(assets_curr/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(assets_curr/cashflow_dividends, 126)) not finished simulation
# Deleting alpha rank(Ts_ZScore(assets_curr/cashflow_dividends, 126)) from purgatory
# Parsing alpha rank(Ts_ZScore(assets_curr/invested_capital, 126))
# Alpha rank(Ts_ZScore(assets_curr/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/invested_capital, 126))
# Alpha rank(Ts_ZScore(assets_curr/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/invested_capital, 126))
# Alpha rank(Ts_ZScore(assets_curr/invested_capital, 126)) not finished simulation
# Deleting alpha rank(Ts_ZScore(assets_curr/invested_capital, 126)) from purgatory
# Parsing alpha rank(Ts_ZScore(assets_curr/rd_expense, 126))
# Alpha rank(Ts_ZScore(assets_curr/rd_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/rd_expense, 126))
# Alpha rank(Ts_ZScore(assets_curr/rd_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/rd_expense, 126))
# Alpha rank(Ts_ZScore(assets_curr/rd_expense, 126)) not finished simulation
# Deleting alpha rank(Ts_ZScore(assets_curr/rd_expense, 126)) from purgatory
# Parsing alpha rank(Ts_ZScore(assets_curr/sales_growth, 126))
# Alpha rank(Ts_ZScore(assets_curr/sales_growth, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/sales_growth, 126))
# Alpha rank(Ts_ZScore(assets_curr/sales_growth, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/sales_growth, 126))
# Alpha rank(Ts_ZScore(assets_curr/sales_growth, 126)) not finished simulation
# Deleting alpha rank(Ts_ZScore(assets_curr/sales_growth, 126)) from purgatory
# Parsing alpha rank(Ts_ZScore(assets_curr/sales_ps, 126))
# Alpha rank(Ts_ZScore(assets_curr/sales_ps, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/sales_ps, 126))
# Alpha rank(Ts_ZScore(assets_curr/sales_ps, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/sales_ps, 126))

# %%
for i in range(50):
    mode.simulate_base_pack(200)
# Out:
# Function simulating alphas started
# Simulating alpha rank(Ts_ZScore(assets/assets_curr, 126))
# Simulating alpha rank(Ts_ZScore(assets/bookvalue_ps, 126))
# Simulating alpha rank(Ts_ZScore(assets/capex, 126))
# Simulating alpha rank(Ts_ZScore(assets/cash, 126))
# Simulating alpha rank(Ts_ZScore(assets/cashflow, 126))
# Simulating alpha rank(Ts_ZScore(assets/cashflow_dividends, 126))
# Simulating alpha rank(Ts_ZScore(assets/cashflow_fin, 126))
# Simulating alpha rank(Ts_ZScore(assets/cashflow_invst, 126))
# Simulating alpha rank(Ts_ZScore(assets/cashflow_op, 126))
# Simulating alpha rank(Ts_ZScore(assets/cogs, 126))
# Simulating alpha rank(Ts_ZScore(assets/current_ratio, 126))
# Simulating alpha rank(Ts_ZScore(assets/debt, 126))
# Simulating alpha rank(Ts_ZScore(assets/debt_lt, 126))
# Simulating alpha rank(Ts_ZScore(assets/debt_st, 126))
# Simulating alpha rank(Ts_ZScore(assets/depre_amort, 126))
# Simulating alpha rank(Ts_ZScore(assets/EBIT, 126))
# Simulating alpha rank(Ts_ZScore(assets/EBITDA, 126))
# Simulating alpha rank(Ts_ZScore(assets/employee, 126))
# Simulating alpha rank(Ts_ZScore(assets/enterprise_value, 126))
# Simulating alpha rank(Ts_ZScore(assets/eps, 126))
# Simulating alpha rank(Ts_ZScore(assets/equity, 126))
# Simulating alpha rank(Ts_ZScore(assets/goodwill, 126))
# Simulating alpha rank(Ts_ZScore(assets/income, 126))
# Simulating alpha rank(Ts_ZScore(assets/income_beforeextra, 126))
# Simulating alpha rank(Ts_ZScore(assets/income_tax, 126))
# Simulating alpha rank(Ts_ZScore(assets/interest_expense, 126))
# Simulating alpha rank(Ts_ZScore(assets/inventory, 126))
# Simulating alpha rank(Ts_ZScore(assets/inventory_turnover, 126))
# Simulating alpha rank(Ts_ZScore(assets/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(assets/liabilities, 126))
# Simulating alpha rank(Ts_ZScore(assets/liabilities_curr, 126))
# Simulating alpha rank(Ts_ZScore(assets/operating_expense, 126))
# Simulating alpha rank(Ts_ZScore(assets/operating_income, 126))
# Simulating alpha rank(Ts_ZScore(assets/pretax_income, 126))
# Simulating alpha rank(Ts_ZScore(assets/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(assets/receivable, 126))
# Simulating alpha rank(Ts_ZScore(assets/retained_earnings, 126))
# Simulating alpha rank(Ts_ZScore(assets/return_assets, 126))
# Simulating alpha rank(Ts_ZScore(assets/return_equity, 126))
# Simulating alpha rank(Ts_ZScore(assets/revenue, 126))
# Simulating alpha rank(Ts_ZScore(assets/sales, 126))
# Simulating alpha rank(Ts_ZScore(assets/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(assets/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(assets/SGA_expense, 126))
# Simulating alpha rank(Ts_ZScore(assets/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/bookvalue_ps, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/capex, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/cash, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/cashflow, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/cashflow_dividends, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/cashflow_fin, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/cashflow_invst, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/cashflow_op, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/cogs, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/current_ratio, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/debt, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/debt_lt, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/debt_st, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/depre_amort, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/EBIT, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/EBITDA, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/employee, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/enterprise_value, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/eps, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/equity, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/goodwill, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/income, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/income_beforeextra, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/income_tax, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/interest_expense, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/inventory, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/inventory_turnover, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/liabilities, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/liabilities_curr, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/operating_expense, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/operating_income, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/pretax_income, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/receivable, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/retained_earnings, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/return_assets, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/return_equity, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/revenue, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/sales, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/SGA_expense, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/capex, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/cash, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/cashflow, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/cashflow_dividends, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/cashflow_fin, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/cashflow_invst, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/cashflow_op, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/cogs, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/current_ratio, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/debt, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/debt_lt, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/debt_st, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/depre_amort, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/EBIT, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/EBITDA, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/employee, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/enterprise_value, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/eps, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/equity, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/goodwill, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/income, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/income_beforeextra, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/income_tax, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/interest_expense, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/inventory, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/inventory_turnover, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/liabilities, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/liabilities_curr, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/operating_expense, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/operating_income, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/pretax_income, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/receivable, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/retained_earnings, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/return_assets, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/return_equity, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/revenue, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/sales, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/SGA_expense, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(capex/cash, 126))
# Simulating alpha rank(Ts_ZScore(capex/cashflow, 126))
# Simulating alpha rank(Ts_ZScore(capex/cashflow_dividends, 126))
# Simulating alpha rank(Ts_ZScore(capex/cashflow_fin, 126))
# Simulating alpha rank(Ts_ZScore(capex/cashflow_invst, 126))
# Simulating alpha rank(Ts_ZScore(capex/cashflow_op, 126))
# Simulating alpha rank(Ts_ZScore(capex/cogs, 126))
# Simulating alpha rank(Ts_ZScore(capex/current_ratio, 126))
# Simulating alpha rank(Ts_ZScore(capex/debt, 126))
# Simulating alpha rank(Ts_ZScore(capex/debt_lt, 126))
# Simulating alpha rank(Ts_ZScore(capex/debt_st, 126))
# Simulating alpha rank(Ts_ZScore(capex/depre_amort, 126))
# Simulating alpha rank(Ts_ZScore(capex/EBIT, 126))
# Simulating alpha rank(Ts_ZScore(capex/EBITDA, 126))
# Simulating alpha rank(Ts_ZScore(capex/employee, 126))
# Simulating alpha rank(Ts_ZScore(capex/enterprise_value, 126))
# Simulating alpha rank(Ts_ZScore(capex/eps, 126))
# Simulating alpha rank(Ts_ZScore(capex/equity, 126))
# Simulating alpha rank(Ts_ZScore(capex/goodwill, 126))
# Simulating alpha rank(Ts_ZScore(capex/income, 126))
# Simulating alpha rank(Ts_ZScore(capex/income_beforeextra, 126))
# Simulating alpha rank(Ts_ZScore(capex/income_tax, 126))
# Simulating alpha rank(Ts_ZScore(capex/interest_expense, 126))
# Simulating alpha rank(Ts_ZScore(capex/inventory, 126))
# Simulating alpha rank(Ts_ZScore(capex/inventory_turnover, 126))
# Simulating alpha rank(Ts_ZScore(capex/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(capex/liabilities, 126))
# Simulating alpha rank(Ts_ZScore(capex/liabilities_curr, 126))
# Simulating alpha rank(Ts_ZScore(capex/operating_expense, 126))
# Simulating alpha rank(Ts_ZScore(capex/operating_income, 126))
# Simulating alpha rank(Ts_ZScore(capex/pretax_income, 126))
# Simulating alpha rank(Ts_ZScore(capex/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(capex/receivable, 126))
# Simulating alpha rank(Ts_ZScore(capex/retained_earnings, 126))
# Simulating alpha rank(Ts_ZScore(capex/return_assets, 126))
# Simulating alpha rank(Ts_ZScore(capex/return_equity, 126))
# Simulating alpha rank(Ts_ZScore(capex/revenue, 126))
# Simulating alpha rank(Ts_ZScore(capex/sales, 126))
# Simulating alpha rank(Ts_ZScore(capex/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(capex/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(capex/SGA_expense, 126))
# Simulating alpha rank(Ts_ZScore(capex/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(cash/cashflow, 126))
# Simulating alpha rank(Ts_ZScore(cash/cashflow_dividends, 126))
# Simulating alpha rank(Ts_ZScore(cash/cashflow_fin, 126))
# Simulating alpha rank(Ts_ZScore(cash/cashflow_invst, 126))
# Simulating alpha rank(Ts_ZScore(cash/cashflow_op, 126))
# Simulating alpha rank(Ts_ZScore(cash/cogs, 126))
# Simulating alpha rank(Ts_ZScore(cash/current_ratio, 126))
# Simulating alpha rank(Ts_ZScore(cash/debt, 126))
# Simulating alpha rank(Ts_ZScore(cash/debt_lt, 126))
# Simulating alpha rank(Ts_ZScore(cash/debt_st, 126))
# Simulating alpha rank(Ts_ZScore(cash/depre_amort, 126))
# Simulating alpha rank(Ts_ZScore(cash/EBIT, 126))
# Simulating alpha rank(Ts_ZScore(cash/EBITDA, 126))
# Simulating alpha rank(Ts_ZScore(cash/employee, 126))
# Simulating alpha rank(Ts_ZScore(cash/enterprise_value, 126))
# Simulating alpha rank(Ts_ZScore(cash/eps, 126))
# Simulating alpha rank(Ts_ZScore(cash/equity, 126))
# Simulating alpha rank(Ts_ZScore(cash/goodwill, 126))
# Simulating alpha rank(Ts_ZScore(cash/income, 126))
# Simulating alpha rank(Ts_ZScore(cash/income_beforeextra, 126))
# Simulating alpha rank(Ts_ZScore(cash/income_tax, 126))
# Simulating alpha rank(Ts_ZScore(cash/interest_expense, 126))
# Simulating alpha rank(Ts_ZScore(cash/inventory, 126))
# Simulating alpha rank(Ts_ZScore(cash/inventory_turnover, 126))
# Simulating alpha rank(Ts_ZScore(cash/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(cash/liabilities, 126))
# Function simulating alphas finished
#
#
# Function parsing alphas started
# Parsing alpha rank(Ts_ZScore(assets/assets_curr, 126))
# Parsing alpha rank(Ts_ZScore(assets/bookvalue_ps, 126))
# Parsing alpha rank(Ts_ZScore(assets/capex, 126))
# Parsing alpha rank(Ts_ZScore(assets/cash, 126))
# Parsing alpha rank(Ts_ZScore(assets/cashflow, 126))
# Alpha rank(Ts_ZScore(assets/cashflow, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/cashflow, 126))
# Alpha rank(Ts_ZScore(assets/cashflow, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/cashflow, 126))
# Alpha rank(Ts_ZScore(assets/cashflow, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(assets/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(assets/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(assets/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/cashflow_fin, 126))
# Parsing alpha rank(Ts_ZScore(assets/cashflow_invst, 126))
# Parsing alpha rank(Ts_ZScore(assets/cashflow_op, 126))
# Parsing alpha rank(Ts_ZScore(assets/cogs, 126))
# Parsing alpha rank(Ts_ZScore(assets/current_ratio, 126))
# Parsing alpha rank(Ts_ZScore(assets/debt, 126))
# Parsing alpha rank(Ts_ZScore(assets/debt_lt, 126))
# Parsing alpha rank(Ts_ZScore(assets/debt_st, 126))
# Parsing alpha rank(Ts_ZScore(assets/depre_amort, 126))
# Parsing alpha rank(Ts_ZScore(assets/EBIT, 126))
# Parsing alpha rank(Ts_ZScore(assets/EBITDA, 126))
# Parsing alpha rank(Ts_ZScore(assets/employee, 126))
# Parsing alpha rank(Ts_ZScore(assets/enterprise_value, 126))
# Parsing alpha rank(Ts_ZScore(assets/eps, 126))
# Parsing alpha rank(Ts_ZScore(assets/equity, 126))
# Parsing alpha rank(Ts_ZScore(assets/goodwill, 126))
# Parsing alpha rank(Ts_ZScore(assets/income, 126))
# Parsing alpha rank(Ts_ZScore(assets/income_beforeextra, 126))
# Parsing alpha rank(Ts_ZScore(assets/income_tax, 126))
# Parsing alpha rank(Ts_ZScore(assets/interest_expense, 126))
# Parsing alpha rank(Ts_ZScore(assets/inventory, 126))
# Parsing alpha rank(Ts_ZScore(assets/inventory_turnover, 126))
# Parsing alpha rank(Ts_ZScore(assets/invested_capital, 126))
# Alpha rank(Ts_ZScore(assets/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/invested_capital, 126))
# Alpha rank(Ts_ZScore(assets/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/invested_capital, 126))
# Alpha rank(Ts_ZScore(assets/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/liabilities, 126))
# Parsing alpha rank(Ts_ZScore(assets/liabilities_curr, 126))
# Parsing alpha rank(Ts_ZScore(assets/operating_expense, 126))
# Parsing alpha rank(Ts_ZScore(assets/operating_income, 126))
# Parsing alpha rank(Ts_ZScore(assets/pretax_income, 126))
# Parsing alpha rank(Ts_ZScore(assets/rd_expense, 126))
# Alpha rank(Ts_ZScore(assets/rd_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/rd_expense, 126))
# Alpha rank(Ts_ZScore(assets/rd_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/rd_expense, 126))
# Alpha rank(Ts_ZScore(assets/rd_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/receivable, 126))
# Parsing alpha rank(Ts_ZScore(assets/retained_earnings, 126))
# Parsing alpha rank(Ts_ZScore(assets/return_assets, 126))
# Parsing alpha rank(Ts_ZScore(assets/return_equity, 126))
# Parsing alpha rank(Ts_ZScore(assets/revenue, 126))
# Parsing alpha rank(Ts_ZScore(assets/sales, 126))
# Parsing alpha rank(Ts_ZScore(assets/sales_growth, 126))
# Alpha rank(Ts_ZScore(assets/sales_growth, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/sales_growth, 126))
# Alpha rank(Ts_ZScore(assets/sales_growth, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/sales_growth, 126))
# Alpha rank(Ts_ZScore(assets/sales_growth, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/sales_ps, 126))
# Alpha rank(Ts_ZScore(assets/sales_ps, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/sales_ps, 126))
# Alpha rank(Ts_ZScore(assets/sales_ps, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/sales_ps, 126))
# Alpha rank(Ts_ZScore(assets/sales_ps, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/SGA_expense, 126))
# Parsing alpha rank(Ts_ZScore(assets/working_capital, 126))
# Alpha rank(Ts_ZScore(assets/working_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/working_capital, 126))
# Alpha rank(Ts_ZScore(assets/working_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets/working_capital, 126))
# Alpha rank(Ts_ZScore(assets/working_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/bookvalue_ps, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/capex, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/cash, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/cashflow, 126))
# Alpha rank(Ts_ZScore(assets_curr/cashflow, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/cashflow, 126))
# Alpha rank(Ts_ZScore(assets_curr/cashflow, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/cashflow, 126))
# Alpha rank(Ts_ZScore(assets_curr/cashflow, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(assets_curr/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(assets_curr/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(assets_curr/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/cashflow_fin, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/cashflow_invst, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/cashflow_op, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/cogs, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/current_ratio, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/debt, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/debt_lt, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/debt_st, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/depre_amort, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/EBIT, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/EBITDA, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/employee, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/enterprise_value, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/eps, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/equity, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/goodwill, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/income, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/income_beforeextra, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/income_tax, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/interest_expense, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/inventory, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/inventory_turnover, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/invested_capital, 126))
# Alpha rank(Ts_ZScore(assets_curr/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/invested_capital, 126))
# Alpha rank(Ts_ZScore(assets_curr/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/invested_capital, 126))
# Alpha rank(Ts_ZScore(assets_curr/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/liabilities, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/liabilities_curr, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/operating_expense, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/operating_income, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/pretax_income, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/rd_expense, 126))
# Alpha rank(Ts_ZScore(assets_curr/rd_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/rd_expense, 126))
# Alpha rank(Ts_ZScore(assets_curr/rd_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/rd_expense, 126))
# Alpha rank(Ts_ZScore(assets_curr/rd_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/receivable, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/retained_earnings, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/return_assets, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/return_equity, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/revenue, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/sales, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/sales_growth, 126))
# Alpha rank(Ts_ZScore(assets_curr/sales_growth, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/sales_growth, 126))
# Alpha rank(Ts_ZScore(assets_curr/sales_growth, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/sales_growth, 126))
# Alpha rank(Ts_ZScore(assets_curr/sales_growth, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/sales_ps, 126))
# Alpha rank(Ts_ZScore(assets_curr/sales_ps, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/sales_ps, 126))
# Alpha rank(Ts_ZScore(assets_curr/sales_ps, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/sales_ps, 126))
# Alpha rank(Ts_ZScore(assets_curr/sales_ps, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/SGA_expense, 126))
# Parsing alpha rank(Ts_ZScore(assets_curr/working_capital, 126))
# Alpha rank(Ts_ZScore(assets_curr/working_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/working_capital, 126))
# Alpha rank(Ts_ZScore(assets_curr/working_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(assets_curr/working_capital, 126))
# Alpha rank(Ts_ZScore(assets_curr/working_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/capex, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/cash, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/cashflow, 126))
# Alpha rank(Ts_ZScore(bookvalue_ps/cashflow, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/cashflow, 126))
# Alpha rank(Ts_ZScore(bookvalue_ps/cashflow, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/cashflow, 126))
# Alpha rank(Ts_ZScore(bookvalue_ps/cashflow, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(bookvalue_ps/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(bookvalue_ps/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(bookvalue_ps/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/cashflow_fin, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/cashflow_invst, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/cashflow_op, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/cogs, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/current_ratio, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/debt, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/debt_lt, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/debt_st, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/depre_amort, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/EBIT, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/EBITDA, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/employee, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/enterprise_value, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/eps, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/equity, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/goodwill, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/income, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/income_beforeextra, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/income_tax, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/interest_expense, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/inventory, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/inventory_turnover, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/invested_capital, 126))
# Alpha rank(Ts_ZScore(bookvalue_ps/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/invested_capital, 126))
# Alpha rank(Ts_ZScore(bookvalue_ps/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/invested_capital, 126))
# Alpha rank(Ts_ZScore(bookvalue_ps/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/liabilities, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/liabilities_curr, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/operating_expense, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/operating_income, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/pretax_income, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/rd_expense, 126))
# Alpha rank(Ts_ZScore(bookvalue_ps/rd_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/rd_expense, 126))
# Alpha rank(Ts_ZScore(bookvalue_ps/rd_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/rd_expense, 126))
# Alpha rank(Ts_ZScore(bookvalue_ps/rd_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/receivable, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/retained_earnings, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/return_assets, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/return_equity, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/revenue, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/sales, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/sales_growth, 126))
# Alpha rank(Ts_ZScore(bookvalue_ps/sales_growth, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/sales_growth, 126))
# Alpha rank(Ts_ZScore(bookvalue_ps/sales_growth, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/sales_growth, 126))
# Alpha rank(Ts_ZScore(bookvalue_ps/sales_growth, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/sales_ps, 126))
# Alpha rank(Ts_ZScore(bookvalue_ps/sales_ps, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/sales_ps, 126))
# Alpha rank(Ts_ZScore(bookvalue_ps/sales_ps, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/sales_ps, 126))
# Alpha rank(Ts_ZScore(bookvalue_ps/sales_ps, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/SGA_expense, 126))
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/working_capital, 126))
# Alpha rank(Ts_ZScore(bookvalue_ps/working_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/working_capital, 126))
# Alpha rank(Ts_ZScore(bookvalue_ps/working_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(bookvalue_ps/working_capital, 126))
# Alpha rank(Ts_ZScore(bookvalue_ps/working_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(capex/cash, 126))
# Parsing alpha rank(Ts_ZScore(capex/cashflow, 126))
# Alpha rank(Ts_ZScore(capex/cashflow, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(capex/cashflow, 126))
# Alpha rank(Ts_ZScore(capex/cashflow, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(capex/cashflow, 126))
# Alpha rank(Ts_ZScore(capex/cashflow, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(capex/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(capex/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(capex/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(capex/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(capex/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(capex/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(capex/cashflow_fin, 126))
# Parsing alpha rank(Ts_ZScore(capex/cashflow_invst, 126))
# Parsing alpha rank(Ts_ZScore(capex/cashflow_op, 126))
# Parsing alpha rank(Ts_ZScore(capex/cogs, 126))
# Parsing alpha rank(Ts_ZScore(capex/current_ratio, 126))
# Parsing alpha rank(Ts_ZScore(capex/debt, 126))
# Parsing alpha rank(Ts_ZScore(capex/debt_lt, 126))
# Parsing alpha rank(Ts_ZScore(capex/debt_st, 126))
# Parsing alpha rank(Ts_ZScore(capex/depre_amort, 126))
# Parsing alpha rank(Ts_ZScore(capex/EBIT, 126))
# Parsing alpha rank(Ts_ZScore(capex/EBITDA, 126))
# Parsing alpha rank(Ts_ZScore(capex/employee, 126))
# Parsing alpha rank(Ts_ZScore(capex/enterprise_value, 126))
# Parsing alpha rank(Ts_ZScore(capex/eps, 126))
# Parsing alpha rank(Ts_ZScore(capex/equity, 126))
# Parsing alpha rank(Ts_ZScore(capex/goodwill, 126))
# Parsing alpha rank(Ts_ZScore(capex/income, 126))
# Parsing alpha rank(Ts_ZScore(capex/income_beforeextra, 126))
# Parsing alpha rank(Ts_ZScore(capex/income_tax, 126))
# Parsing alpha rank(Ts_ZScore(capex/interest_expense, 126))
# Parsing alpha rank(Ts_ZScore(capex/inventory, 126))
# Parsing alpha rank(Ts_ZScore(capex/inventory_turnover, 126))
# Parsing alpha rank(Ts_ZScore(capex/invested_capital, 126))
# Alpha rank(Ts_ZScore(capex/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(capex/invested_capital, 126))
# Alpha rank(Ts_ZScore(capex/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(capex/invested_capital, 126))
# Alpha rank(Ts_ZScore(capex/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(capex/liabilities, 126))
# Parsing alpha rank(Ts_ZScore(capex/liabilities_curr, 126))
# Parsing alpha rank(Ts_ZScore(capex/operating_expense, 126))
# Parsing alpha rank(Ts_ZScore(capex/operating_income, 126))
# Parsing alpha rank(Ts_ZScore(capex/pretax_income, 126))
# Parsing alpha rank(Ts_ZScore(capex/rd_expense, 126))
# Alpha rank(Ts_ZScore(capex/rd_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(capex/rd_expense, 126))
# Alpha rank(Ts_ZScore(capex/rd_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(capex/rd_expense, 126))
# Alpha rank(Ts_ZScore(capex/rd_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(capex/receivable, 126))
# Parsing alpha rank(Ts_ZScore(capex/retained_earnings, 126))
# Parsing alpha rank(Ts_ZScore(capex/return_assets, 126))
# Parsing alpha rank(Ts_ZScore(capex/return_equity, 126))
# Parsing alpha rank(Ts_ZScore(capex/revenue, 126))
# Parsing alpha rank(Ts_ZScore(capex/sales, 126))
# Parsing alpha rank(Ts_ZScore(capex/sales_growth, 126))
# Alpha rank(Ts_ZScore(capex/sales_growth, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(capex/sales_growth, 126))
# Alpha rank(Ts_ZScore(capex/sales_growth, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(capex/sales_growth, 126))
# Alpha rank(Ts_ZScore(capex/sales_growth, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(capex/sales_ps, 126))
# Alpha rank(Ts_ZScore(capex/sales_ps, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(capex/sales_ps, 126))
# Alpha rank(Ts_ZScore(capex/sales_ps, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(capex/sales_ps, 126))
# Alpha rank(Ts_ZScore(capex/sales_ps, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(capex/SGA_expense, 126))
# Parsing alpha rank(Ts_ZScore(capex/working_capital, 126))
# Alpha rank(Ts_ZScore(capex/working_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(capex/working_capital, 126))
# Alpha rank(Ts_ZScore(capex/working_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(capex/working_capital, 126))
# Alpha rank(Ts_ZScore(capex/working_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/cashflow, 126))
# Alpha rank(Ts_ZScore(cash/cashflow, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/cashflow, 126))
# Alpha rank(Ts_ZScore(cash/cashflow, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/cashflow, 126))
# Alpha rank(Ts_ZScore(cash/cashflow, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(cash/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(cash/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(cash/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/cashflow_fin, 126))
# Parsing alpha rank(Ts_ZScore(cash/cashflow_invst, 126))
# Parsing alpha rank(Ts_ZScore(cash/cashflow_op, 126))
# Parsing alpha rank(Ts_ZScore(cash/cogs, 126))
# Parsing alpha rank(Ts_ZScore(cash/current_ratio, 126))
# Parsing alpha rank(Ts_ZScore(cash/debt, 126))
# Parsing alpha rank(Ts_ZScore(cash/debt_lt, 126))
# Parsing alpha rank(Ts_ZScore(cash/debt_st, 126))
# Parsing alpha rank(Ts_ZScore(cash/depre_amort, 126))
# Parsing alpha rank(Ts_ZScore(cash/EBIT, 126))
# Parsing alpha rank(Ts_ZScore(cash/EBITDA, 126))
# Parsing alpha rank(Ts_ZScore(cash/employee, 126))
# Parsing alpha rank(Ts_ZScore(cash/enterprise_value, 126))
# Parsing alpha rank(Ts_ZScore(cash/eps, 126))
# Parsing alpha rank(Ts_ZScore(cash/equity, 126))
# Parsing alpha rank(Ts_ZScore(cash/goodwill, 126))
# Parsing alpha rank(Ts_ZScore(cash/income, 126))
# Parsing alpha rank(Ts_ZScore(cash/income_beforeextra, 126))
# Parsing alpha rank(Ts_ZScore(cash/income_tax, 126))
# Parsing alpha rank(Ts_ZScore(cash/interest_expense, 126))
# Parsing alpha rank(Ts_ZScore(cash/inventory, 126))
# Parsing alpha rank(Ts_ZScore(cash/inventory_turnover, 126))
# Parsing alpha rank(Ts_ZScore(cash/invested_capital, 126))
# Alpha rank(Ts_ZScore(cash/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/invested_capital, 126))
# Alpha rank(Ts_ZScore(cash/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/invested_capital, 126))
# Alpha rank(Ts_ZScore(cash/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/liabilities, 126))
# Function parsing alphas finished
#
#
# Function parse submissions started
# Function parse submissions finished
# Function simulating alphas started
# Simulating alpha rank(Ts_ZScore(assets/cashflow, 126))
# Simulating alpha rank(Ts_ZScore(assets/cashflow_dividends, 126))
# Simulating alpha rank(Ts_ZScore(assets/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(assets/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(assets/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(assets/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(assets/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/cashflow, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/cashflow_dividends, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(assets_curr/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/cashflow, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/cashflow_dividends, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(bookvalue_ps/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(capex/cashflow, 126))
# Simulating alpha rank(Ts_ZScore(capex/cashflow_dividends, 126))
# Simulating alpha rank(Ts_ZScore(capex/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(capex/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(capex/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(capex/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(capex/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(cash/cashflow, 126))
# Simulating alpha rank(Ts_ZScore(cash/cashflow_dividends, 126))
# Simulating alpha rank(Ts_ZScore(cash/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(cash/liabilities_curr, 126))
# Simulating alpha rank(Ts_ZScore(cash/operating_expense, 126))
# Simulating alpha rank(Ts_ZScore(cash/operating_income, 126))
# Simulating alpha rank(Ts_ZScore(cash/pretax_income, 126))
# Simulating alpha rank(Ts_ZScore(cash/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(cash/receivable, 126))
# Simulating alpha rank(Ts_ZScore(cash/retained_earnings, 126))
# Simulating alpha rank(Ts_ZScore(cash/return_assets, 126))
# Simulating alpha rank(Ts_ZScore(cash/return_equity, 126))
# Simulating alpha rank(Ts_ZScore(cash/revenue, 126))
# Simulating alpha rank(Ts_ZScore(cash/sales, 126))
# Simulating alpha rank(Ts_ZScore(cash/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(cash/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(cash/SGA_expense, 126))
# Simulating alpha rank(Ts_ZScore(cash/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/cashflow_dividends, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/cashflow_fin, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/cashflow_invst, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/cashflow_op, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/cogs, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/current_ratio, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/debt, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/debt_lt, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/debt_st, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/depre_amort, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/EBIT, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/EBITDA, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/employee, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/enterprise_value, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/eps, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/equity, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/goodwill, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/income, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/income_beforeextra, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/income_tax, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/interest_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/inventory, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/inventory_turnover, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/liabilities, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/liabilities_curr, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/operating_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/operating_income, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/pretax_income, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/receivable, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/retained_earnings, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/return_assets, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/return_equity, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/revenue, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/sales, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/SGA_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/cashflow_fin, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/cashflow_invst, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/cashflow_op, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/cogs, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/current_ratio, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/debt, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/debt_lt, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/debt_st, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/depre_amort, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/EBIT, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/EBITDA, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/employee, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/enterprise_value, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/eps, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/equity, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/goodwill, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/income, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/income_beforeextra, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/income_tax, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/interest_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/inventory, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/inventory_turnover, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/liabilities, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/liabilities_curr, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/operating_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/operating_income, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/pretax_income, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/receivable, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/retained_earnings, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/return_assets, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/return_equity, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/revenue, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/sales, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/SGA_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_dividends/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/cashflow_invst, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/cashflow_op, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/cogs, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/current_ratio, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/debt, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/debt_lt, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/debt_st, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/depre_amort, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/EBIT, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/EBITDA, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/employee, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_fin/employee, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_fin/employee, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_fin/employee, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/enterprise_value, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/eps, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_fin/eps, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/equity, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/goodwill, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/income, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/income_beforeextra, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/income_tax, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/interest_expense, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_fin/interest_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/inventory, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/inventory_turnover, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_fin/inventory_turnover, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_fin/inventory_turnover, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_fin/inventory_turnover, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/invested_capital, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/liabilities, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/liabilities_curr, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/operating_expense, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_fin/operating_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/operating_income, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/pretax_income, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_fin/pretax_income, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/rd_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/receivable, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/retained_earnings, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_fin/retained_earnings, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_fin/retained_earnings, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/return_assets, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/return_equity, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_fin/return_equity, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/revenue, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_fin/revenue, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/sales, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/sales_growth, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_fin/sales_growth, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/sales_ps, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/SGA_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_fin/working_capital, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_fin/working_capital, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/cashflow_op, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/cogs, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/current_ratio, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/debt, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/debt_lt, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_invst/debt_lt, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_invst/debt_lt, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/debt_st, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/depre_amort, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_invst/depre_amort, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/EBIT, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/EBITDA, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_invst/EBITDA, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/employee, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/enterprise_value, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_invst/enterprise_value, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_invst/enterprise_value, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/eps, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/equity, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_invst/equity, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/goodwill, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_invst/goodwill, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_invst/goodwill, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/income, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/income_beforeextra, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/income_tax, 126))
# Too many alphas simulating
# Simulating alpha rank(Ts_ZScore(cashflow_invst/income_tax, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/interest_expense, 126))
# Simulating alpha rank(Ts_ZScore(cashflow_invst/inventory, 126))
# ...
# Parsing alpha rank(Ts_ZScore(cash/cashflow, 126))
# Alpha rank(Ts_ZScore(cash/cashflow, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(cash/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(cash/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(cash/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/invested_capital, 126))
# Alpha rank(Ts_ZScore(cash/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/invested_capital, 126))
# Alpha rank(Ts_ZScore(cash/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/invested_capital, 126))
# Alpha rank(Ts_ZScore(cash/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/rd_expense, 126))
# Alpha rank(Ts_ZScore(cash/rd_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/rd_expense, 126))
# Alpha rank(Ts_ZScore(cash/rd_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/rd_expense, 126))
# Alpha rank(Ts_ZScore(cash/rd_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/sales_growth, 126))
# Alpha rank(Ts_ZScore(cash/sales_growth, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/sales_growth, 126))
# Alpha rank(Ts_ZScore(cash/sales_growth, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/sales_growth, 126))
# Alpha rank(Ts_ZScore(cash/sales_growth, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/sales_ps, 126))
# Alpha rank(Ts_ZScore(cash/sales_ps, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/sales_ps, 126))
# Alpha rank(Ts_ZScore(cash/sales_ps, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/sales_ps, 126))
# Alpha rank(Ts_ZScore(cash/sales_ps, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/working_capital, 126))
# Alpha rank(Ts_ZScore(cash/working_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/working_capital, 126))
# Alpha rank(Ts_ZScore(cash/working_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cash/working_capital, 126))
# Alpha rank(Ts_ZScore(cash/working_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(cashflow/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(cashflow/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/cashflow_dividends, 126))
# Alpha rank(Ts_ZScore(cashflow/cashflow_dividends, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/cashflow_fin, 126))
# Alpha rank(Ts_ZScore(cashflow/cashflow_fin, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/cashflow_fin, 126))
# Alpha rank(Ts_ZScore(cashflow/cashflow_fin, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/cashflow_fin, 126))
# Alpha rank(Ts_ZScore(cashflow/cashflow_fin, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/cashflow_invst, 126))
# Alpha rank(Ts_ZScore(cashflow/cashflow_invst, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/cashflow_invst, 126))
# Alpha rank(Ts_ZScore(cashflow/cashflow_invst, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/cashflow_invst, 126))
# Alpha rank(Ts_ZScore(cashflow/cashflow_invst, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/cashflow_op, 126))
# Alpha rank(Ts_ZScore(cashflow/cashflow_op, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/cashflow_op, 126))
# Alpha rank(Ts_ZScore(cashflow/cashflow_op, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/cashflow_op, 126))
# Alpha rank(Ts_ZScore(cashflow/cashflow_op, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/cogs, 126))
# Alpha rank(Ts_ZScore(cashflow/cogs, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/cogs, 126))
# Alpha rank(Ts_ZScore(cashflow/cogs, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/cogs, 126))
# Alpha rank(Ts_ZScore(cashflow/cogs, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/current_ratio, 126))
# Alpha rank(Ts_ZScore(cashflow/current_ratio, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/current_ratio, 126))
# Alpha rank(Ts_ZScore(cashflow/current_ratio, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/current_ratio, 126))
# Alpha rank(Ts_ZScore(cashflow/current_ratio, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/debt, 126))
# Alpha rank(Ts_ZScore(cashflow/debt, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/debt, 126))
# Alpha rank(Ts_ZScore(cashflow/debt, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/debt, 126))
# Alpha rank(Ts_ZScore(cashflow/debt, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/debt_lt, 126))
# Alpha rank(Ts_ZScore(cashflow/debt_lt, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/debt_lt, 126))
# Alpha rank(Ts_ZScore(cashflow/debt_lt, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/debt_lt, 126))
# Alpha rank(Ts_ZScore(cashflow/debt_lt, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/debt_st, 126))
# Alpha rank(Ts_ZScore(cashflow/debt_st, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/debt_st, 126))
# Alpha rank(Ts_ZScore(cashflow/debt_st, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/debt_st, 126))
# Alpha rank(Ts_ZScore(cashflow/debt_st, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/depre_amort, 126))
# Alpha rank(Ts_ZScore(cashflow/depre_amort, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/depre_amort, 126))
# Alpha rank(Ts_ZScore(cashflow/depre_amort, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/depre_amort, 126))
# Alpha rank(Ts_ZScore(cashflow/depre_amort, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/EBIT, 126))
# Alpha rank(Ts_ZScore(cashflow/EBIT, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/EBIT, 126))
# Alpha rank(Ts_ZScore(cashflow/EBIT, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/EBIT, 126))
# Alpha rank(Ts_ZScore(cashflow/EBIT, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/EBITDA, 126))
# Alpha rank(Ts_ZScore(cashflow/EBITDA, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/EBITDA, 126))
# Alpha rank(Ts_ZScore(cashflow/EBITDA, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/EBITDA, 126))
# Alpha rank(Ts_ZScore(cashflow/EBITDA, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/employee, 126))
# Alpha rank(Ts_ZScore(cashflow/employee, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/employee, 126))
# Alpha rank(Ts_ZScore(cashflow/employee, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/employee, 126))
# Alpha rank(Ts_ZScore(cashflow/employee, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/enterprise_value, 126))
# Alpha rank(Ts_ZScore(cashflow/enterprise_value, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/enterprise_value, 126))
# Alpha rank(Ts_ZScore(cashflow/enterprise_value, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/enterprise_value, 126))
# Alpha rank(Ts_ZScore(cashflow/enterprise_value, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/eps, 126))
# Alpha rank(Ts_ZScore(cashflow/eps, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/eps, 126))
# Alpha rank(Ts_ZScore(cashflow/eps, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/eps, 126))
# Alpha rank(Ts_ZScore(cashflow/eps, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/equity, 126))
# Alpha rank(Ts_ZScore(cashflow/equity, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/equity, 126))
# Alpha rank(Ts_ZScore(cashflow/equity, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/equity, 126))
# Alpha rank(Ts_ZScore(cashflow/equity, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/goodwill, 126))
# Alpha rank(Ts_ZScore(cashflow/goodwill, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/goodwill, 126))
# Alpha rank(Ts_ZScore(cashflow/goodwill, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/goodwill, 126))
# Alpha rank(Ts_ZScore(cashflow/goodwill, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/income, 126))
# Alpha rank(Ts_ZScore(cashflow/income, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/income, 126))
# Alpha rank(Ts_ZScore(cashflow/income, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/income, 126))
# Alpha rank(Ts_ZScore(cashflow/income, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/income_beforeextra, 126))
# Alpha rank(Ts_ZScore(cashflow/income_beforeextra, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/income_beforeextra, 126))
# Alpha rank(Ts_ZScore(cashflow/income_beforeextra, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/income_beforeextra, 126))
# Alpha rank(Ts_ZScore(cashflow/income_beforeextra, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/income_tax, 126))
# Alpha rank(Ts_ZScore(cashflow/income_tax, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/income_tax, 126))
# Alpha rank(Ts_ZScore(cashflow/income_tax, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/income_tax, 126))
# Alpha rank(Ts_ZScore(cashflow/income_tax, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/interest_expense, 126))
# Alpha rank(Ts_ZScore(cashflow/interest_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/interest_expense, 126))
# Alpha rank(Ts_ZScore(cashflow/interest_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/interest_expense, 126))
# Alpha rank(Ts_ZScore(cashflow/interest_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/inventory, 126))
# Alpha rank(Ts_ZScore(cashflow/inventory, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/inventory, 126))
# Alpha rank(Ts_ZScore(cashflow/inventory, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/inventory, 126))
# Alpha rank(Ts_ZScore(cashflow/inventory, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/inventory_turnover, 126))
# Alpha rank(Ts_ZScore(cashflow/inventory_turnover, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/inventory_turnover, 126))
# Alpha rank(Ts_ZScore(cashflow/inventory_turnover, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/inventory_turnover, 126))
# Alpha rank(Ts_ZScore(cashflow/inventory_turnover, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/invested_capital, 126))
# Alpha rank(Ts_ZScore(cashflow/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/invested_capital, 126))
# Alpha rank(Ts_ZScore(cashflow/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/invested_capital, 126))
# Alpha rank(Ts_ZScore(cashflow/invested_capital, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/liabilities, 126))
# Alpha rank(Ts_ZScore(cashflow/liabilities, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/liabilities, 126))
# Alpha rank(Ts_ZScore(cashflow/liabilities, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/liabilities, 126))
# Alpha rank(Ts_ZScore(cashflow/liabilities, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/liabilities_curr, 126))
# Alpha rank(Ts_ZScore(cashflow/liabilities_curr, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/liabilities_curr, 126))
# Alpha rank(Ts_ZScore(cashflow/liabilities_curr, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/liabilities_curr, 126))
# Alpha rank(Ts_ZScore(cashflow/liabilities_curr, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/operating_expense, 126))
# Alpha rank(Ts_ZScore(cashflow/operating_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/operating_expense, 126))
# Alpha rank(Ts_ZScore(cashflow/operating_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/operating_expense, 126))
# Alpha rank(Ts_ZScore(cashflow/operating_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/operating_income, 126))
# Alpha rank(Ts_ZScore(cashflow/operating_income, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/operating_income, 126))
# Alpha rank(Ts_ZScore(cashflow/operating_income, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/operating_income, 126))
# Alpha rank(Ts_ZScore(cashflow/operating_income, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/pretax_income, 126))
# Alpha rank(Ts_ZScore(cashflow/pretax_income, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/pretax_income, 126))
# Alpha rank(Ts_ZScore(cashflow/pretax_income, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/pretax_income, 126))
# Alpha rank(Ts_ZScore(cashflow/pretax_income, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/rd_expense, 126))
# Alpha rank(Ts_ZScore(cashflow/rd_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/rd_expense, 126))
# Alpha rank(Ts_ZScore(cashflow/rd_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/rd_expense, 126))
# Alpha rank(Ts_ZScore(cashflow/rd_expense, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/receivable, 126))
# Alpha rank(Ts_ZScore(cashflow/receivable, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/receivable, 126))
# Alpha rank(Ts_ZScore(cashflow/receivable, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/receivable, 126))
# Alpha rank(Ts_ZScore(cashflow/receivable, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/retained_earnings, 126))
# Alpha rank(Ts_ZScore(cashflow/retained_earnings, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/retained_earnings, 126))
# Alpha rank(Ts_ZScore(cashflow/retained_earnings, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/retained_earnings, 126))
# Alpha rank(Ts_ZScore(cashflow/retained_earnings, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/return_assets, 126))
# Alpha rank(Ts_ZScore(cashflow/return_assets, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/return_assets, 126))
# Alpha rank(Ts_ZScore(cashflow/return_assets, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/return_assets, 126))
# Alpha rank(Ts_ZScore(cashflow/return_assets, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/return_equity, 126))
# Alpha rank(Ts_ZScore(cashflow/return_equity, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/return_equity, 126))
# Alpha rank(Ts_ZScore(cashflow/return_equity, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/return_equity, 126))
# Alpha rank(Ts_ZScore(cashflow/return_equity, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/revenue, 126))
# Alpha rank(Ts_ZScore(cashflow/revenue, 126)) not finished simulation
# Parsing alpha rank(Ts_ZScore(cashflow/revenue, 126))
# Alpha rank(Ts_ZScore(cashflow/revenue, 126)) not finished simulation

# %%
import sys

del sys.modules['alpha_client']

import alpha_client

# %%
with open(config_fn, 'r') as f:
    config = json.load(f)

# %%
config
# Out:
# {'mongodb_connection_string': 'mongodb://dalisa1212:kloppolk_2017@wqserver-shard-00-00-ftqza.mongodb.net:27017,wqserver-shard-00-01-ftqza.mongodb.net:27017,wqserver-shard-00-02-ftqza.mongodb.net:27017/wq?ssl=true&replicaSet=WQServer-shard-0&authSource=admin&retryWrites=true',
#  'origin': 'https://www.worldquantvrc.com/simulate',
#  'users': [{'name': 'nk',
#    'login': 'krokhmal11@mail.ru',
#    'password': 'cop12345',
#    'xsrf': '2|0d88a38b|11fba3b3de4b36710dcc7b5e9e1b53c1|1534426416',
#    'db_base': 'alphas_base_nk',
#    'db_simulate': 'alphas_simulate_nk',
#    'db_trash': 'alphas_trash_nk',
#    'db_prod': 'alphas_prod_nk',
#    'beg_time': '',
#    'end_time': '',
#    'days off': '',
#    'proxies': {}},
#   {'name': 'da',
#    'login': 'dalisa1212@mail.ru',
#    'xsrf': '2|fb38ac16|5d2254a56b5d9fe3cbbeeace215a55ef|1529707760',
#    'password': 'playhard1212',
#    'db_base': 'alphas_base_da',
#    'db_simulate': 'alphas_simulate_da',
#    'db_trash': 'alphas_trash_da',
#    'db_prod': 'alphas_prod_da',
#    'beg_time': '',
#    'end_time': '',
#    'days_off': '',
#    'proxies': {'http': 'http://ppohxc:OROarUUmzT@78.40.118.31:24531'}},
#   {'name': 'mg',
#    'login': 'nikita95borisov@mail.ru',
#    'password': 'Ð²ÐºÐ¾Ð½Ñ‚Ð°ÐºÑ‚ÐµÐ´Ð¾Ð±Ñ€Ð¾Ð¿Ð¾Ð¶Ð°Ð»Ð¾Ð²Ð°Ñ‚ÑŒ',
#    'xsrf': '2|0aaabecb|5053f6e633c94aaebbd44a577c19985b|1530485282',
#    'db_base': 'alphas_base_mg',
#    'db_simulate': 'alphas_simulate_mg',
#    'db_trash': 'alphas_trash_mg',
#    'db_prod': 'alphas_prod_mg',
#    'beg_time': '',
#    'end_time': '',
#    'days_off': '',
#    'proxies': {'http': 'http://ppohxc:OROarUUmzT@78.40.118.31:24531'}}]}

# %%
user_name = 'da'
mongo_connection_string = config['mongodb_connection_string']
origin = config['origin']
site_address = 'https://www.worldquantvrc.com'
info = [x for x in config['users'] if x['name'] == user_name]
collection_purgatory = 'alphas_purgatory'
collection_trash = 'alphas_trash'
collection_simulate = 'alphas_simulate'
collection_prod = 'alphas_prod'
login = info[0]['login']
password = info[0]['password']
xsrf = info[0]['xsrf']
proxies = info[0]['proxies']

# %%
client = alpha_client.alpha_client(login=login, 
                                   password=password,
                                   collection_prod=collection_prod,
                                   collection_simulate=collection_simulate,
                                   collection_trash = collection_trash,
                                   collection_purgatory = collection_purgatory,
                                   mongo_connection_string = mongo_connection_string,
                                   origin=origin,
                                   xsrf=xsrf,
                                   site_address=site_address,
                                   proxies = proxies)

# %%
requestor = alpha_requestor.Request(login=login,
                                    password=password,
                                    origin=origin,
                                    xsrf=xsrf,
                                    site_address=site_address,
                                    proxies=proxies)

# %% [markdown]
# # Test

# %%
res = requestor.log_in()
cookie = res.cookies
full_cookie = requestor.build_cookie(cookie)

# %%
mongo = pymongo.MongoClient(mongo_connection_string).wq

# %% [markdown]
# ### Simulate

# %%
alphas = pd.DataFrame(list(mongo['alphas_simulate'].find({'Status': 'InProgress', 'Executor': 'da'}).limit(10)))
ids = list(alphas['_id'])

# %%
client.simulate_alphas(cookie, ids)
# Out:
# Simulating alpha Ts_ZScore(assets/bookvalue_ps, 126)
# Simulating alpha Ts_ZScore(assets/cashflow, 126)
# Simulating alpha Ts_ZScore(assets/cashflow_fin, 126)
# Simulating alpha Ts_ZScore(assets/debt_st, 126)
# Simulating alpha Ts_ZScore(assets/EBITDA, 126)
# Simulating alpha Ts_ZScore(assets/income_tax, 126)
# Simulating alpha Ts_ZScore(assets/liabilities_curr, 126)
# Simulating alpha Ts_ZScore(assets_curr/cashflow_op, 126)
# Simulating alpha Ts_ZScore(assets_curr/employee, 126)
# Simulating alpha Ts_ZScore(assets_curr/eps, 126)

# %% [markdown]
# ### Parse

# %%
alphas = pd.DataFrame(list(mongo['alphas_purgatory'].find({'Status': 'InProgress', 'Executor': 'da'}).limit(10)))
ids = list(alphas['_id'])

# %%
client.parse_alphas(cookie, ids)
# Out:
# Parsing alpha Ts_ZScore(assets/bookvalue_ps, 126)
# {'AlphaId': ObjectId('5ba2bd594e28b32ffc20e9ab'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "Ts_ZScore(assets/bookvalue_ps, 126)", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': 'Ts_ZScore(assets/bookvalue_ps, 126)', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-19 21:19:21.177708', 'Executor': 'da', 'LogicName': 'BT-6', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 162898536}
# Parsing alpha Ts_ZScore(assets/cashflow, 126)
# {'AlphaId': ObjectId('5ba2bd594e28b32ffc20e9ae'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "Ts_ZScore(assets/cashflow, 126)", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': 'Ts_ZScore(assets/cashflow, 126)', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-19 21:19:21.178711', 'Executor': 'da', 'LogicName': 'BT-6', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 162898604}
# Parsing alpha Ts_ZScore(assets/cashflow_fin, 126)
# {'AlphaId': ObjectId('5ba2bd594e28b32ffc20e9b0'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "Ts_ZScore(assets/cashflow_fin, 126)", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': 'Ts_ZScore(assets/cashflow_fin, 126)', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-19 21:19:21.178711', 'Executor': 'da', 'LogicName': 'BT-6', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 162898630}
# Parsing alpha Ts_ZScore(assets/debt_st, 126)
# {'AlphaId': ObjectId('5ba2bd594e28b32ffc20e9b7'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "Ts_ZScore(assets/debt_st, 126)", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': 'Ts_ZScore(assets/debt_st, 126)', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-19 21:19:21.178711', 'Executor': 'da', 'LogicName': 'BT-6', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 162898677}
# Parsing alpha Ts_ZScore(assets/EBITDA, 126)
# {'AlphaId': ObjectId('5ba2bd594e28b32ffc20e9ba'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "Ts_ZScore(assets/EBITDA, 126)", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': 'Ts_ZScore(assets/EBITDA, 126)', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-19 21:19:21.179703', 'Executor': 'da', 'LogicName': 'BT-6', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 162898700}
# Parsing alpha Ts_ZScore(assets/income_tax, 126)
# {'AlphaId': ObjectId('5ba2bd594e28b32ffc20e9c2'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "Ts_ZScore(assets/income_tax, 126)", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': 'Ts_ZScore(assets/income_tax, 126)', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-19 21:19:21.179703', 'Executor': 'da', 'LogicName': 'BT-6', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 162898734}
# Parsing alpha Ts_ZScore(assets/liabilities_curr, 126)
# {'AlphaId': ObjectId('5ba2bd594e28b32ffc20e9c8'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "Ts_ZScore(assets/liabilities_curr, 126)", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': 'Ts_ZScore(assets/liabilities_curr, 126)', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-19 21:19:21.179703', 'Executor': 'da', 'LogicName': 'BT-6', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 162898759}
# Parsing alpha Ts_ZScore(assets_curr/cashflow_op, 126)
# {'AlphaId': ObjectId('5ba2bd594e28b32ffc20e9de'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "Ts_ZScore(assets_curr/cashflow_op, 126)", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': 'Ts_ZScore(assets_curr/cashflow_op, 126)', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-19 21:19:21.180708', 'Executor': 'da', 'LogicName': 'BT-6', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 162898797}
# Parsing alpha Ts_ZScore(assets_curr/employee, 126)
# {'AlphaId': ObjectId('5ba2bd594e28b32ffc20e9e7'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "Ts_ZScore(assets_curr/employee, 126)", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': 'Ts_ZScore(assets_curr/employee, 126)', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-19 21:19:21.181710', 'Executor': 'da', 'LogicName': 'BT-6', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 162898815}
# Parsing alpha Ts_ZScore(assets_curr/eps, 126)
# {'AlphaId': ObjectId('5ba2bd594e28b32ffc20e9e9'), 'Alpha': '[{"delay": "1", "unitcheck": "off", "univid": "TOP3000", "opcodetype": "EXPRESSION", "opassetclass": "EQUITY", "optrunc": "0.1", "code": "Ts_ZScore(assets_curr/eps, 126)", "region": "USA", "opneut": "subindustry", "tags": "equity", "decay": "5", "DataViz": "false", "backdays": "512", "simtime": "Y5"}]', 'Code': 'Ts_ZScore(assets_curr/eps, 126)', 'Neutralization': 'market', 'Universe': 'TOP3000', 'Delay': 1, 'Region': 'USA', 'Time': '2018-09-19 21:19:21.181710', 'Executor': 'da', 'LogicName': 'BT-6', 'Comment': '', 'Status': 'InProgress', 'Type': 'Base0', 'DataType': 'Fundamental', 'Index': 162898888}

# %% [markdown]
# ### Submit

# %%
alphas = pd.DataFrame(list(mongo['alphas_prod'].find({'Status': 'InProgress', 'Executor': 'da'}).limit(10)))
ids = list(alphas['_id'])

# %%
client.parse_submissions(cookie, ids)
# Out:
# Parsing submission of alpha with index 162884752
# Exception occured while submission'SubmissionId'
# Parsing submission of alpha with index 162884752
# Exception occured while submission'SubmissionId'
# Parsing submission of alpha with index 162884752
# Exception occured while submission'SubmissionId'
# Parsing submission of alpha with index 162884752
# Exception occured while submission'SubmissionId'
# Parsing submission of alpha with index 162884752
# Exception occured while submission'SubmissionId'
# Too many errors, function Parse_Submission finished

# %%
requestor.log_out(cookie)
# Out:
# <Response [200]>

# %% [markdown]
# # Test

# %%
import pymongo
import time
import json
import pandas as pd
from bson.objectid import ObjectId

mongo_connection_string = 'mongodb://dalisa1212:kloppolk_2017@wqserver-shard-00-00-ftqza.mongodb.net:27017,wqserver-shard-00-01-ftqza.mongodb.net:27017,wqserver-shard-00-02-ftqza.mongodb.net:27017/wq?ssl=true&replicaSet=WQServer-shard-0&authSource=admin&retryWrites=true'
mongo = pymongo.MongoClient(mongo_connection_string).wq
pack_number = 2
iteration = 1
alphas = pd.DataFrame(list(mongo['alphas_prod'].find({'Sharpe': {'$gte': 0.7},
                                                              'Executor': 'da',
                                                              'IsMix': True,
                                                              'Iteration': iteration-1}).limit(pack_number)))

# %%
alphas.columns
# Out:
# Index(['Alpha', 'AlphaId', 'BookSize', 'Code', 'Comment', 'DataType', 'Delay',
#        'DrawDown', 'Executor', 'Fitness', 'Index', 'IsMix', 'IsTour', 'IsTuch',
#        'Iteration', 'LogicName', 'LongCount', 'Margin', 'Neutralization',
#        'PnL', 'Region', 'Returns', 'Sharpe', 'ShortCount', 'Status', 'Time',
#        'TurnOver', 'Type', 'Universe', 'Year', 'YearId', '_id'],
#       dtype='object')
